# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
import os
import math
import pathlib
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from IPython.display import clear_output

import warnings
from lifelines.utils import CensoringType
from lifelines.utils import concordance_index

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

experiment = 220627
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
endpoint_defs = pd.read_feather(f"{output_path}/phecode_defs_220306.feather").sort_values("endpoint")

# %%
data_outcomes = pd.read_feather(f"{output_path}/baseline_outcomes_220627.feather").set_index("eid")
endpoints = [e[:-6] for e in data_outcomes.columns if "_event" in e]

# %%
data_outcomes
# Out:
#          OMOP_4306655_prev  phecode_202_prev  phecode_401_prev  \
# eid
# 1000018              False             False              True
# 1000020              False             False             False
# 1000037              False             False             False
# 1000043              False             False              True
# 1000051              False              True             False
# ...                    ...               ...               ...
# 6025150              False             False             False
# 6025165              False             False             False
# 6025173              False             False             False
# 6025182              False             False             False
# 6025198              False             False              True
#
#          phecode_401-1_prev  phecode_475_prev  phecode_202-2_prev  \
# eid
# 1000018                True             False               False
# 1000020               False             False               False
# 1000037               False             False               False
# 1000043                True             False               False
# 1000051               False             False                True
# ...                     ...               ...                 ...
# 6025150               False             False               False
# 6025165               False             False               False
# 6025173               False             False               False
# 6025182               False              True               False
# 6025198                True             False               False
#
#          phecode_718_prev  phecode_089_prev  phecode_130_prev  \
# eid
# 1000018             False             False             False
# 1000020             False             False             False
# 1000037              True             False             False
# 1000043             False              True              True
# 1000051             False             False             False
# ...                   ...               ...               ...
# 6025150             False             False             False
# 6025165              True              True             False
# 6025173             False             False             False
# 6025182              True             False             False
# 6025198             False             False             False
#
#          phecode_713_prev  ...  phecode_247-85_time  phecode_361-24_time  \
# eid                        ...
# 1000018             False  ...            11.866089            11.866089
# 1000020             False  ...            13.596446            13.596446
# 1000037              True  ...            12.868163            12.868163
# 1000043              True  ...            12.309629            12.309629
# 1000051             False  ...            15.291210            15.291210
# ...                   ...  ...                  ...                  ...
# 6025150             False  ...            14.237117            14.237117
# 6025165             False  ...            13.059816            13.059816
# 6025173             False  ...            13.018748            13.018748
# 6025182              True  ...            11.233632            11.233632
# 6025198             False  ...             8.868081             8.868081
#
#          phecode_424-7_time  phecode_244-3_time  phecode_824-1_time  \
# eid
# 1000018           11.866089           11.866089           11.866089
# 1000020           13.596446           13.596446           13.596446
# 1000037           12.868163           12.868163           12.868163
# 1000043           12.309629           12.309629           12.309629
# 1000051           15.291210           15.291210           15.291210
# ...                     ...                 ...                 ...
# 6025150           14.237117           14.237117           14.237117
# 6025165           13.059816           13.059816           13.059816
# 6025173           13.018748           13.018748           13.018748
# 6025182           11.233632           11.233632           11.233632
# 6025198            8.868081            8.868081            8.868081
#
#          phecode_206-1_time  phecode_018_time  phecode_363-8_time  \
# eid
# 1000018           11.866089         11.866089           11.866089
# 1000020           13.596446         13.596446           13.596446
# 1000037           12.868163         12.868163           12.868163
# 1000043           12.309629         12.309629           12.309629
# 1000051           15.291210         15.291210           15.291210
# ...                     ...               ...                 ...
# 6025150           14.237117         14.237117           14.237117
# 6025165           13.059816         13.059816           13.059816
# 6025173           13.018748         13.018748           13.018748
# 6025182           11.233632         11.233632           11.233632
# 6025198            8.868081          8.868081            8.868081
#
#          phecode_396-6_time  phecode_361-93_time
# eid
# 1000018           11.866089            11.866089
# 1000020           13.596446            13.596446
# 1000037           12.868163            12.868163
# 1000043           12.309629            12.309629
# 1000051           15.291210            15.291210
# ...                     ...                  ...
# 6025150           14.237117            14.237117
# 6025165           13.059816            13.059816
# 6025173           13.018748            13.018748
# 6025182           11.233632            11.233632
# 6025198            8.868081             8.868081
#
# [502460 rows x 8508 columns]

# %%
eligable_eids = pd.read_feather(f"{output_path}/eligable_eids_220627.feather")
eids_dict = eligable_eids.set_index("endpoint")["eid_list"].to_dict()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
d = []
for endpoint in tqdm(endpoints):
    s = data_outcomes[f"{endpoint}_event"].loc[eids_dict[endpoint]]
    n = s.sum()
    freq = s.mean()
    d.append({"endpoint":endpoint, "eligable":len(eids_dict[endpoint]), "n": n, "freq": freq})

# %%
endpoints_freqs = pd.DataFrame().from_dict(d).sort_values("endpoint").reset_index(drop=True)

# %%
endpoints_freqs.sort_values("freq")#query("n>100")

# %%
endpoints_ds = endpoints_freqs.query("n>100").sort_values("endpoint").reset_index(drop=True).merge(endpoint_defs)

# %%
endpoints_ds

# %%
endpoints_ds.to_csv(f"{experiment_path}/endpoints.csv")

# %%
endpoints_old = pd.read_csv(f"{output_path}/220531/endpoints.csv").endpoint.to_list()

# %%
endpoints_ds.query("endpoint==@endpoints_old")
