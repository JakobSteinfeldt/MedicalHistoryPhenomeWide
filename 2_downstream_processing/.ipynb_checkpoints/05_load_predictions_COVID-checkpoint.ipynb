# %%
import numpy as np
import pandas as pd
import pathlib
from tqdm.auto import tqdm

import hydra
from omegaconf import DictConfig, OmegaConf

import torch
import ray

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

pathlib.Path(figure_path).mkdir(parents=True, exist_ok=True)
pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

experiment = 230425
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
ray.shutdown()

# %%
ray.init(num_cpus=24, include_dashboard=False)
# Out:
# 2023-05-10 11:11:38,038	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8267
# RayContext(dashboard_url='127.0.0.1:8267', python_version='3.10.9', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '10.32.105.10', 'raylet_ip_address': '10.32.105.10', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-05-10_11-11-33_057540_358394/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-05-10_11-11-33_057540_358394/sockets/raylet', 'webui_url': '127.0.0.1:8267', 'session_dir': '/tmp/ray/session_2023-05-10_11-11-33_057540_358394', 'metrics_export_port': 54920, 'gcs_address': '10.32.105.10:60735', 'address': '10.32.105.10:60735', 'dashboard_agent_listen_port': 52365, 'node_id': 'a79943bdf43f4fb2b94e7456f6394520d21c44d9f61b0352dd63aca8'})

# %%
import wandb
api = wandb.Api(timeout=120)
entity, project = "cardiors", "recordgraphs"  # set to your entity and project 
tag = "230428_covid_inference"
runs = api.runs(entity + "/" + project, filters={"tags": {"$in": [tag]}})

# %%
len(runs)
# Out:
# 22

# %%
run_list = []
for run in tqdm(runs):
    run_list.append(
        {
            "id": run.path[-1], 
            "name": run.name,
            "tags": run.tags,
            "config": {k: v for k,v in run.config.items() if not k.startswith('_')},
            "summary": run.summary._json_dict,
            "path": None if "best_checkpoint" not in run.config.keys() else str(pathlib.Path(run.config["best_checkpoint"]).parent.parent)
        }
    )
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x7fac51536680>
# Traceback (most recent call last):
#   File "/home/steinfej/miniconda3/envs/udm/lib/python3.10/site-packages/tqdm/std.py", line 1162, in __del__
#     self.close()
#   File "/home/steinfej/miniconda3/envs/udm/lib/python3.10/site-packages/tqdm/notebook.py", line 282, in close
#     if self.disable:
# AttributeError: 'tqdm' object has no attribute 'disable'
#   0%|          | 0/22 [00:00<?, ?it/s]

# %%
model_path = "/sc-projects/sc-proj-ukb-cvd/results/models/RecordGraphs/"

# %%
pd.DataFrame(run_list)
# Out:
#           id                      name  \
# 0   133al0d6      autumn-darkness-6444
# 1   19ntedgh       scarlet-donkey-6443
# 2   1u8pz9b9       winter-firefly-6442
# 3   1cblrjri      swift-armadillo-6441
# 4   3sjfxviz          polar-night-6440
# 5   1s8uwf1p         vivid-dragon-6439
# 6   13x5yibt        gentle-deluge-6438
# 7   z7q7jhj4         drawn-plasma-6437
# 8   2udx8zye        vibrant-music-6436
# 9   2j1w29pr         easy-firefly-6435
# 10  nnc2ah0h       wobbly-morning-6434
# 11  389twhxs          expert-lion-6433
# 12  3fh1zry5         morning-rain-6432
# 13  1uaw9rbc          swept-glade-6431
# 14  2tpi4pvi  dauntless-armadillo-6430
# 15  28yxnxnk          fresh-field-6429
# 16  1nyo51rr       blooming-grass-6428
# 17  20hlbiwn         lilac-monkey-6427
# 18  3gvcwl28         sleek-planet-6426
# 19  2tt3rkyw          cool-deluge-6425
# 20  1mgbvam1          sleek-paper-6424
# 21  2x6x0y2g        wise-universe-6423
#
#                                              tags  \
# 0   [230428_covid_inference, full_data, identity]
# 1   [230428_covid_inference, full_data, identity]
# 2   [230428_covid_inference, full_data, identity]
# 3   [230428_covid_inference, full_data, identity]
# 4   [230428_covid_inference, full_data, identity]
# 5   [230428_covid_inference, full_data, identity]
# 6   [230428_covid_inference, full_data, identity]
# 7   [230428_covid_inference, full_data, identity]
# 8   [230428_covid_inference, full_data, identity]
# 9   [230428_covid_inference, full_data, identity]
# 10  [230428_covid_inference, full_data, identity]
# 11  [230428_covid_inference, full_data, identity]
# 12  [230428_covid_inference, full_data, identity]
# 13  [230428_covid_inference, full_data, identity]
# 14  [230428_covid_inference, full_data, identity]
# 15  [230428_covid_inference, full_data, identity]
# 16  [230428_covid_inference, full_data, identity]
# 17  [230428_covid_inference, full_data, identity]
# 18  [230428_covid_inference, full_data, identity]
# 19  [230428_covid_inference, full_data, identity]
# 20  [230428_covid_inference, full_data, identity]
# 21  [230428_covid_inference, full_data, identity]
#
#                                                config  \
# 0   {'feature_metadata': {'records': {'n': 15596, ...
# 1   {'feature_metadata': {'records': {'n': 15596, ...
# 2   {'feature_metadata': {'records': {'n': 15596, ...
# 3   {'feature_metadata': {'records': {'n': 15596, ...
# 4   {'feature_metadata': {'records': {'n': 15596, ...
# 5   {'feature_metadata': {'records': {'n': 15596, ...
# 6   {'feature_metadata': {'records': {'n': 15596, ...
# 7   {'feature_metadata': {'records': {'n': 15596, ...
# 8   {'feature_metadata': {'records': {'n': 15596, ...
# 9   {'feature_metadata': {'records': {'n': 15596, ...
# 10  {'feature_metadata': {'records': {'n': 15596, ...
# 11  {'feature_metadata': {'records': {'n': 15596, ...
# 12  {'feature_metadata': {'records': {'n': 15596, ...
# 13  {'feature_metadata': {'records': {'n': 15596, ...
# 14  {'feature_metadata': {'records': {'n': 15596, ...
# 15  {'feature_metadata': {'records': {'n': 15596, ...
# 16  {'feature_metadata': {'records': {'n': 15596, ...
# 17  {'feature_metadata': {'records': {'n': 15596, ...
# 18  {'feature_metadata': {'records': {'n': 15596, ...
# 19  {'feature_metadata': {'records': {'n': 15596, ...
# 20  {'feature_metadata': {'records': {'n': 15596, ...
# 21  {'feature_metadata': {'records': {'n': 15596, ...
#
#                          summary  path
# 0   {'_wandb': {'runtime': 769}}  None
# 1   {'_wandb': {'runtime': 878}}  None
# 2   {'_wandb': {'runtime': 857}}  None
# 3   {'_wandb': {'runtime': 771}}  None
# 4   {'_wandb': {'runtime': 628}}  None
# 5   {'_wandb': {'runtime': 614}}  None
# 6   {'_wandb': {'runtime': 625}}  None
# 7   {'_wandb': {'runtime': 776}}  None
# 8   {'_wandb': {'runtime': 773}}  None
# 9   {'_wandb': {'runtime': 852}}  None
# 10  {'_wandb': {'runtime': 860}}  None
# 11  {'_wandb': {'runtime': 631}}  None
# 12  {'_wandb': {'runtime': 611}}  None
# 13  {'_wandb': {'runtime': 610}}  None
# 14  {'_wandb': {'runtime': 758}}  None
# 15  {'_wandb': {'runtime': 800}}  None
# 16  {'_wandb': {'runtime': 760}}  None
# 17  {'_wandb': {'runtime': 859}}  None
# 18  {'_wandb': {'runtime': 856}}  None
# 19  {'_wandb': {'runtime': 624}}  None
# 20  {'_wandb': {'runtime': 595}}  None
# 21  {'_wandb': {'runtime': 605}}  None

# %%
runs_df = pd.DataFrame(run_list)#query("path==path")
runs_df["path"] = "/sc-projects/sc-proj-ukb-cvd/results/models/RecordGraphs/" + runs_df["id"]
print(runs_df.shape)
runs_df.sort_values("name")
# Out:
# (22, 6)
#           id                      name  \
# 0   133al0d6      autumn-darkness-6444
# 16  1nyo51rr       blooming-grass-6428
# 19  2tt3rkyw          cool-deluge-6425
# 14  2tpi4pvi  dauntless-armadillo-6430
# 7   z7q7jhj4         drawn-plasma-6437
# 9   2j1w29pr         easy-firefly-6435
# 11  389twhxs          expert-lion-6433
# 15  28yxnxnk          fresh-field-6429
# 6   13x5yibt        gentle-deluge-6438
# 17  20hlbiwn         lilac-monkey-6427
# 12  3fh1zry5         morning-rain-6432
# 4   3sjfxviz          polar-night-6440
# 1   19ntedgh       scarlet-donkey-6443
# 20  1mgbvam1          sleek-paper-6424
# 18  3gvcwl28         sleek-planet-6426
# 13  1uaw9rbc          swept-glade-6431
# 3   1cblrjri      swift-armadillo-6441
# 8   2udx8zye        vibrant-music-6436
# 5   1s8uwf1p         vivid-dragon-6439
# 2   1u8pz9b9       winter-firefly-6442
# 21  2x6x0y2g        wise-universe-6423
# 10  nnc2ah0h       wobbly-morning-6434
#
#                                              tags  \
# 0   [230428_covid_inference, full_data, identity]
# 16  [230428_covid_inference, full_data, identity]
# 19  [230428_covid_inference, full_data, identity]
# 14  [230428_covid_inference, full_data, identity]
# 7   [230428_covid_inference, full_data, identity]
# 9   [230428_covid_inference, full_data, identity]
# 11  [230428_covid_inference, full_data, identity]
# 15  [230428_covid_inference, full_data, identity]
# 6   [230428_covid_inference, full_data, identity]
# 17  [230428_covid_inference, full_data, identity]
# 12  [230428_covid_inference, full_data, identity]
# 4   [230428_covid_inference, full_data, identity]
# 1   [230428_covid_inference, full_data, identity]
# 20  [230428_covid_inference, full_data, identity]
# 18  [230428_covid_inference, full_data, identity]
# 13  [230428_covid_inference, full_data, identity]
# 3   [230428_covid_inference, full_data, identity]
# 8   [230428_covid_inference, full_data, identity]
# 5   [230428_covid_inference, full_data, identity]
# 2   [230428_covid_inference, full_data, identity]
# 21  [230428_covid_inference, full_data, identity]
# 10  [230428_covid_inference, full_data, identity]
#
#                                                config  \
# 0   {'feature_metadata': {'records': {'n': 15596, ...
# 16  {'feature_metadata': {'records': {'n': 15596, ...
# 19  {'feature_metadata': {'records': {'n': 15596, ...
# 14  {'feature_metadata': {'records': {'n': 15596, ...
# 7   {'feature_metadata': {'records': {'n': 15596, ...
# 9   {'feature_metadata': {'records': {'n': 15596, ...
# 11  {'feature_metadata': {'records': {'n': 15596, ...
# 15  {'feature_metadata': {'records': {'n': 15596, ...
# 6   {'feature_metadata': {'records': {'n': 15596, ...
# 17  {'feature_metadata': {'records': {'n': 15596, ...
# 12  {'feature_metadata': {'records': {'n': 15596, ...
# 4   {'feature_metadata': {'records': {'n': 15596, ...
# 1   {'feature_metadata': {'records': {'n': 15596, ...
# 20  {'feature_metadata': {'records': {'n': 15596, ...
# 18  {'feature_metadata': {'records': {'n': 15596, ...
# 13  {'feature_metadata': {'records': {'n': 15596, ...
# 3   {'feature_metadata': {'records': {'n': 15596, ...
# 8   {'feature_metadata': {'records': {'n': 15596, ...
# 5   {'feature_metadata': {'records': {'n': 15596, ...
# 2   {'feature_metadata': {'records': {'n': 15596, ...
# 21  {'feature_metadata': {'records': {'n': 15596, ...
# 10  {'feature_metadata': {'records': {'n': 15596, ...
#
#                          summary  \
# 0   {'_wandb': {'runtime': 769}}
# 16  {'_wandb': {'runtime': 760}}
# 19  {'_wandb': {'runtime': 624}}
# 14  {'_wandb': {'runtime': 758}}
# 7   {'_wandb': {'runtime': 776}}
# 9   {'_wandb': {'runtime': 852}}
# 11  {'_wandb': {'runtime': 631}}
# 15  {'_wandb': {'runtime': 800}}
# 6   {'_wandb': {'runtime': 625}}
# 17  {'_wandb': {'runtime': 859}}
# 12  {'_wandb': {'runtime': 611}}
# 4   {'_wandb': {'runtime': 628}}
# 1   {'_wandb': {'runtime': 878}}
# 20  {'_wandb': {'runtime': 595}}
# 18  {'_wandb': {'runtime': 856}}
# 13  {'_wandb': {'runtime': 610}}
# 3   {'_wandb': {'runtime': 771}}
# 8   {'_wandb': {'runtime': 773}}
# 5   {'_wandb': {'runtime': 614}}
# 2   {'_wandb': {'runtime': 857}}
# 21  {'_wandb': {'runtime': 605}}
# 10  {'_wandb': {'runtime': 860}}
#
#                                                  path
# 0   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 16  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 19  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 14  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 7   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 9   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 11  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 15  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 6   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 17  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 12  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 4   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 1   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 20  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 18  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 13  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 3   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 8   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 5   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 2   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 21  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 10  /sc-projects/sc-proj-ukb-cvd/results/models/Re...

# %%
runs_df["path"].iloc[0]
# Out:
# '/sc-projects/sc-proj-ukb-cvd/results/models/RecordGraphs/133al0d6/predictions/predictions.feather'

# %%
runs_df.iloc[0].path
# Out:
# '/sc-projects/sc-proj-ukb-cvd/results/models/RecordGraphs/w0vw9p4h'

# %%
temp = pd.read_feather("/sc-projects/sc-proj-ukb-cvd/results/models/RecordGraphs/133al0d6/predictions/predictions.feather")

# %%
temp
# Out:
#           index  OMOP_4306655  phecode_001  phecode_002  phecode_002-1  \
# 0       4196644     -3.023430     0.392832    -1.079083      -0.989298
# 1       3678640     -1.085831    -0.748256    -1.151758      -1.208433
# 2       3542454     -1.573979    -0.579084    -1.005102      -0.980639
# 3       5230713     -0.571794    -0.806532    -1.498115      -1.509850
# 4       1980056     -4.097597     0.367956    -1.418018      -1.334728
# ...         ...           ...          ...          ...            ...
# 478098  6024953     -3.969854     0.328685    -1.604424      -1.620170
# 478099  6024971     -2.252863     0.224587    -1.239970      -1.234634
# 478100  6025001     -2.186860     0.526358     0.043661       0.151743
# 478101  6025034     -2.526110     0.810040    -0.319046      -0.171159
# 478102  6025165     -3.539971     0.242056    -1.659227      -1.592663
#
#         phecode_003  phecode_004  phecode_004-1  phecode_004-2  phecode_004-3  \
# 0         -0.013465    -0.815178      -0.938865      -1.420820      -1.378703
# 1         -0.503294    -1.148521      -1.725332      -0.890989      -0.978545
# 2         -0.861540    -1.141987      -1.134000      -0.956642      -1.513900
# 3         -0.692266    -0.936145      -1.373790      -1.102478      -1.737673
# 4         -0.822585    -1.098619      -1.467062      -1.040672      -1.879112
# ...             ...          ...            ...            ...            ...
# 478098    -1.325243    -0.874249      -1.048770      -0.839142      -1.610433
# 478099    -0.507474    -0.669180      -0.276952      -1.346914      -1.891803
# 478100    -0.404995    -0.224563      -0.154687      -0.408305      -0.448138
# 478101    -0.586102    -0.395552      -0.290282      -0.984672      -0.901149
# 478102    -0.969535    -0.790459      -0.867105      -1.402604      -1.999897
#
#         ...  phecode_979  phecode_979-2  phecode_979-7  partition  \
# 0       ...    -1.391467      -0.650496      -2.569006          6
# 1       ...    -1.137585      -0.151188      -2.448870          6
# 2       ...    -0.707294       0.477993      -2.035967          6
# 3       ...    -1.303061      -1.371436      -0.755044          6
# 4       ...    -2.286474      -1.505977      -2.592870          6
# ...     ...          ...            ...            ...        ...
# 478098  ...    -1.802008      -1.827339      -0.854436          6
# 478099  ...    -1.200621      -1.811466      -0.652684          6
# 478100  ...     0.161320       0.352546      -1.614432          6
# 478101  ...    -1.167964      -1.304386      -1.515227          6
# 478102  ...    -2.218894      -2.030696      -1.659448          6
#
#                          module  encoder     head  covariate_cols  \
# 0       RecordsIdentityTraining     None  MLPHead              []
# 1       RecordsIdentityTraining     None  MLPHead              []
# 2       RecordsIdentityTraining     None  MLPHead              []
# 3       RecordsIdentityTraining     None  MLPHead              []
# 4       RecordsIdentityTraining     None  MLPHead              []
# ...                         ...      ...      ...             ...
# 478098  RecordsIdentityTraining     None  MLPHead              []
# 478099  RecordsIdentityTraining     None  MLPHead              []
# 478100  RecordsIdentityTraining     None  MLPHead              []
# 478101  RecordsIdentityTraining     None  MLPHead              []
# 478102  RecordsIdentityTraining     None  MLPHead              []
#
#                                               record_cols  split
# 0       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 1       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 2       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 3       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 4       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# ...                                                   ...    ...
# 478098  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 478099  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 478100  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 478101  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 478102  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
#
# [478103 rows x 1891 columns]

# %% [markdown]
# ## Process Predictions

# %%
name_dict = {
    "CovariatesOnlyTraining_['age_at_recruitment_f21022_0_0', 'sex_f31_0_0']_None_MLPHead": "Identity(AgeSex)+MLP",
    "RecordsIdentityTraining_[]_None_MLPHead": "Identity(Records)+MLP",
     "RecordsIdentityTraining_[]_None_LinearHead": "Identity(Records)+Linear",
    "RecordsGraphTraining_[]_HeteroGNN_MLPHead": "GNN(Records)+MLP",
    "RecordsIdentityTraining_['age_at_recruitment_f21022_0_0', 'sex_f31_0_0']_None_MLPHead": "Identity(AgeSex+Records)+MLP",
    "RecordsGraphTraining_['age_at_recruitment_f21022_0_0', 'sex_f31_0_0']_HeteroGNN_MLPHead": "GNN(AgeSex+Records)+MLP"
}

# %%
id_vars = ["eid", "model", "partition", "split"]

# %%
out_path = f"{experiment_path}/loghs_covid"
pathlib.Path(out_path).mkdir(parents=True, exist_ok=True)

# %%
@ray.remote
def prepare_predictions(in_path, out_path):
    
    temp = pd.read_feather(in_path).rename(columns={"index": "eid"}).reset_index(drop=True)
    temp["model"] = (temp.module.astype(str) + "_" + temp.covariate_cols.astype(str) + "_" + temp.encoder.astype(str) + "_" + temp["head"].astype(str)).astype("category")
    temp = temp.replace({"model":name_dict}).drop(columns=["module", "encoder", "head", "covariate_cols", "record_cols"])
    for c in id_vars: temp[c] = temp[c].astype("category")
    
    model = temp.model.unique()[0]
    partition = temp.partition.unique()[0]
    for split in ["train", "valid", "test"]:
        fp_out = f"{out_path}/{model}/{partition}"
        pathlib.Path(fp_out).mkdir(parents=True, exist_ok=True)
        temp.query("split==@split").reset_index(drop=True).to_feather(f"{fp_out}/{split}.feather")

# %%
for p in tqdm(runs_df.path): 
    prepare_predictions.remote(f"{p}/predictions/predictions.feather", out_path)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]

# %%
1+1
