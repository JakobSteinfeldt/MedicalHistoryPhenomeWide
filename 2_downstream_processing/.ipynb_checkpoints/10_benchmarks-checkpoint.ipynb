# %% [markdown]
# # Benchmark Models

# %%
import os
import math
import pathlib
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from IPython.display import clear_output
import ray

import warnings
import lifelines
from lifelines.utils import CensoringType
from lifelines.utils import concordance_index

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

experiment = 230425
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
in_path = f"{experiment_path}/coxph/predictions"
prediction_paths = !ls $in_path
predictions = pd.Series(prediction_paths).str.split("_", expand=True)\
    .assign(path = prediction_paths)\
    .assign(endpoint = lambda x: x[0]+"_"+x[1])\
    .assign(score = lambda x: x[2])\
    .assign(partition = lambda x: x[3].str.replace(".feather", "", regex=True).astype(int))\
    [["endpoint", "score", "partition", "path"]].sort_values(["endpoint", "score", "partition"]).reset_index(drop=True)
predictions
# Out:
#              endpoint                  score  partition  \
# 0        OMOP_4306655                  ASCVD          0
# 1        OMOP_4306655                  ASCVD          1
# 2        OMOP_4306655                  ASCVD          2
# 3        OMOP_4306655                  ASCVD          3
# 4        OMOP_4306655                  ASCVD          4
# ...               ...                    ...        ...
# 621385  phecode_979-7  SCORE2+MedicalHistory         17
# 621386  phecode_979-7  SCORE2+MedicalHistory         18
# 621387  phecode_979-7  SCORE2+MedicalHistory         19
# 621388  phecode_979-7  SCORE2+MedicalHistory         20
# 621389  phecode_979-7  SCORE2+MedicalHistory         21
#
#                                                   path
# 0                         OMOP_4306655_ASCVD_0.feather
# 1                         OMOP_4306655_ASCVD_1.feather
# 2                         OMOP_4306655_ASCVD_2.feather
# 3                         OMOP_4306655_ASCVD_3.feather
# 4                         OMOP_4306655_ASCVD_4.feather
# ...                                                ...
# 621385  phecode_979-7_SCORE2+MedicalHistory_17.feather
# 621386  phecode_979-7_SCORE2+MedicalHistory_18.feather
# 621387  phecode_979-7_SCORE2+MedicalHistory_19.feather
# 621388  phecode_979-7_SCORE2+MedicalHistory_20.feather
# 621389  phecode_979-7_SCORE2+MedicalHistory_21.feather
#
# [621390 rows x 4 columns]

# %%
predictions.score.unique()
# Out:
# array(['ASCVD', 'ASCVD+MedicalHistory', 'Age+Sex',
#        'Age+Sex+Comorbidities', 'Age+Sex+Comorbidities+MedicalHistory',
#        'Age+Sex+Comorbidities+MedicalHistoryLM', 'Age+Sex+MedicalHistory',
#        'Age+Sex+MedicalHistoryLM', 'Comorbidities', 'MedicalHistory',
#        'MedicalHistoryLM', 'QRISK3', 'QRISK3+MedicalHistory', 'SCORE2',
#        'SCORE2+MedicalHistory'], dtype=object)

# %%
predictions.to_feather(f"{experiment_path}/prediction_paths.feather")

# %% [markdown]
# ## Submit Benchmark jobs

# %%
# %%
import datetime
import itertools
import os
import pathlib
import re
import subprocess

import pandas as pd
from omegaconf import OmegaConf
from tqdm.auto import tqdm

# %% codecell
USER = "steinfej"
BASE = pathlib.Path(f"/home/{USER}/code/")

EXPERIMENT_NAME = "22_medhistory"  # name under which to store the generated .sh scripts and yamls
TEMPLATE_CONFIG = f"{BASE}/config/"  # template yaml to use
TRAIN_SCRIPT = f"{BASE}/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py"
ACTIVATE_ENV_CMD = """mamba activate ehrgraphs"""

TAG = 230425
JOBNAME = "benchmarks"

# %%
TRAIN_SCRIPT
# Out:
# '/home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py'

# %%
os.makedirs(f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_submissions", exist_ok=True)
os.makedirs(f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_configs", exist_ok=True)
os.makedirs(f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_outputs", exist_ok=True)

# %%
def make_job_script(user, job_name, iteration):

    job_script_str = (
        f"""#!/bin/bash

#SBATCH --job-name={job_name}  # Specify job name
#SBATCH --nodes=1              # Specify number of nodes
#SBATCH --mem=485G              # Specify number of nodes
#SBATCH --time=1:00:00        # Set a limit on the total run time
#SBATCH --tasks-per-node=1
#SBATCH --exclusive

{ACTIVATE_ENV_CMD}

ray start --head --port=6378 --num-cpus 32
python {TRAIN_SCRIPT} --iteration {iteration}"""
            )

    return job_script_str

# %%
def submit(path, job_name, job_script, time_stamp=None):
    if not time_stamp:
        time_stamp = datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

    script_path_long = f"{path}/{job_name}_{time_stamp}.sh"

    with open(script_path_long, "w") as outfile:
        outfile.write(job_script)
    script_path = f"{path}/{job_name}.sh"
    try:
        os.unlink(script_path)
    except FileNotFoundError:  # because we cannot overwrite symlinks directly
        pass
    os.symlink(os.path.realpath(script_path_long), script_path)

    output_path = f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_outputs/{job_name}"

    print(job_script)
    print("\n\nSubmission:\n===========\n")
    sub_cmd = (
        f"sbatch --error={output_path}_%j_stderr.out --output={output_path}_%j_stdout.out <"
        f" {script_path}"
    )
    print(sub_cmd)

    ret = subprocess.run(sub_cmd, shell=True, cwd=os.getcwd(), capture_output=True)
    print(ret.stdout.decode())

# %%
iterations = [i for i in range(1, 100)]

# %%
import time

jobids = []
for iteration in iterations:
    
    job_name = f"{iteration}_{JOBNAME}"

    job_script = make_job_script(user=USER, job_name=job_name, iteration=iteration)

    jobid = submit(
        path=f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_submissions",
        job_name=job_name,
        job_script=job_script,
    )

    jobids.append(jobid)

print(jobids)
# Out:
# #!/bin/bash
#
# #SBATCH --job-name=1_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 1
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/1_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/1_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/1_benchmarks.sh
# Submitted batch job 948344
#
# #!/bin/bash
#
# #SBATCH --job-name=2_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 2
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/2_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/2_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/2_benchmarks.sh
# Submitted batch job 948345
#
# #!/bin/bash
#
# #SBATCH --job-name=3_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 3
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/3_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/3_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/3_benchmarks.sh
# Submitted batch job 948346
#
# #!/bin/bash
#
# #SBATCH --job-name=4_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 4
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/4_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/4_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/4_benchmarks.sh
# Submitted batch job 948347
#
# #!/bin/bash
#
# #SBATCH --job-name=5_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 5
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/5_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/5_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/5_benchmarks.sh
# Submitted batch job 948348
#
# #!/bin/bash
#
# #SBATCH --job-name=6_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 6
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/6_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/6_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/6_benchmarks.sh
# Submitted batch job 948349
#
# #!/bin/bash
#
# #SBATCH --job-name=7_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 7
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/7_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/7_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/7_benchmarks.sh
# Submitted batch job 948350
#
# #!/bin/bash
#
# #SBATCH --job-name=8_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 8
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/8_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/8_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/8_benchmarks.sh
# Submitted batch job 948351
#
# #!/bin/bash
#
# #SBATCH --job-name=9_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 9
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/9_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/9_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/9_benchmarks.sh
# Submitted batch job 948352
#
# #!/bin/bash
#
# #SBATCH --job-name=10_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 10
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/10_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/10_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/10_benchmarks.sh
# Submitted batch job 948353
#
# #!/bin/bash
#
# #SBATCH --job-name=11_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 11
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/11_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/11_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/11_benchmarks.sh
# Submitted batch job 948354
#
# #!/bin/bash
#
# #SBATCH --job-name=12_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 12
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/12_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/12_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/12_benchmarks.sh
# Submitted batch job 948355
#
# #!/bin/bash
#
# #SBATCH --job-name=13_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 13
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/13_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/13_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/13_benchmarks.sh
# Submitted batch job 948356
#
# #!/bin/bash
#
# #SBATCH --job-name=14_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 14
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/14_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/14_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/14_benchmarks.sh
# Submitted batch job 948357
#
# #!/bin/bash
#
# #SBATCH --job-name=15_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 15
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/15_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/15_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/15_benchmarks.sh
# Submitted batch job 948358
#
# #!/bin/bash
#
# #SBATCH --job-name=16_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 16
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/16_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/16_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/16_benchmarks.sh
# Submitted batch job 948359
#
# #!/bin/bash
#
# #SBATCH --job-name=17_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 17
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/17_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/17_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/17_benchmarks.sh
# Submitted batch job 948360
#
# #!/bin/bash
#
# #SBATCH --job-name=18_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 18
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/18_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/18_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/18_benchmarks.sh
# Submitted batch job 948361
#
# #!/bin/bash
#
# #SBATCH --job-name=19_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 19
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/19_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/19_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/19_benchmarks.sh
# Submitted batch job 948362
#
# #!/bin/bash
#
# #SBATCH --job-name=20_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 20
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/20_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/20_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/20_benchmarks.sh
# Submitted batch job 948363
#
# #!/bin/bash
#
# #SBATCH --job-name=21_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 21
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/21_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/21_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/21_benchmarks.sh
# Submitted batch job 948364
#
# #!/bin/bash
#
# #SBATCH --job-name=22_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 22
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/22_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/22_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/22_benchmarks.sh
# Submitted batch job 948365
#
# #!/bin/bash
#
# #SBATCH --job-name=23_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 23
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/23_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/23_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/23_benchmarks.sh
# Submitted batch job 948366
#
# #!/bin/bash
#
# #SBATCH --job-name=24_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 24
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/24_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/24_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/24_benchmarks.sh
# Submitted batch job 948367
#
# #!/bin/bash
#
# #SBATCH --job-name=25_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 25
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/25_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/25_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/25_benchmarks.sh
# Submitted batch job 948368
#
# #!/bin/bash
#
# #SBATCH --job-name=26_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 26
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/26_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/26_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/26_benchmarks.sh
# Submitted batch job 948369
#
# #!/bin/bash
#
# #SBATCH --job-name=27_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 27
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/27_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/27_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/27_benchmarks.sh
# Submitted batch job 948370
#
# #!/bin/bash
#
# #SBATCH --job-name=28_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 28
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/28_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/28_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/28_benchmarks.sh
# Submitted batch job 948371
#
# #!/bin/bash
#
# #SBATCH --job-name=29_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 29
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/29_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/29_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/29_benchmarks.sh
# Submitted batch job 948372
#
# #!/bin/bash
#
# #SBATCH --job-name=30_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 30
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/30_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/30_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/30_benchmarks.sh
# Submitted batch job 948373
#
# #!/bin/bash
#
# #SBATCH --job-name=31_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 31
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/31_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/31_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/31_benchmarks.sh
# Submitted batch job 948374
#
# #!/bin/bash
#
# #SBATCH --job-name=32_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 32
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/32_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/32_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/32_benchmarks.sh
# Submitted batch job 948375
#
# #!/bin/bash
#
# #SBATCH --job-name=33_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 33
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/33_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/33_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/33_benchmarks.sh
# Submitted batch job 948376
#
# #!/bin/bash
#
# #SBATCH --job-name=34_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 34
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/34_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/34_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/34_benchmarks.sh
# Submitted batch job 948377
#
# #!/bin/bash
#
# #SBATCH --job-name=35_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 35
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/35_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/35_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/35_benchmarks.sh
# Submitted batch job 948378
#
# #!/bin/bash
#
# #SBATCH --job-name=36_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 36
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/36_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/36_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/36_benchmarks.sh
# Submitted batch job 948379
#
# #!/bin/bash
#
# #SBATCH --job-name=37_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 37
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/37_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/37_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/37_benchmarks.sh
# Submitted batch job 948380
#
# #!/bin/bash
#
# #SBATCH --job-name=38_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 38
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/38_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/38_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/38_benchmarks.sh
# Submitted batch job 948381
#
# #!/bin/bash
#
# #SBATCH --job-name=39_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 39
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/39_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/39_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/39_benchmarks.sh
# Submitted batch job 948382
#
# #!/bin/bash
#
# #SBATCH --job-name=40_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 40
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/40_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/40_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/40_benchmarks.sh
# Submitted batch job 948383
#
# #!/bin/bash
#
# #SBATCH --job-name=41_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 41
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/41_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/41_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/41_benchmarks.sh
# Submitted batch job 948384
#
# #!/bin/bash
#
# #SBATCH --job-name=42_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 42
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/42_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/42_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/42_benchmarks.sh
# Submitted batch job 948385
#
# #!/bin/bash
#
# #SBATCH --job-name=43_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 43
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/43_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/43_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/43_benchmarks.sh
# Submitted batch job 948386
#
# #!/bin/bash
#
# #SBATCH --job-name=44_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 44
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/44_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/44_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/44_benchmarks.sh
# Submitted batch job 948387
#
# #!/bin/bash
#
# #SBATCH --job-name=45_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 45
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/45_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/45_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/45_benchmarks.sh
# Submitted batch job 948388
#
# #!/bin/bash
#
# #SBATCH --job-name=46_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 46
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/46_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/46_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/46_benchmarks.sh
# Submitted batch job 948389
#
# #!/bin/bash
#
# #SBATCH --job-name=47_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 47
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/47_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/47_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/47_benchmarks.sh
# Submitted batch job 948390
#
# #!/bin/bash
#
# #SBATCH --job-name=48_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 48
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/48_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/48_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/48_benchmarks.sh
# Submitted batch job 948391
#
# #!/bin/bash
#
# #SBATCH --job-name=49_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 49
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/49_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/49_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/49_benchmarks.sh
# Submitted batch job 948392
#
# #!/bin/bash
#
# #SBATCH --job-name=50_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 50
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/50_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/50_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/50_benchmarks.sh
# Submitted batch job 948393
#
# #!/bin/bash
#
# #SBATCH --job-name=51_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 51
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/51_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/51_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/51_benchmarks.sh
# Submitted batch job 948394
#
# #!/bin/bash
#
# #SBATCH --job-name=52_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 52
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/52_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/52_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/52_benchmarks.sh
# Submitted batch job 948395
#
# #!/bin/bash
#
# #SBATCH --job-name=53_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 53
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/53_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/53_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/53_benchmarks.sh
# Submitted batch job 948396
#
# #!/bin/bash
#
# #SBATCH --job-name=54_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 54
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/54_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/54_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/54_benchmarks.sh
# Submitted batch job 948397
#
# #!/bin/bash
#
# #SBATCH --job-name=55_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 55
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/55_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/55_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/55_benchmarks.sh
# Submitted batch job 948398
#
# #!/bin/bash
#
# #SBATCH --job-name=56_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 56
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/56_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/56_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/56_benchmarks.sh
# Submitted batch job 948399
#
# #!/bin/bash
#
# #SBATCH --job-name=57_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 57
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/57_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/57_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/57_benchmarks.sh
# Submitted batch job 948400
#
# #!/bin/bash
#
# #SBATCH --job-name=58_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 58
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/58_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/58_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/58_benchmarks.sh
# Submitted batch job 948401
#
# #!/bin/bash
#
# #SBATCH --job-name=59_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 59
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/59_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/59_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/59_benchmarks.sh
# Submitted batch job 948402
#
# #!/bin/bash
#
# #SBATCH --job-name=60_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 60
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/60_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/60_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/60_benchmarks.sh
# Submitted batch job 948403
#
# #!/bin/bash
#
# #SBATCH --job-name=61_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 61
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/61_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/61_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/61_benchmarks.sh
# Submitted batch job 948404
#
# #!/bin/bash
#
# #SBATCH --job-name=62_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 62
#
#
# Submission:
# ===========
#
# ...
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 80
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/80_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/80_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/80_benchmarks.sh
# Submitted batch job 948423
#
# #!/bin/bash
#
# #SBATCH --job-name=81_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 81
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/81_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/81_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/81_benchmarks.sh
# Submitted batch job 948424
#
# #!/bin/bash
#
# #SBATCH --job-name=82_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 82
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/82_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/82_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/82_benchmarks.sh
# Submitted batch job 948425
#
# #!/bin/bash
#
# #SBATCH --job-name=83_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 83
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/83_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/83_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/83_benchmarks.sh
# Submitted batch job 948426
#
# #!/bin/bash
#
# #SBATCH --job-name=84_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 84
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/84_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/84_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/84_benchmarks.sh
# Submitted batch job 948427
#
# #!/bin/bash
#
# #SBATCH --job-name=85_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 85
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/85_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/85_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/85_benchmarks.sh
# Submitted batch job 948428
#
# #!/bin/bash
#
# #SBATCH --job-name=86_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 86
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/86_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/86_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/86_benchmarks.sh
# Submitted batch job 948429
#
# #!/bin/bash
#
# #SBATCH --job-name=87_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 87
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/87_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/87_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/87_benchmarks.sh
# Submitted batch job 948430
#
# #!/bin/bash
#
# #SBATCH --job-name=88_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 88
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/88_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/88_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/88_benchmarks.sh
# Submitted batch job 948431
#
# #!/bin/bash
#
# #SBATCH --job-name=89_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 89
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/89_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/89_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/89_benchmarks.sh
# Submitted batch job 948432
#
# #!/bin/bash
#
# #SBATCH --job-name=90_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 90
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/90_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/90_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/90_benchmarks.sh
# Submitted batch job 948433
#
# #!/bin/bash
#
# #SBATCH --job-name=91_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 91
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/91_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/91_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/91_benchmarks.sh
# Submitted batch job 948434
#
# #!/bin/bash
#
# #SBATCH --job-name=92_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 92
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/92_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/92_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/92_benchmarks.sh
# Submitted batch job 948435
#
# #!/bin/bash
#
# #SBATCH --job-name=93_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 93
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/93_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/93_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/93_benchmarks.sh
# Submitted batch job 948436
#
# #!/bin/bash
#
# #SBATCH --job-name=94_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 94
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/94_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/94_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/94_benchmarks.sh
# Submitted batch job 948437
#
# #!/bin/bash
#
# #SBATCH --job-name=95_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 95
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/95_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/95_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/95_benchmarks.sh
# Submitted batch job 948438
#
# #!/bin/bash
#
# #SBATCH --job-name=96_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 96
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/96_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/96_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/96_benchmarks.sh
# Submitted batch job 948439
#
# #!/bin/bash
#
# #SBATCH --job-name=97_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 97
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/97_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/97_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/97_benchmarks.sh
# Submitted batch job 948440
#
# #!/bin/bash
#
# #SBATCH --job-name=98_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 98
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/98_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/98_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/98_benchmarks.sh
# Submitted batch job 948441
#
# #!/bin/bash
#
# #SBATCH --job-name=99_benchmarks  # Specify job name
# #SBATCH --nodes=1              # Specify number of nodes
# #SBATCH --mem=485G              # Specify number of nodes
# #SBATCH --time=1:00:00        # Set a limit on the total run time
# #SBATCH --tasks-per-node=1
# #SBATCH --exclusive
#
# mamba activate ehrgraphs
#
# ray start --head --port=6378 --num-cpus 32
# python /home/steinfej/code/MedicalHistoryPhenomeWide/2_downstream_processing/10_benchmarks_iteration.py --iteration 99
#
#
# Submission:
# ===========
#
# sbatch --error=/home/steinfej/tmp/22_medhistory/job_outputs/99_benchmarks_%j_stderr.out --output=/home/steinfej/tmp/22_medhistory/job_outputs/99_benchmarks_%j_stdout.out < /home/steinfej/tmp/22_medhistory/job_submissions/99_benchmarks.sh
# Submitted batch job 948442
#
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ## Check progress

# %%
from pathlib import Path
benchmark_paths = paths = list(Path("/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/230425/benchmarks/").rglob('*.feather'))

benchmarks_df = pd.concat([pd.read_feather(p) for p in benchmark_paths], axis=0)

benchmarks_df.value_counts(["iteration"]).to_frame().sort_values("iteration")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       1 from pathlib import Path
#       2 benchmark_paths = paths = list(Path("/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/230425/benchmarks/").rglob('*.feather'))
# ----> 4 benchmarks_df = pd.concat([pd.read_feather(p) for p in benchmark_paths], axis=0)
#       6 benchmarks_df.value_counts(["iteration"]).to_frame().sort_values("iteration")
#
# File ~/miniconda3/envs/udm/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/udm/lib/python3.10/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~/miniconda3/envs/udm/lib/python3.10/site-packages/pandas/core/reshape/concat.py:425, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     422     objs = list(objs)
#     424 if len(objs) == 0:
# --> 425     raise ValueError("No objects to concatenate")
#     427 if keys is None:
#     428     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %%
benchmarks_df.reset_index(drop=True).to_feather(f"{experiment_path}/benchmarks_cindex_230425.feather")

# %%
benchmarks_df.groupby(["score"]).mean("cindex").sort_values("cindex")

# %%
benchmarks_df.groupby(["score"]).mean("cindex").sort_values("cindex")
