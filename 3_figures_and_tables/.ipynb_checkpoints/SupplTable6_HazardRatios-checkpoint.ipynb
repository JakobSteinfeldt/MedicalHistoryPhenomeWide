# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
#library(Rmisc)
library(dtplyr)
library(tidyverse)
library(glue)
library(arrow)
library(patchwork)
library(data.table)
library("jsonlite")
library(ggthemes)
# Out:
# Warning message:
# “package ‘dtplyr’ was built under R version 4.0.5”
# Warning message:
# “package ‘tidyverse’ was built under R version 4.0.5”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.5”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.5”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.5”
# Warning message:
# “package ‘readr’ was built under R version 4.0.5”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.5”
# Warning message:
# “package ‘forcats’ was built under R version 4.0.5”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Warning message:
# “package ‘glue’ was built under R version 4.0.5”
# Warning message:
# “package ‘arrow’ was built under R version 4.0.3”
#
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# Warning message:
# “package ‘data.table’ was built under R version 4.0.5”
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Warning message:
# “package ‘jsonlite’ was built under R version 4.0.5”
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
#
# Warning message:
# “package ‘ggthemes’ was built under R version 4.0.3”

# %%
if (grepl("sc", Sys.info()[["nodename"]], fixed=TRUE)) {
    base_path = "/sc-projects/sc-proj-ukb-cvd"
} else {
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"}
print(base_path)

project_label="22_medical_records"
project_path = glue("{base_path}/results/projects/{project_label}")
figure_path = glue("{project_path}/figures")
output_path = glue("{project_path}/data")

experiment = 230425
experiment_path = glue("{output_path}/{experiment}")
# Out:
# [1] "/sc-projects/sc-proj-ukb-cvd"

# %%
base_size = 8
title_size = 10
facet_size = 10
geom_text_size=3
theme_set(theme_classic(base_size = base_size) + 
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0), 
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major=element_line()))

# %%
colors_dict = read_json("colors.json")
color_map <- c(
    "Identity(AgeSex)+MLP" = colors_dict$pastel$red$mid,
    "Identity(Records)+MLP" = colors_dict$pastel$red$mid,
    "GNN(Records)+MLP" = colors_dict$pastel$red$mid,
    "Identity(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid,
    "GNN(AgeSex+Records)+MLP" = colors_dict$pastel$red$mid
)

# %%
endpoint_defs = arrow::read_feather(glue("{output_path}/phecode_defs_220306.feather")) %>% arrange(endpoint)

# %%
endpoint_map = endpoint_defs$phecode_string
names(endpoint_map) =  endpoint_defs$endpoint
#endpoint_order_freq = (outcome_freq %>% arrange(desc(freq)))$endpoint

# %%
endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint

# %%
endpoint_selection = c(
'phecode_164',
'phecode_179',
'phecode_202-2',
'phecode_284',
'phecode_401',
'phecode_404-1',
'phecode_413-21',
'phecode_413-32',
'phecode_416-21',
'phecode_420',
'phecode_424',
'phecode_431-1',
'phecode_438-6',
'phecode_440-3',
'phecode_444-13',
'phecode_448',
'phecode_468',
'phecode_474',
'phecode_542-4',
'phecode_583',
'phecode_665-1',
'phecode_705-1',
'phecode_718',
'OMOP_4306655'
    )

# %% [markdown]
# ## Load data

# %% [markdown]
# # Load Benchmarks

# %%
name = "hrs_endpoints"
hrs_endpoints = arrow::read_feather(glue("{experiment_path}/{name}.feather"), col_select=c("endpoint", "score", "partition", "hrs_mh", "hrs_mh_age", "hrs_mh_sex")) %>% left_join(endpoint_defs)
# Out:
# Joining, by = "endpoint"

# %%
hrs_endpoints
# Out:
#        endpoint      score                                partition hrs_mh
# 1      OMOP_4306655  ASCVD+MedicalHistory                 0         2.630058
# 2      OMOP_4306655  ASCVD+MedicalHistory                 1         2.627838
# 3      OMOP_4306655  ASCVD+MedicalHistory                 2         2.706116
# 4      OMOP_4306655  ASCVD+MedicalHistory                 3         2.700938
# 5      OMOP_4306655  ASCVD+MedicalHistory                 4         2.612606
# 6      OMOP_4306655  ASCVD+MedicalHistory                 5         2.625049
# 7      OMOP_4306655  ASCVD+MedicalHistory                 6         2.724130
# 8      OMOP_4306655  ASCVD+MedicalHistory                 7         2.781958
# 9      OMOP_4306655  ASCVD+MedicalHistory                 8         2.702470
# 10     OMOP_4306655  ASCVD+MedicalHistory                 9         2.767540
# 11     OMOP_4306655  ASCVD+MedicalHistory                 10        2.683536
# 12     OMOP_4306655  ASCVD+MedicalHistory                 11        2.741360
# 13     OMOP_4306655  ASCVD+MedicalHistory                 12        2.729932
# 14     OMOP_4306655  ASCVD+MedicalHistory                 13        2.671174
# 15     OMOP_4306655  ASCVD+MedicalHistory                 14        2.760730
# 16     OMOP_4306655  ASCVD+MedicalHistory                 15        2.681578
# 17     OMOP_4306655  ASCVD+MedicalHistory                 16        2.610182
# 18     OMOP_4306655  ASCVD+MedicalHistory                 17        2.664844
# 19     OMOP_4306655  ASCVD+MedicalHistory                 18        2.593229
# 20     OMOP_4306655  ASCVD+MedicalHistory                 19        2.637880
# 21     OMOP_4306655  ASCVD+MedicalHistory                 20        2.647081
# 22     OMOP_4306655  ASCVD+MedicalHistory                 21        2.681810
# 23     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 0         2.724409
# 24     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 1         2.738987
# 25     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2         2.778256
# 26     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 3         2.779690
# 27     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 4         2.711358
# 28     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 5         2.727607
# 29     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 6         2.837157
# 30     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 7         2.888678
# ⋮      ⋮             ⋮                                    ⋮         ⋮
# 372805 phecode_979-7 QRISK3+MedicalHistory                14        2.9804688
# 372806 phecode_979-7 QRISK3+MedicalHistory                15        2.8071655
# 372807 phecode_979-7 QRISK3+MedicalHistory                16        0.7632269
# 372808 phecode_979-7 QRISK3+MedicalHistory                17        2.6669510
# 372809 phecode_979-7 QRISK3+MedicalHistory                18        2.7988693
# 372810 phecode_979-7 QRISK3+MedicalHistory                19        2.8312608
# 372811 phecode_979-7 QRISK3+MedicalHistory                20        0.6462974
# 372812 phecode_979-7 QRISK3+MedicalHistory                21        2.8311480
# 372813 phecode_979-7 SCORE2+MedicalHistory                0         2.9936383
# 372814 phecode_979-7 SCORE2+MedicalHistory                1         2.6617123
# 372815 phecode_979-7 SCORE2+MedicalHistory                2         2.6723927
# 372816 phecode_979-7 SCORE2+MedicalHistory                3         2.7058651
# 372817 phecode_979-7 SCORE2+MedicalHistory                4         2.8216346
# 372818 phecode_979-7 SCORE2+MedicalHistory                5         2.8026950
# 372819 phecode_979-7 SCORE2+MedicalHistory                6         2.8676102
# 372820 phecode_979-7 SCORE2+MedicalHistory                7         2.7237674
# 372821 phecode_979-7 SCORE2+MedicalHistory                8         2.7459159
# 372822 phecode_979-7 SCORE2+MedicalHistory                9         2.8424895
# 372823 phecode_979-7 SCORE2+MedicalHistory                10        2.8860117
# 372824 phecode_979-7 SCORE2+MedicalHistory                11        2.8621457
# 372825 phecode_979-7 SCORE2+MedicalHistory                12        2.8651821
# 372826 phecode_979-7 SCORE2+MedicalHistory                13        2.8463502
# 372827 phecode_979-7 SCORE2+MedicalHistory                14        2.9463669
# 372828 phecode_979-7 SCORE2+MedicalHistory                15        2.7780201
# 372829 phecode_979-7 SCORE2+MedicalHistory                16        2.8520975
# 372830 phecode_979-7 SCORE2+MedicalHistory                17        2.6400810
# 372831 phecode_979-7 SCORE2+MedicalHistory                18        2.7465903
# 372832 phecode_979-7 SCORE2+MedicalHistory                19        2.8113601
# 372833 phecode_979-7 SCORE2+MedicalHistory                20        2.7303478
# 372834 phecode_979-7 SCORE2+MedicalHistory                21        2.8062345
#        hrs_mh_age hrs_mh_sex phecode phecode_string         phecode_category
# 1      NA         NA         4306655 All-Cause Death        Death
# 2      NA         NA         4306655 All-Cause Death        Death
# 3      NA         NA         4306655 All-Cause Death        Death
# 4      NA         NA         4306655 All-Cause Death        Death
# 5      NA         NA         4306655 All-Cause Death        Death
# 6      NA         NA         4306655 All-Cause Death        Death
# 7      NA         NA         4306655 All-Cause Death        Death
# 8      NA         NA         4306655 All-Cause Death        Death
# 9      NA         NA         4306655 All-Cause Death        Death
# 10     NA         NA         4306655 All-Cause Death        Death
# 11     NA         NA         4306655 All-Cause Death        Death
# 12     NA         NA         4306655 All-Cause Death        Death
# 13     NA         NA         4306655 All-Cause Death        Death
# 14     NA         NA         4306655 All-Cause Death        Death
# 15     NA         NA         4306655 All-Cause Death        Death
# 16     NA         NA         4306655 All-Cause Death        Death
# 17     NA         NA         4306655 All-Cause Death        Death
# 18     NA         NA         4306655 All-Cause Death        Death
# 19     NA         NA         4306655 All-Cause Death        Death
# 20     NA         NA         4306655 All-Cause Death        Death
# 21     NA         NA         4306655 All-Cause Death        Death
# 22     NA         NA         4306655 All-Cause Death        Death
# 23     NA         NA         4306655 All-Cause Death        Death
# 24     NA         NA         4306655 All-Cause Death        Death
# 25     NA         NA         4306655 All-Cause Death        Death
# 26     NA         NA         4306655 All-Cause Death        Death
# 27     NA         NA         4306655 All-Cause Death        Death
# 28     NA         NA         4306655 All-Cause Death        Death
# 29     NA         NA         4306655 All-Cause Death        Death
# 30     NA         NA         4306655 All-Cause Death        Death
# ⋮      ⋮          ⋮          ⋮       ⋮                      ⋮
# 372805 NA         NA         979.7   Bone marrow transplant Stat
# 372806 NA         NA         979.7   Bone marrow transplant Stat
# 372807 NA         NA         979.7   Bone marrow transplant Stat
# 372808 NA         NA         979.7   Bone marrow transplant Stat
# 372809 NA         NA         979.7   Bone marrow transplant Stat
# 372810 NA         NA         979.7   Bone marrow transplant Stat
# 372811 NA         NA         979.7   Bone marrow transplant Stat
# 372812 NA         NA         979.7   Bone marrow transplant Stat
# 372813 NA         NA         979.7   Bone marrow transplant Stat
# 372814 NA         NA         979.7   Bone marrow transplant Stat
# 372815 NA         NA         979.7   Bone marrow transplant Stat
# 372816 NA         NA         979.7   Bone marrow transplant Stat
# 372817 NA         NA         979.7   Bone marrow transplant Stat
# 372818 NA         NA         979.7   Bone marrow transplant Stat
# 372819 NA         NA         979.7   Bone marrow transplant Stat
# 372820 NA         NA         979.7   Bone marrow transplant Stat
# 372821 NA         NA         979.7   Bone marrow transplant Stat
# 372822 NA         NA         979.7   Bone marrow transplant Stat
# 372823 NA         NA         979.7   Bone marrow transplant Stat
# 372824 NA         NA         979.7   Bone marrow transplant Stat
# 372825 NA         NA         979.7   Bone marrow transplant Stat
# 372826 NA         NA         979.7   Bone marrow transplant Stat
# 372827 NA         NA         979.7   Bone marrow transplant Stat
# 372828 NA         NA         979.7   Bone marrow transplant Stat
# 372829 NA         NA         979.7   Bone marrow transplant Stat
# 372830 NA         NA         979.7   Bone marrow transplant Stat
# 372831 NA         NA         979.7   Bone marrow transplant Stat
# 372832 NA         NA         979.7   Bone marrow transplant Stat
# 372833 NA         NA         979.7   Bone marrow transplant Stat
# 372834 NA         NA         979.7   Bone marrow transplant Stat
#        sex  ICD10_only phecode_top leaf
# 1      Both NA         NA          NA
# 2      Both NA         NA          NA
# 3      Both NA         NA          NA
# 4      Both NA         NA          NA
# 5      Both NA         NA          NA
# 6      Both NA         NA          NA
# 7      Both NA         NA          NA
# 8      Both NA         NA          NA
# 9      Both NA         NA          NA
# 10     Both NA         NA          NA
# 11     Both NA         NA          NA
# 12     Both NA         NA          NA
# 13     Both NA         NA          NA
# 14     Both NA         NA          NA
# 15     Both NA         NA          NA
# 16     Both NA         NA          NA
# 17     Both NA         NA          NA
# 18     Both NA         NA          NA
# 19     Both NA         NA          NA
# 20     Both NA         NA          NA
# 21     Both NA         NA          NA
# 22     Both NA         NA          NA
# 23     Both NA         NA          NA
# 24     Both NA         NA          NA
# 25     Both NA         NA          NA
# 26     Both NA         NA          NA
# 27     Both NA         NA          NA
# 28     Both NA         NA          NA
# 29     Both NA         NA          NA
# 30     Both NA         NA          NA
# ⋮      ⋮    ⋮          ⋮           ⋮
# 372805 Both 0          979         1
# 372806 Both 0          979         1
# 372807 Both 0          979         1
# 372808 Both 0          979         1
# 372809 Both 0          979         1
# 372810 Both 0          979         1
# 372811 Both 0          979         1
# 372812 Both 0          979         1
# 372813 Both 0          979         1
# 372814 Both 0          979         1
# 372815 Both 0          979         1
# 372816 Both 0          979         1
# 372817 Both 0          979         1
# 372818 Both 0          979         1
# 372819 Both 0          979         1
# 372820 Both 0          979         1
# 372821 Both 0          979         1
# 372822 Both 0          979         1
# 372823 Both 0          979         1
# 372824 Both 0          979         1
# 372825 Both 0          979         1
# 372826 Both 0          979         1
# 372827 Both 0          979         1
# 372828 Both 0          979         1
# 372829 Both 0          979         1
# 372830 Both 0          979         1
# 372831 Both 0          979         1
# 372832 Both 0          979         1
# 372833 Both 0          979         1
# 372834 Both 0          979         1

# %% [raw]
# hrs_endpoints %>% filter(score %in% c("Age+Sex+MedicalHistory", "MedicalHistory")) %>% group_by(endpoint) %>% tally()# %>% arrange(n)

# %%
hrs = hrs_endpoints %>% 
    group_by(endpoint, score, phecode_string, phecode_category) %>% 
    #filter(score %in% c("MedicalHistory", "Age+Sex+MedicalHistory", "Age+Sex+MedicalHistory+I(Age*MH)")) %>%
    #mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    #mutate(phecode_category = factor(phecode_category, levels=pcats_sorted)) %>%
    select(endpoint, score, hrs_mh, hrs_mh_age, hrs_mh_sex, phecode_string, phecode_category) %>%
    ungroup()
hrs
# Out:
#        endpoint      score                                hrs_mh    hrs_mh_age
# 1      OMOP_4306655  ASCVD+MedicalHistory                 2.630058  NA
# 2      OMOP_4306655  ASCVD+MedicalHistory                 2.627838  NA
# 3      OMOP_4306655  ASCVD+MedicalHistory                 2.706116  NA
# 4      OMOP_4306655  ASCVD+MedicalHistory                 2.700938  NA
# 5      OMOP_4306655  ASCVD+MedicalHistory                 2.612606  NA
# 6      OMOP_4306655  ASCVD+MedicalHistory                 2.625049  NA
# 7      OMOP_4306655  ASCVD+MedicalHistory                 2.724130  NA
# 8      OMOP_4306655  ASCVD+MedicalHistory                 2.781958  NA
# 9      OMOP_4306655  ASCVD+MedicalHistory                 2.702470  NA
# 10     OMOP_4306655  ASCVD+MedicalHistory                 2.767540  NA
# 11     OMOP_4306655  ASCVD+MedicalHistory                 2.683536  NA
# 12     OMOP_4306655  ASCVD+MedicalHistory                 2.741360  NA
# 13     OMOP_4306655  ASCVD+MedicalHistory                 2.729932  NA
# 14     OMOP_4306655  ASCVD+MedicalHistory                 2.671174  NA
# 15     OMOP_4306655  ASCVD+MedicalHistory                 2.760730  NA
# 16     OMOP_4306655  ASCVD+MedicalHistory                 2.681578  NA
# 17     OMOP_4306655  ASCVD+MedicalHistory                 2.610182  NA
# 18     OMOP_4306655  ASCVD+MedicalHistory                 2.664844  NA
# 19     OMOP_4306655  ASCVD+MedicalHistory                 2.593229  NA
# 20     OMOP_4306655  ASCVD+MedicalHistory                 2.637880  NA
# 21     OMOP_4306655  ASCVD+MedicalHistory                 2.647081  NA
# 22     OMOP_4306655  ASCVD+MedicalHistory                 2.681810  NA
# 23     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.724409  NA
# 24     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.738987  NA
# 25     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.778256  NA
# 26     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.779690  NA
# 27     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.711358  NA
# 28     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.727607  NA
# 29     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.837157  NA
# 30     OMOP_4306655  Age+Sex+Comorbidities+MedicalHistory 2.888678  NA
# ⋮      ⋮             ⋮                                    ⋮         ⋮
# 372805 phecode_979-7 QRISK3+MedicalHistory                2.9804688 NA
# 372806 phecode_979-7 QRISK3+MedicalHistory                2.8071655 NA
# 372807 phecode_979-7 QRISK3+MedicalHistory                0.7632269 NA
# 372808 phecode_979-7 QRISK3+MedicalHistory                2.6669510 NA
# 372809 phecode_979-7 QRISK3+MedicalHistory                2.7988693 NA
# 372810 phecode_979-7 QRISK3+MedicalHistory                2.8312608 NA
# 372811 phecode_979-7 QRISK3+MedicalHistory                0.6462974 NA
# 372812 phecode_979-7 QRISK3+MedicalHistory                2.8311480 NA
# 372813 phecode_979-7 SCORE2+MedicalHistory                2.9936383 NA
# 372814 phecode_979-7 SCORE2+MedicalHistory                2.6617123 NA
# 372815 phecode_979-7 SCORE2+MedicalHistory                2.6723927 NA
# 372816 phecode_979-7 SCORE2+MedicalHistory                2.7058651 NA
# 372817 phecode_979-7 SCORE2+MedicalHistory                2.8216346 NA
# 372818 phecode_979-7 SCORE2+MedicalHistory                2.8026950 NA
# 372819 phecode_979-7 SCORE2+MedicalHistory                2.8676102 NA
# 372820 phecode_979-7 SCORE2+MedicalHistory                2.7237674 NA
# 372821 phecode_979-7 SCORE2+MedicalHistory                2.7459159 NA
# 372822 phecode_979-7 SCORE2+MedicalHistory                2.8424895 NA
# 372823 phecode_979-7 SCORE2+MedicalHistory                2.8860117 NA
# 372824 phecode_979-7 SCORE2+MedicalHistory                2.8621457 NA
# 372825 phecode_979-7 SCORE2+MedicalHistory                2.8651821 NA
# 372826 phecode_979-7 SCORE2+MedicalHistory                2.8463502 NA
# 372827 phecode_979-7 SCORE2+MedicalHistory                2.9463669 NA
# 372828 phecode_979-7 SCORE2+MedicalHistory                2.7780201 NA
# 372829 phecode_979-7 SCORE2+MedicalHistory                2.8520975 NA
# 372830 phecode_979-7 SCORE2+MedicalHistory                2.6400810 NA
# 372831 phecode_979-7 SCORE2+MedicalHistory                2.7465903 NA
# 372832 phecode_979-7 SCORE2+MedicalHistory                2.8113601 NA
# 372833 phecode_979-7 SCORE2+MedicalHistory                2.7303478 NA
# 372834 phecode_979-7 SCORE2+MedicalHistory                2.8062345 NA
#        hrs_mh_sex phecode_string         phecode_category
# 1      NA         All-Cause Death        Death
# 2      NA         All-Cause Death        Death
# 3      NA         All-Cause Death        Death
# 4      NA         All-Cause Death        Death
# 5      NA         All-Cause Death        Death
# 6      NA         All-Cause Death        Death
# 7      NA         All-Cause Death        Death
# 8      NA         All-Cause Death        Death
# 9      NA         All-Cause Death        Death
# 10     NA         All-Cause Death        Death
# 11     NA         All-Cause Death        Death
# 12     NA         All-Cause Death        Death
# 13     NA         All-Cause Death        Death
# 14     NA         All-Cause Death        Death
# 15     NA         All-Cause Death        Death
# 16     NA         All-Cause Death        Death
# 17     NA         All-Cause Death        Death
# 18     NA         All-Cause Death        Death
# 19     NA         All-Cause Death        Death
# 20     NA         All-Cause Death        Death
# 21     NA         All-Cause Death        Death
# 22     NA         All-Cause Death        Death
# 23     NA         All-Cause Death        Death
# 24     NA         All-Cause Death        Death
# 25     NA         All-Cause Death        Death
# 26     NA         All-Cause Death        Death
# 27     NA         All-Cause Death        Death
# 28     NA         All-Cause Death        Death
# 29     NA         All-Cause Death        Death
# 30     NA         All-Cause Death        Death
# ⋮      ⋮          ⋮                      ⋮
# 372805 NA         Bone marrow transplant Stat
# 372806 NA         Bone marrow transplant Stat
# 372807 NA         Bone marrow transplant Stat
# 372808 NA         Bone marrow transplant Stat
# 372809 NA         Bone marrow transplant Stat
# 372810 NA         Bone marrow transplant Stat
# 372811 NA         Bone marrow transplant Stat
# 372812 NA         Bone marrow transplant Stat
# 372813 NA         Bone marrow transplant Stat
# 372814 NA         Bone marrow transplant Stat
# 372815 NA         Bone marrow transplant Stat
# 372816 NA         Bone marrow transplant Stat
# 372817 NA         Bone marrow transplant Stat
# 372818 NA         Bone marrow transplant Stat
# 372819 NA         Bone marrow transplant Stat
# 372820 NA         Bone marrow transplant Stat
# 372821 NA         Bone marrow transplant Stat
# 372822 NA         Bone marrow transplant Stat
# 372823 NA         Bone marrow transplant Stat
# 372824 NA         Bone marrow transplant Stat
# 372825 NA         Bone marrow transplant Stat
# 372826 NA         Bone marrow transplant Stat
# 372827 NA         Bone marrow transplant Stat
# 372828 NA         Bone marrow transplant Stat
# 372829 NA         Bone marrow transplant Stat
# 372830 NA         Bone marrow transplant Stat
# 372831 NA         Bone marrow transplant Stat
# 372832 NA         Bone marrow transplant Stat
# 372833 NA         Bone marrow transplant Stat
# 372834 NA         Bone marrow transplant Stat

# %%
unique(hrs$score)
# Out:
# [1] "ASCVD+MedicalHistory"
# [2] "Age+Sex+Comorbidities+MedicalHistory"
# [3] "Age+Sex+Comorbidities+MedicalHistoryLM"
# [4] "Age+Sex+MedicalHistory"
# [5] "Age+Sex+MedicalHistoryLM"
# [6] "MedicalHistory"
# [7] "MedicalHistoryLM"
# [8] "QRISK3+MedicalHistory"
# [9] "SCORE2+MedicalHistory"

# %%
purrr::map_dfr(integer(100), ~ hrs %>% group_by(endpoint, score) %>% sample_frac(1, replace=TRUE), .id="i") -> temp_hrs

# %%
library(ggdist)
# Out:
# Warning message:
# “package ‘ggdist’ was built under R version 4.0.5”

# %%
temp_hrs_mh = temp_hrs %>% group_by(endpoint, score, phecode_string, phecode_category) %>% median_qi(hrs_mh, hrs_mh_age, hrs_mh_sex, na.rm=TRUE)

# %%
temp_hrs_linear = temp_hrs %>% ungroup() %>%
    filter(score %in% c("MedicalHistory", "Age+Sex+MedicalHistory", "Age+Sex+Comorbidities+MedicalHistory", "ASCVD+MedicalHistory")) %>%
    group_by(endpoint, score, phecode_string, phecode_category) %>% 
    median_qi(`hrs_mh`, na.rm=TRUE) %>% rename(hr = `hrs_mh`) %>%
    mutate(hr = round(hr, 2), .lower=round(.lower, 2), .upper=round(.upper, 2)) %>%#c(hr, .lower, .upper), round, 1) %>%
    mutate(HR_MedicalHistory = glue("{hr} ({.lower}, {.upper})")) %>% 
    select(endpoint, score, phecode_string, phecode_category, HR_MedicalHistory) %>%
    pivot_wider(names_from="score", values_from="HR_MedicalHistory") %>% 
    select(all_of(c("phecode_category", "endpoint", "phecode_string", "MedicalHistory", 'Age+Sex+MedicalHistory',  "Age+Sex+Comorbidities+MedicalHistory", "ASCVD+MedicalHistory"))) %>% 
    mutate(endpoint = factor(endpoint, levels = endpoint_order)) %>% 
    arrange(endpoint) %>%
    #mutate(endpoint = recode(endpoint, !!!endpoint_map)) %>%
    ungroup()
    
temp_hrs_linear

# %%
temp_hrs_linear  %>% 
    write_csv("outputs/SupplTable6_HRsAll.csv")
