# %%
import numpy as np
import pandas as pd
import pathlib
from tqdm.auto import tqdm

import hydra
from omegaconf import DictConfig, OmegaConf

import torch
import ray

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

pathlib.Path(figure_path).mkdir(parents=True, exist_ok=True)
pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

experiment = 230425
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
ray.shutdown()

# %%
ray.init(num_cpus=24, include_dashboard=False)
# Out:
# 2023-04-26 11:07:04,286	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.10.9', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '10.32.105.119', 'raylet_ip_address': '10.32.105.119', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-04-26_11-06-59_214981_2171264/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-04-26_11-06-59_214981_2171264/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2023-04-26_11-06-59_214981_2171264', 'metrics_export_port': 49652, 'gcs_address': '10.32.105.119:49825', 'address': '10.32.105.119:49825', 'dashboard_agent_listen_port': 52365, 'node_id': '40da04cc66188105604640e60584488a432b2148f7820dc8093dc0d0'})

# %%
import wandb
api = wandb.Api(timeout=60)
entity, project = "cardiors", "recordgraphs"  # set to your entity and project 
tag = "revision_230425"
runs = api.runs(entity + "/" + project, filters={"tags": {"$in": [tag]}})

# %%
run_list = []
for run in tqdm(runs):
    run_list.append(
        {
            "id": run.path[-1], 
            "name": run.name,
            "tags": run.tags,
            "config": {k: v for k,v in run.config.items() if not k.startswith('_')},
            "summary": run.summary._json_dict,
            "path": None if "best_checkpoint" not in run.config.keys() else str(pathlib.Path(run.config["best_checkpoint"]).parent.parent)
        }
    )
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
runs_df = pd.DataFrame(run_list).query("path==path")
print(runs_df.shape)
runs_df.sort_values("name")
# Out:
# (44, 6)
#           id                           name  \
# 36  2e41x1jl   230424_linearno_covariates_0
# 35  37p9r8ei   230424_linearno_covariates_1
# 19  odoyt6ww  230424_linearno_covariates_10
# 18  3dzael71  230424_linearno_covariates_11
# 17  27mf5vie  230424_linearno_covariates_12
# 16  2kji3t9v  230424_linearno_covariates_13
# 15  2zv4pd6e  230424_linearno_covariates_14
# 13  21cey4mi  230424_linearno_covariates_15
# 11  2p3fbt6z  230424_linearno_covariates_16
# 5   q2or6s48  230424_linearno_covariates_17
# 3   2ak63hl0  230424_linearno_covariates_18
# 1   3q28lgxq  230424_linearno_covariates_19
# 34  1vzqalcx   230424_linearno_covariates_2
# 2   2vrnshys  230424_linearno_covariates_20
# 0   w0vw9p4h  230424_linearno_covariates_21
# 33  1jdozy7y   230424_linearno_covariates_3
# 32  1thc8rv3   230424_linearno_covariates_4
# 31  24suqcor   230424_linearno_covariates_5
# 30  1krcwcia   230424_linearno_covariates_6
# 29  2tm4qavv   230424_linearno_covariates_7
# 28  eh24wp3l   230424_linearno_covariates_8
# 20  1q56m23l   230424_linearno_covariates_9
# 37  16q0dsxz    230424identityno_covariates
# 38  22eqnjsk    230424identityno_covariates
# 39  37ptgsf2    230424identityno_covariates
# 40  2osqub5e    230424identityno_covariates
# 41  17fstw6g    230424identityno_covariates
# 21  v2isnx3i    230424identityno_covariates
# 26  1i6zbv90    230424identityno_covariates
# 25  3gybn0az    230424identityno_covariates
# 24  3n1eabtc    230424identityno_covariates
# 23  1m4apuxc    230424identityno_covariates
# 22  fi5qkmts    230424identityno_covariates
# 42  rn73or6d    230424identityno_covariates
# 14  2lskghmi    230424identityno_covariates
# 12  3ozs0xxw    230424identityno_covariates
# 10  3h0y3oly    230424identityno_covariates
# 9   3isuy34u    230424identityno_covariates
# 8   327cdxjv    230424identityno_covariates
# 7   1tncfcyc    230424identityno_covariates
# 6   2aewpg3s    230424identityno_covariates
# 4   3eucowge    230424identityno_covariates
# 27  2h2kim9q    230424identityno_covariates
# 43  8jlgenex    230424identityno_covariates
#
#                                       tags  \
# 36  [full_data, identity, revision_230425]
# 35  [full_data, identity, revision_230425]
# 19  [full_data, identity, revision_230425]
# 18  [full_data, identity, revision_230425]
# 17  [full_data, identity, revision_230425]
# 16  [full_data, identity, revision_230425]
# 15  [full_data, identity, revision_230425]
# 13  [full_data, identity, revision_230425]
# 11  [full_data, identity, revision_230425]
# 5   [full_data, identity, revision_230425]
# 3   [full_data, identity, revision_230425]
# 1   [full_data, identity, revision_230425]
# 34  [full_data, identity, revision_230425]
# 2   [full_data, identity, revision_230425]
# 0   [full_data, identity, revision_230425]
# 33  [full_data, identity, revision_230425]
# 32  [full_data, identity, revision_230425]
# 31  [full_data, identity, revision_230425]
# 30  [full_data, identity, revision_230425]
# 29  [full_data, identity, revision_230425]
# 28  [full_data, identity, revision_230425]
# 20  [full_data, identity, revision_230425]
# 37  [full_data, identity, revision_230425]
# 38  [full_data, identity, revision_230425]
# 39  [full_data, identity, revision_230425]
# 40  [full_data, identity, revision_230425]
# 41  [full_data, identity, revision_230425]
# 21  [full_data, identity, revision_230425]
# 26  [full_data, identity, revision_230425]
# 25  [full_data, identity, revision_230425]
# 24  [full_data, identity, revision_230425]
# 23  [full_data, identity, revision_230425]
# 22  [full_data, identity, revision_230425]
# 42  [full_data, identity, revision_230425]
# 14  [full_data, identity, revision_230425]
# 12  [full_data, identity, revision_230425]
# 10  [full_data, identity, revision_230425]
# 9   [full_data, identity, revision_230425]
# 8   [full_data, identity, revision_230425]
# 7   [full_data, identity, revision_230425]
# 6   [full_data, identity, revision_230425]
# 4   [full_data, identity, revision_230425]
# 27  [full_data, identity, revision_230425]
# 43  [full_data, identity, revision_230425]
#
#                                                config  \
# 36  {'best_score': 4.023687839508057, 'node_dropou...
# 35  {'best_score': 4.043667793273926, 'node_dropou...
# 19  {'best_score': 4.049468040466309, 'node_dropou...
# 18  {'best_score': 4.0361456871032715, 'node_dropo...
# 17  {'best_score': 4.047984600067139, 'node_dropou...
# 16  {'best_score': 4.068432331085205, 'node_dropou...
# 15  {'best_score': 4.082460403442383, 'node_dropou...
# 13  {'best_score': 4.06764030456543, 'node_dropout...
# 11  {'best_score': 4.028999328613281, 'node_dropou...
# 5   {'best_score': 4.0303239822387695, 'node_dropo...
# 3   {'best_score': 4.03322696685791, 'node_dropout...
# 1   {'best_score': 4.05049991607666, 'node_dropout...
# 34  {'best_score': 4.048755645751953, 'node_dropou...
# 2   {'best_score': 4.05116081237793, 'node_dropout...
# 0   {'best_score': 4.040450572967529, 'node_dropou...
# 33  {'best_score': 4.0332489013671875, 'node_dropo...
# 32  {'best_score': 4.038598537445068, 'node_dropou...
# 31  {'best_score': 4.050586700439453, 'node_dropou...
# 30  {'best_score': 4.0504889488220215, 'node_dropo...
# 29  {'best_score': 4.0399298667907715, 'node_dropo...
# 28  {'best_score': 4.0451788902282715, 'node_dropo...
# 20  {'best_score': 4.048370361328125, 'node_dropou...
# 37  {'best_score': 3.8801674842834473, 'node_dropo...
# 38  {'best_score': 3.895275831222534, 'node_dropou...
# 39  {'best_score': 3.897392749786377, 'node_dropou...
# 40  {'best_score': 3.89337420463562, 'node_dropout...
# 41  {'best_score': 3.8880057334899902, 'node_dropo...
# 21  {'best_score': 3.9256722927093506, 'node_dropo...
# 26  {'best_score': 3.8958144187927246, 'node_dropo...
# 25  {'best_score': 3.898661375045776, 'node_dropou...
# 24  {'best_score': 3.8933472633361816, 'node_dropo...
# 23  {'best_score': 3.883189201354981, 'node_dropou...
# 22  {'best_score': 3.8968746662139897, 'node_dropo...
# 42  {'best_score': 3.8941783905029297, 'node_dropo...
# 14  {'best_score': 3.9360742568969727, 'node_dropo...
# 12  {'best_score': 3.921203374862671, 'node_dropou...
# 10  {'best_score': 3.8844828605651855, 'node_dropo...
# 9   {'best_score': 3.8826069831848145, 'node_dropo...
# 8   {'best_score': 3.8881313800811768, 'node_dropo...
# 7   {'best_score': 3.899914979934693, 'node_dropou...
# 6   {'best_score': 3.903437614440918, 'node_dropou...
# 4   {'best_score': 3.890296697616577, 'node_dropou...
# 27  {'best_score': 3.886729478836059, 'node_dropou...
# 43  {'best_score': 3.870687484741211, 'node_dropou...
#
#                                               summary  \
# 36  {'valid/phecode_511 - Gastro-esophageal reflux...
# 35  {'test/phecode_139-6 - Hemangioma and lymphang...
# 19  {'valid/phecode_333-3 - Hypersomnia_CIndex': 0...
# 18  {'test/phecode_324-8 - Restless legs syndrome_...
# 17  {'valid/phecode_509 - Diseases of tongue_CInde...
# 16  {'test/phecode_060 - Adenovirus_CIndex': 0.323...
# 15  {'valid/phecode_679-3 - Changes in skin textur...
# 13  {'test/phecode_716-3 - Spinal disc displacemen...
# 11  {'test/phecode_334-4 - Disorders of oculomotor...
# 5   {'valid/phecode_381-82 - Exophoria_CIndex': 0....
# 3   {'valid/phecode_686 - Chronic ulcer of skin_CI...
# 1   {'valid/phecode_360 - Inflammation of eyelids_...
# 34  {'test/phecode_099 - Lab findings related to i...
# 2   {'test/phecode_714 - Deforming dorsopathies_CI...
# 0   {'test/phecode_684-2 - Hypertrichosis and hirs...
# 33  {'valid/phecode_624 - Symptoms involving femal...
# 32  {'test/phecode_719-8 - Rhabdomyolysis_CIndex':...
# 31  {'test/phecode_208-2 - Hyperparathyroidism_CIn...
# 30  {'valid/phecode_668-4 - Dermatitis due to subs...
# 29  {'test/phecode_670 - Seborrheic keratosis_CInd...
# 28  {'valid/phecode_709-11 - Mallet finger_CIndex'...
# 20  {'test/phecode_668-2 - Seborrheic dermatitis_C...
# 37  {'test/phecode_719-7 - Muscle weakness (genera...
# 38  {'valid/phecode_686 - Chronic ulcer of skin_CI...
# 39  {'test/phecode_500-41 - Impacted teeth*_CIndex...
# 40  {'test/phecode_209-21 - Diabetes insipidus_CIn...
# 41  {'valid/CoxPH': 3.8969380855560303, 'test/phec...
# 21  {'valid/phecode_596-1 - Bladder neck obstructi...
# 26  {'test/phecode_209-13 - Hyperprolactinemia*_CI...
# 25  {'test/phecode_506-3 - Sialoadenitis_CIndex': ...
# 24  {'valid/phecode_705-4 - Palindromic rheumatism...
# 23  {'valid/phecode_413-4 - Pulmonary valve disord...
# 22  {'valid/phecode_121-11 - Acute lymphoid leukem...
# 42  {'valid/phecode_230-22 - Underweight_CIndex': ...
# 14  {'test/phecode_518 - Appendicitis_CIndex': 0.4...
# 12  {'test/phecode_669 - Neutrophilic and Eosinoph...
# 10  {'test/phecode_721-7 - Synovial hypertrophy*_C...
# 9   {'valid/phecode_340 - Myopathies_CIndex': 0.76...
# 8   {'valid/phecode_367-41 - Cellulitis of orbit_C...
# 7   {'test/phecode_209 - Disorders of the pituitar...
# 6   {'test/phecode_619-4 - Noninflammatory disorde...
# 4   {'test/phecode_334-4 - Disorders of oculomotor...
# 27  {'test/phecode_381-4 - Exotropia_CIndex': 0.68...
# 43  {'valid/phecode_544 - Biliary cirrhosis_CIndex...
#
#                                                  path
# 36  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 35  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 19  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 18  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 17  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 16  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 15  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 13  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 11  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 5   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 3   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 1   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 34  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 2   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 0   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 33  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 32  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 31  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 30  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 29  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 28  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 20  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 37  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 38  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 39  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 40  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 41  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 21  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 26  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 25  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 24  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 23  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 22  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 42  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 14  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 12  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 10  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 9   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 8   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 7   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 6   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 4   /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 27  /sc-projects/sc-proj-ukb-cvd/results/models/Re...
# 43  /sc-projects/sc-proj-ukb-cvd/results/models/Re...

# %%
runs_df.iloc[0].path
# Out:
# '/sc-projects/sc-proj-ukb-cvd/results/models/RecordGraphs/w0vw9p4h'

# %%
temp = pd.read_feather("/sc-projects/sc-proj-ukb-cvd/results/models/RecordGraphs/w0vw9p4h/predictions/predictions.feather")

# %%
temp
# Out:
#           index  OMOP_4306655  phecode_001  phecode_002  phecode_002-1  \
# 0       1396056     -2.003530     0.361274     0.038692       0.122211
# 1       4252082      0.618109    -4.992557     4.057137       4.536081
# 2       1868322      0.100651    -0.145091     0.318971       0.329597
# 3       3023433     -0.842339     0.454700    -0.064704       0.052182
# 4       2662927      0.303058     0.272868     0.380122       0.390945
# ...         ...           ...          ...          ...            ...
# 502455  5971976      0.330164     0.311025     0.434097       0.437815
# 502456  5979031      0.303058     0.272868     0.380122       0.390945
# 502457  5990682      0.281786     0.433223     0.483855       0.485373
# 502458  6011735      0.197576     0.052841     0.306138       0.338970
# 502459  6013074      0.930211    -0.171898     0.783523       0.817458
#
#         phecode_003  phecode_004  phecode_004-1  phecode_004-2  phecode_004-3  \
# 0          0.110131     0.425914       0.641219      -0.420324      -0.061410
# 1          2.161767     2.343617      -1.292540      -1.757566       2.186577
# 2          0.334905     0.415730      -0.237269       0.001429       0.098487
# 3          0.054635     0.035032       0.217104       0.067919       0.034503
# 4          0.359778     0.389229       0.369213       0.248584       0.266713
# ...             ...          ...            ...            ...            ...
# 502455     0.281324     0.412591       0.375606      -0.179013      -0.160882
# 502456     0.359778     0.389229       0.369213       0.248584       0.266713
# 502457     0.501096     0.442838       0.359975       0.432647       0.442925
# 502458     0.345662     0.368905       0.385607      -0.419740       0.210292
# 502459     0.809199     0.667437       0.449638       0.102004       0.092082
#
#         ...  phecode_979  phecode_979-2  phecode_979-7  partition  \
# 0       ...     0.235215      -0.003101      -0.862161         21
# 1       ...     1.125460       0.344579      -7.545802         21
# 2       ...     0.126879       0.166778      -0.100045         21
# 3       ...     0.159570       0.058622       0.184406         21
# 4       ...     0.411443       0.327052       0.171649         21
# ...     ...          ...            ...            ...        ...
# 502455  ...     0.444895       0.328390       0.080754         21
# 502456  ...     0.411443       0.327052       0.171649         21
# 502457  ...     0.523792       0.550018       0.278911         21
# 502458  ...     0.423183       0.191406      -0.049430         21
# 502459  ...     0.381628       0.265595      -0.425489         21
#
#                          module  encoder        head  covariate_cols  \
# 0       RecordsIdentityTraining     None  LinearHead              []
# 1       RecordsIdentityTraining     None  LinearHead              []
# 2       RecordsIdentityTraining     None  LinearHead              []
# 3       RecordsIdentityTraining     None  LinearHead              []
# 4       RecordsIdentityTraining     None  LinearHead              []
# ...                         ...      ...         ...             ...
# 502455  RecordsIdentityTraining     None  LinearHead              []
# 502456  RecordsIdentityTraining     None  LinearHead              []
# 502457  RecordsIdentityTraining     None  LinearHead              []
# 502458  RecordsIdentityTraining     None  LinearHead              []
# 502459  RecordsIdentityTraining     None  LinearHead              []
#
#                                               record_cols  split
# 0       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 1       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 2       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 3       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# 4       ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...  train
# ...                                                   ...    ...
# 502455  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 502456  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 502457  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 502458  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
# 502459  ['OMOP_1000560', 'OMOP_1000632', 'OMOP_1000995...   test
#
# [502460 rows x 1891 columns]

# %% [markdown]
# ## Process Predictions

# %%
name_dict = {
    "CovariatesOnlyTraining_['age_at_recruitment_f21022_0_0', 'sex_f31_0_0']_None_MLPHead": "Identity(AgeSex)+MLP",
    "RecordsIdentityTraining_[]_None_MLPHead": "Identity(Records)+MLP",
     "RecordsIdentityTraining_[]_None_LinearHead": "Identity(Records)+Linear",
    "RecordsGraphTraining_[]_HeteroGNN_MLPHead": "GNN(Records)+MLP",
    "RecordsIdentityTraining_['age_at_recruitment_f21022_0_0', 'sex_f31_0_0']_None_MLPHead": "Identity(AgeSex+Records)+MLP",
    "RecordsGraphTraining_['age_at_recruitment_f21022_0_0', 'sex_f31_0_0']_HeteroGNN_MLPHead": "GNN(AgeSex+Records)+MLP"
}

# %%
id_vars = ["eid", "model", "partition", "split"]

# %%
out_path = f"{experiment_path}/loghs"
pathlib.Path(out_path).mkdir(parents=True, exist_ok=True)

# %%
@ray.remote
def prepare_predictions(in_path, out_path):
    
    temp = pd.read_feather(in_path).rename(columns={"index": "eid"}).reset_index(drop=True)
    temp["model"] = (temp.module.astype(str) + "_" + temp.covariate_cols.astype(str) + "_" + temp.encoder.astype(str) + "_" + temp["head"].astype(str)).astype("category")
    temp = temp.replace({"model":name_dict}).drop(columns=["module", "encoder", "head", "covariate_cols", "record_cols"])
    for c in id_vars: temp[c] = temp[c].astype("category")
    
    model = temp.model.unique()[0]
    partition = temp.partition.unique()[0]
    for split in ["train", "valid", "test"]:
        fp_out = f"{out_path}/{model}/{partition}"
        pathlib.Path(fp_out).mkdir(parents=True, exist_ok=True)
        temp.query("split==@split").reset_index(drop=True).to_feather(f"{fp_out}/{split}.feather")

# %%
for p in tqdm(runs_df.path): 
    prepare_predictions.remote(f"{p}/predictions/predictions.feather", out_path)
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]

# %%
1+1
