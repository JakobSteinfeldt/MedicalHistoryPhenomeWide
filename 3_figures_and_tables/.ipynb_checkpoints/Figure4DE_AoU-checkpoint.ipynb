# %%
library(ggplot2)
library(dtplyr)
library(tidyverse)
library(glue)
library(arrow)
library(patchwork)
library(data.table)
library("jsonlite")
library(ggthemes)
library(stringr)
library(ggtext)
library(ggdist)
library(boot)
library(dplyr)
library(Hmisc)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.5”
# Warning message:
# “package ‘dtplyr’ was built under R version 4.0.5”
# Warning message:
# “package ‘tidyverse’ was built under R version 4.0.5”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ✔ purrr   0.3.4
# Warning message:
# “package ‘tibble’ was built under R version 4.0.5”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.5”
# Warning message:
# “package ‘readr’ was built under R version 4.0.5”
# Warning message:
# “package ‘purrr’ was built under R version 4.0.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.5”
# Warning message:
# “package ‘stringr’ was built under R version 4.0.5”
# Warning message:
# “package ‘forcats’ was built under R version 4.0.5”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Warning message:
# “package ‘glue’ was built under R version 4.0.5”
# Warning message:
# “package ‘arrow’ was built under R version 4.0.5”
#
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# Warning message:
# “package ‘patchwork’ was built under R version 4.0.5”
# Warning message:
# “package ‘data.table’ was built under R version 4.0.5”
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose
#
#
# Warning message:
# “package ‘jsonlite’ was built under R version 4.0.5”
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
#
# Warning message:
# “package ‘ggthemes’ was built under R version 4.0.3”
# Warning message:
# “package ‘ggtext’ was built under R version 4.0.3”
# Warning message:
# “package ‘ggdist’ was built under R version 4.0.5”
# Warning message:
# “package ‘boot’ was built under R version 4.0.3”
# Loading required package: lattice
#
# Warning message:
# “package ‘lattice’ was built under R version 4.0.5”
#
# Attaching package: ‘lattice’
#
#
# The following object is masked from ‘package:boot’:
#
#     melanoma
#
#
# Loading required package: survival
#
# Warning message:
# “package ‘survival’ was built under R version 4.0.5”
#
# Attaching package: ‘survival’
#
#
# The following object is masked from ‘package:boot’:
#
#     aml
#
#
# Loading required package: Formula
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     src, summarize
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units

# %%
base_path = "/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220823_allofus/230502_revision"
base_path
# Out:
# [1] "/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220823_allofus/230502_revision"

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) +
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0),
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major.y=element_line()))

# %%
results = arrow::read_feather(glue("{base_path}/230503_result_ukbbparams_ubr_clean_cindices_ensemble.feather"))

# %%
results
# Out:
#       index score                           cindex    endpoint      num_events
# 1     0     Entire population               0.8083307 OMOP_4306655  2427
# 2     1     Sexual and gender minorities    0.7912060 OMOP_4306655   303
# 3     2     Non-white or Hispanic/Latino    0.8251000 OMOP_4306655  1107
# 4     3     Annual income < $25k            0.7693127 OMOP_4306655   811
# 5     4     Less than high school education 0.7817756 OMOP_4306655   313
# 6     5     Age >= 65                       0.7504583 OMOP_4306655  1175
# 7     6     At least one UBR categorization 0.7952637 OMOP_4306655  2164
# 8     7     No UBR categorization           0.8363416 OMOP_4306655   295
# 9     0     Entire population               0.7687736 phecode_002   1939
# 10    1     Sexual and gender minorities    0.7522011 phecode_002    285
# 11    2     Non-white or Hispanic/Latino    0.7780270 phecode_002    886
# 12    3     Annual income < $25k            0.7447521 phecode_002    750
# 13    4     Less than high school education 0.7424965 phecode_002    286
# 14    5     Age >= 65                       0.7624612 phecode_002    479
# 15    6     At least one UBR categorization 0.7610258 phecode_002   1615
# 16    7     No UBR categorization           0.7900578 phecode_002    370
# 17    0     Entire population               0.7710879 phecode_002.1 1939
# 18    1     Sexual and gender minorities    0.7548913 phecode_002.1  285
# 19    2     Non-white or Hispanic/Latino    0.7797493 phecode_002.1  886
# 20    3     Annual income < $25k            0.7463297 phecode_002.1  750
# 21    4     Less than high school education 0.7457171 phecode_002.1  286
# 22    5     Age >= 65                       0.7636607 phecode_002.1  479
# 23    6     At least one UBR categorization 0.7632975 phecode_002.1 1615
# 24    7     No UBR categorization           0.7927192 phecode_002.1  370
# 25    0     Entire population               0.7657189 phecode_003   1683
# 26    1     Sexual and gender minorities    0.7514590 phecode_003    245
# 27    2     Non-white or Hispanic/Latino    0.7665561 phecode_003    890
# 28    3     Annual income < $25k            0.7626344 phecode_003    632
# 29    4     Less than high school education 0.7483618 phecode_003    267
# 30    5     Age >= 65                       0.7408476 phecode_003    633
# ⋮     ⋮     ⋮                               ⋮         ⋮             ⋮
# 11667 2     Non-white or Hispanic/Latino    0.2400814 phecode_978   112
# 11668 3     Annual income < $25k            0.2914010 phecode_978    92
# 11669 4     Less than high school education 0.2006360 phecode_978    26
# 11670 5     Age >= 65                       0.3079917 phecode_978   116
# 11671 6     At least one UBR categorization 0.2742957 phecode_978   239
# 11672 7     No UBR categorization           0.3165832 phecode_978    57
# 11673 0     Entire population               0.2239004 phecode_978.2 120
# 11674 1     Sexual and gender minorities    0.1132017 phecode_978.2  11
# 11675 2     Non-white or Hispanic/Latino    0.1925936 phecode_978.2  55
# 11676 3     Annual income < $25k            0.2212740 phecode_978.2  29
# 11677 4     Less than high school education 0.1536904 phecode_978.2  13
# 11678 5     Age >= 65                       0.2335080 phecode_978.2  63
# 11679 6     At least one UBR categorization 0.2170321 phecode_978.2 107
# 11680 7     No UBR categorization           0.2476482 phecode_978.2  15
# 11681 0     Entire population               0.2300865 phecode_979   826
# 11682 1     Sexual and gender minorities    0.2053881 phecode_979   107
# 11683 2     Non-white or Hispanic/Latino    0.1862783 phecode_979   450
# 11684 3     Annual income < $25k            0.1998490 phecode_979   213
# 11685 4     Less than high school education 0.1572517 phecode_979    96
# 11686 5     Age >= 65                       0.3169349 phecode_979   289
# 11687 6     At least one UBR categorization 0.2408225 phecode_979   708
# 11688 7     No UBR categorization           0.2300378 phecode_979   137
# 11689 0     Entire population               0.9127252 phecode_979.2 326
# 11690 1     Sexual and gender minorities    0.9235205 phecode_979.2  39
# 11691 2     Non-white or Hispanic/Latino    0.9453046 phecode_979.2 223
# 11692 3     Annual income < $25k            0.9558013 phecode_979.2 104
# 11693 4     Less than high school education 0.9431823 phecode_979.2  50
# 11694 5     Age >= 65                       0.8665331 phecode_979.2  88
# 11695 6     At least one UBR categorization 0.9254744 phecode_979.2 287
# 11696 7     No UBR categorization           0.8367785 phecode_979.2  46
#       num_included partition Group
# 1     232033       ensemble  Entire population
# 2      33400       ensemble  Sexual and gender minorities
# 3     111712       ensemble  Non-white or Hispanic/Latino
# 4      62931       ensemble  Annual income < $25k
# 5      23005       ensemble  Less than high school education
# 6      63161       ensemble  Age >= 65
# 7     182089       ensemble  At least one UBR categorization
# 8      54850       ensemble  No UBR categorization
# 9     227519       ensemble  Entire population
# 10     32684       ensemble  Sexual and gender minorities
# 11    109753       ensemble  Non-white or Hispanic/Latino
# 12     61270       ensemble  Annual income < $25k
# 13     22508       ensemble  Less than high school education
# 14     61864       ensemble  Age >= 65
# 15    178358       ensemble  At least one UBR categorization
# 16     53961       ensemble  No UBR categorization
# 17    227523       ensemble  Entire population
# 18     32684       ensemble  Sexual and gender minorities
# 19    109754       ensemble  Non-white or Hispanic/Latino
# 20     61270       ensemble  Annual income < $25k
# 21     22508       ensemble  Less than high school education
# 22     61866       ensemble  Age >= 65
# 23    178361       ensemble  At least one UBR categorization
# 24     53962       ensemble  No UBR categorization
# 25    228935       ensemble  Entire population
# 26     32954       ensemble  Sexual and gender minorities
# 27    110094       ensemble  Non-white or Hispanic/Latino
# 28     61857       ensemble  Annual income < $25k
# 29     22533       ensemble  Less than high school education
# 30     62028       ensemble  Age >= 65
# ⋮     ⋮            ⋮         ⋮
# 11667 111442       ensemble  Non-white or Hispanic/Latino
# 11668  62742       ensemble  Annual income < $25k
# 11669  22953       ensemble  Less than high school education
# 11670  62864       ensemble  Age >= 65
# 11671 181536       ensemble  At least one UBR categorization
# 11672  54728       ensemble  No UBR categorization
# 11673 231682       ensemble  Entire population
# 11674  33361       ensemble  Sexual and gender minorities
# 11675 111566       ensemble  Non-white or Hispanic/Latino
# 11676  62845       ensemble  Annual income < $25k
# 11677  22978       ensemble  Less than high school education
# 11678  62955       ensemble  Age >= 65
# 11679 181772       ensemble  At least one UBR categorization
# 11680  54813       ensemble  No UBR categorization
# 11681 228477       ensemble  Entire population
# 11682  32978       ensemble  Sexual and gender minorities
# 11683 109945       ensemble  Non-white or Hispanic/Latino
# 11684  61967       ensemble  Annual income < $25k
# 11685  22665       ensemble  Less than high school education
# 11686  61862       ensemble  Age >= 65
# 11687 179179       ensemble  At least one UBR categorization
# 11688  54129       ensemble  No UBR categorization
# 11689 230430       ensemble  Entire population
# 11690  33195       ensemble  Sexual and gender minorities
# 11691 110730       ensemble  Non-white or Hispanic/Latino
# 11692  62447       ensemble  Annual income < $25k
# 11693  22816       ensemble  Less than high school education
# 11694  62709       ensemble  Age >= 65
# 11695 180741       ensemble  At least one UBR categorization
# 11696  54560       ensemble  No UBR categorization

# %%
install.packages('gghighlight')
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(gghighlight)

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) +
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0),
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major.y=element_line()))

plot_width = 8.25; plot_height=2.5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

#temp = benchmark_endpoints %>%
#    filter(score %in% scores_plot) %>%
#    mutate(score = factor(score, levels=scores_plot)) %>%
#    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%

groups_sorted = c('Entire population', 'No UBR categorization', 'At least one UBR categorization', 'Age >= 65', 'Annual income < $25k', 'Less than high school education', 'Non-white or Hispanic/Latino', 'Sexual and gender minorities')

cbbPalette <- c("#000000", "#D55E00")

annotation_y = results %>% filter(endpoint == 'phecode_420') %>% filter(score == 'Entire population') %>% pull(cindex)
results = results %>% 
  mutate(Group=factor(Group, levels=groups_sorted)) %>%
  mutate("is_cardiac" = endpoint == 'phecode_420') %>%
  mutate(Endpoint=factor(is_cardiac, labels=c("Phenome-wide", "Cardiac arrest"))) %>%
  mutate(is_cardiac_dbl = as.numeric(endpoint == 'phecode_420')) %>%
  filter(Group != "At least one UBR categorization")

fig_phenome = results %>%
  ggplot(aes(x = Group, y = cindex))+#, color=is_cardiac))+#, scale=1 + is_cardiac_dbl)) +
  stat_halfeye(side='left', scale=0.5) + 
  coord_cartesian(ylim=c(0., 1.0), clip = "on")+
  stat_dotsinterval(side = "right", scale = 0.5, slab_size = NA) +
  scale_fill_brewer(palette="Set1") + 
  labs(x="Group", y="C-Index") + 
    theme(axis.title.x=element_blank(),
      panel.grid.major=element_blank(),
      strip.text = element_text(angle=270, hjust=1)
    ) +
    theme(legend.position="none") + 
    #theme(legend.position = c(0.95, 0.25)) + 
  scale_x_discrete(labels = function(x) str_wrap(x, width = 10)) +
  scale_fill_manual(values=cbbPalette) + 
  scale_colour_manual(values=cbbPalette)# + 
  #annotate(geom = "text", x = "Entire population", y = annotation_y + 0.15, label = "Cardiac arrest", hjust = "left", size=2)

# Create a new data frame with only "Cardiac arrest" data
cardiac_arrest_data <- results %>%
  filter(is_cardiac == TRUE) %>%
  mutate(color = "Cardiac arrest")

# Add the point for "Cardiac arrest" with the desired color (orange)
fig_phenome <- fig_phenome +
  geom_point(data = cardiac_arrest_data, aes(x = Group, y = cindex, color = color), size = 2.5) +
  scale_color_manual("", values = c("Phenome-wide" = cbbPalette[1], "Cardiac arrest" = "#D55E00"), breaks = "Cardiac arrest") +
  theme(
      legend.position = c(0.85, 0.15),
      legend.background = element_rect(fill = "transparent")
  )# +
  #guides(color = guide_legend(override.aes = list(shape = c(NA, 19), linetype = c("blank", "solid"))))
                   
                   
fig_phenome
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %%
results
# Out:
#       index score                           cindex    endpoint       num_events
# 1     0     Entire population               0.8083307 OMOP_4306655   2427
# 2     1     Sexual and gender minorities    0.7912060 OMOP_4306655    303
# 3     2     Non-white or Hispanic/Latino    0.8251000 OMOP_4306655   1107
# 4     3     Annual income < $25k            0.7693127 OMOP_4306655    811
# 5     4     Less than high school education 0.7817756 OMOP_4306655    313
# 6     5     Age >= 65                       0.7504583 OMOP_4306655   1175
# 7     7     No UBR categorization           0.8363416 OMOP_4306655    295
# 8     0     Entire population               0.7687736 phecode_002    1939
# 9     1     Sexual and gender minorities    0.7522011 phecode_002     285
# 10    2     Non-white or Hispanic/Latino    0.7780270 phecode_002     886
# 11    3     Annual income < $25k            0.7447521 phecode_002     750
# 12    4     Less than high school education 0.7424965 phecode_002     286
# 13    5     Age >= 65                       0.7624612 phecode_002     479
# 14    7     No UBR categorization           0.7900578 phecode_002     370
# 15    0     Entire population               0.7710879 phecode_002.1  1939
# 16    1     Sexual and gender minorities    0.7548913 phecode_002.1   285
# 17    2     Non-white or Hispanic/Latino    0.7797493 phecode_002.1   886
# 18    3     Annual income < $25k            0.7463297 phecode_002.1   750
# 19    4     Less than high school education 0.7457171 phecode_002.1   286
# 20    5     Age >= 65                       0.7636607 phecode_002.1   479
# 21    7     No UBR categorization           0.7927192 phecode_002.1   370
# 22    0     Entire population               0.7657189 phecode_003    1683
# 23    1     Sexual and gender minorities    0.7514590 phecode_003     245
# 24    2     Non-white or Hispanic/Latino    0.7665561 phecode_003     890
# 25    3     Annual income < $25k            0.7626344 phecode_003     632
# 26    4     Less than high school education 0.7483618 phecode_003     267
# 27    5     Age >= 65                       0.7408476 phecode_003     633
# 28    7     No UBR categorization           0.7936323 phecode_003     226
# 29    0     Entire population               0.5090709 phecode_004    3668
# 30    1     Sexual and gender minorities    0.5825545 phecode_004     486
# ⋮     ⋮     ⋮                               ⋮         ⋮              ⋮
# 10205 5     Age >= 65                       0.8295628 phecode_977.71 1032
# 10206 7     No UBR categorization           0.8512231 phecode_977.71  487
# 10207 0     Entire population               0.2798544 phecode_978     290
# 10208 1     Sexual and gender minorities    0.2696191 phecode_978      34
# 10209 2     Non-white or Hispanic/Latino    0.2400814 phecode_978     112
# 10210 3     Annual income < $25k            0.2914010 phecode_978      92
# 10211 4     Less than high school education 0.2006360 phecode_978      26
# 10212 5     Age >= 65                       0.3079917 phecode_978     116
# 10213 7     No UBR categorization           0.3165832 phecode_978      57
# 10214 0     Entire population               0.2239004 phecode_978.2   120
# 10215 1     Sexual and gender minorities    0.1132017 phecode_978.2    11
# 10216 2     Non-white or Hispanic/Latino    0.1925936 phecode_978.2    55
# 10217 3     Annual income < $25k            0.2212740 phecode_978.2    29
# 10218 4     Less than high school education 0.1536904 phecode_978.2    13
# 10219 5     Age >= 65                       0.2335080 phecode_978.2    63
# 10220 7     No UBR categorization           0.2476482 phecode_978.2    15
# 10221 0     Entire population               0.2300865 phecode_979     826
# 10222 1     Sexual and gender minorities    0.2053881 phecode_979     107
# 10223 2     Non-white or Hispanic/Latino    0.1862783 phecode_979     450
# 10224 3     Annual income < $25k            0.1998490 phecode_979     213
# 10225 4     Less than high school education 0.1572517 phecode_979      96
# 10226 5     Age >= 65                       0.3169349 phecode_979     289
# 10227 7     No UBR categorization           0.2300378 phecode_979     137
# 10228 0     Entire population               0.9127252 phecode_979.2   326
# 10229 1     Sexual and gender minorities    0.9235205 phecode_979.2    39
# 10230 2     Non-white or Hispanic/Latino    0.9453046 phecode_979.2   223
# 10231 3     Annual income < $25k            0.9558013 phecode_979.2   104
# 10232 4     Less than high school education 0.9431823 phecode_979.2    50
# 10233 5     Age >= 65                       0.8665331 phecode_979.2    88
# 10234 7     No UBR categorization           0.8367785 phecode_979.2    46
#       num_included partition Group                           is_cardiac
# 1     232033       ensemble  Entire population               FALSE
# 2      33400       ensemble  Sexual and gender minorities    FALSE
# 3     111712       ensemble  Non-white or Hispanic/Latino    FALSE
# 4      62931       ensemble  Annual income < $25k            FALSE
# 5      23005       ensemble  Less than high school education FALSE
# 6      63161       ensemble  Age >= 65                       FALSE
# 7      54850       ensemble  No UBR categorization           FALSE
# 8     227519       ensemble  Entire population               FALSE
# 9      32684       ensemble  Sexual and gender minorities    FALSE
# 10    109753       ensemble  Non-white or Hispanic/Latino    FALSE
# 11     61270       ensemble  Annual income < $25k            FALSE
# 12     22508       ensemble  Less than high school education FALSE
# 13     61864       ensemble  Age >= 65                       FALSE
# 14     53961       ensemble  No UBR categorization           FALSE
# 15    227523       ensemble  Entire population               FALSE
# 16     32684       ensemble  Sexual and gender minorities    FALSE
# 17    109754       ensemble  Non-white or Hispanic/Latino    FALSE
# 18     61270       ensemble  Annual income < $25k            FALSE
# 19     22508       ensemble  Less than high school education FALSE
# 20     61866       ensemble  Age >= 65                       FALSE
# 21     53962       ensemble  No UBR categorization           FALSE
# 22    228935       ensemble  Entire population               FALSE
# 23     32954       ensemble  Sexual and gender minorities    FALSE
# 24    110094       ensemble  Non-white or Hispanic/Latino    FALSE
# 25     61857       ensemble  Annual income < $25k            FALSE
# 26     22533       ensemble  Less than high school education FALSE
# 27     62028       ensemble  Age >= 65                       FALSE
# 28     54405       ensemble  No UBR categorization           FALSE
# 29    222352       ensemble  Entire population               FALSE
# 30     31972       ensemble  Sexual and gender minorities    FALSE
# ⋮     ⋮            ⋮         ⋮                               ⋮
# 10205  59720       ensemble  Age >= 65                       FALSE
# 10206  53409       ensemble  No UBR categorization           FALSE
# 10207 231367       ensemble  Entire population               FALSE
# 10208  33320       ensemble  Sexual and gender minorities    FALSE
# 10209 111442       ensemble  Non-white or Hispanic/Latino    FALSE
# 10210  62742       ensemble  Annual income < $25k            FALSE
# 10211  22953       ensemble  Less than high school education FALSE
# 10212  62864       ensemble  Age >= 65                       FALSE
# 10213  54728       ensemble  No UBR categorization           FALSE
# 10214 231682       ensemble  Entire population               FALSE
# 10215  33361       ensemble  Sexual and gender minorities    FALSE
# 10216 111566       ensemble  Non-white or Hispanic/Latino    FALSE
# 10217  62845       ensemble  Annual income < $25k            FALSE
# 10218  22978       ensemble  Less than high school education FALSE
# 10219  62955       ensemble  Age >= 65                       FALSE
# 10220  54813       ensemble  No UBR categorization           FALSE
# 10221 228477       ensemble  Entire population               FALSE
# 10222  32978       ensemble  Sexual and gender minorities    FALSE
# 10223 109945       ensemble  Non-white or Hispanic/Latino    FALSE
# 10224  61967       ensemble  Annual income < $25k            FALSE
# 10225  22665       ensemble  Less than high school education FALSE
# 10226  61862       ensemble  Age >= 65                       FALSE
# 10227  54129       ensemble  No UBR categorization           FALSE
# 10228 230430       ensemble  Entire population               FALSE
# 10229  33195       ensemble  Sexual and gender minorities    FALSE
# 10230 110730       ensemble  Non-white or Hispanic/Latino    FALSE
# 10231  62447       ensemble  Annual income < $25k            FALSE
# 10232  22816       ensemble  Less than high school education FALSE
# 10233  62709       ensemble  Age >= 65                       FALSE
# 10234  54560       ensemble  No UBR categorization           FALSE
#       Endpoint     is_cardiac_dbl
# 1     Phenome-wide 0
# 2     Phenome-wide 0
# 3     Phenome-wide 0
# 4     Phenome-wide 0
# 5     Phenome-wide 0
# 6     Phenome-wide 0
# 7     Phenome-wide 0
# 8     Phenome-wide 0
# 9     Phenome-wide 0
# 10    Phenome-wide 0
# 11    Phenome-wide 0
# 12    Phenome-wide 0
# 13    Phenome-wide 0
# 14    Phenome-wide 0
# 15    Phenome-wide 0
# 16    Phenome-wide 0
# 17    Phenome-wide 0
# 18    Phenome-wide 0
# 19    Phenome-wide 0
# 20    Phenome-wide 0
# 21    Phenome-wide 0
# 22    Phenome-wide 0
# 23    Phenome-wide 0
# 24    Phenome-wide 0
# 25    Phenome-wide 0
# 26    Phenome-wide 0
# 27    Phenome-wide 0
# 28    Phenome-wide 0
# 29    Phenome-wide 0
# 30    Phenome-wide 0
# ⋮     ⋮            ⋮
# 10205 Phenome-wide 0
# 10206 Phenome-wide 0
# 10207 Phenome-wide 0
# 10208 Phenome-wide 0
# 10209 Phenome-wide 0
# 10210 Phenome-wide 0
# 10211 Phenome-wide 0
# 10212 Phenome-wide 0
# 10213 Phenome-wide 0
# 10214 Phenome-wide 0
# 10215 Phenome-wide 0
# 10216 Phenome-wide 0
# 10217 Phenome-wide 0
# 10218 Phenome-wide 0
# 10219 Phenome-wide 0
# 10220 Phenome-wide 0
# 10221 Phenome-wide 0
# 10222 Phenome-wide 0
# 10223 Phenome-wide 0
# 10224 Phenome-wide 0
# 10225 Phenome-wide 0
# 10226 Phenome-wide 0
# 10227 Phenome-wide 0
# 10228 Phenome-wide 0
# 10229 Phenome-wide 0
# 10230 Phenome-wide 0
# 10231 Phenome-wide 0
# 10232 Phenome-wide 0
# 10233 Phenome-wide 0
# 10234 Phenome-wide 0

# %%
results_cardiac = arrow::read_feather(glue("{base_path}/230503_result_ukbbparams_ubr_cardiac_arrest_delta_clean_cindices_revision_ensemble.feather"))

# %%
results_cardiac = results_cardiac %>% mutate(Group=score)

# %%
results_cardiac
# Out:
#      index delta_cindex score                           endpoint    num_events
# 1     0    0.1828363    Age >= 65                       phecode_420  376
# 2     1    0.1668807    Annual income < $25k            phecode_420  421
# 3     2    0.1906414    At least one UBR categorization phecode_420 1006
# 4     3    0.1853374    Entire population               phecode_420 1154
# 5     4    0.1818571    Less than high school education phecode_420  180
# 6     5    0.1680170    No UBR categorization           phecode_420  154
# 7     6    0.1778026    Non-white or Hispanic/Latino    phecode_420  586
# 8     7    0.2107366    Sexual and gender minorities    phecode_420  138
# 9     8    0.2342592    Age >= 65                       phecode_420  382
# 10    9    0.1957920    Annual income < $25k            phecode_420  448
# 11   10    0.2095672    At least one UBR categorization phecode_420 1002
# 12   11    0.2043444    Entire population               phecode_420 1153
# 13   12    0.2141477    Less than high school education phecode_420  153
# 14   13    0.1657938    No UBR categorization           phecode_420  154
# 15   14    0.1949754    Non-white or Hispanic/Latino    phecode_420  591
# 16   15    0.1966189    Sexual and gender minorities    phecode_420  156
# 17   16    0.2244020    Age >= 65                       phecode_420  387
# 18   17    0.1783946    Annual income < $25k            phecode_420  408
# 19   18    0.2133408    At least one UBR categorization phecode_420  963
# 20   19    0.2104815    Entire population               phecode_420 1129
# 21   20    0.2049393    Less than high school education phecode_420  180
# 22   21    0.1926193    No UBR categorization           phecode_420  171
# 23   22    0.1874042    Non-white or Hispanic/Latino    phecode_420  535
# 24   23    0.2101723    Sexual and gender minorities    phecode_420  160
# 25   24    0.2065328    Age >= 65                       phecode_420  391
# 26   25    0.1632744    Annual income < $25k            phecode_420  432
# 27   26    0.1965903    At least one UBR categorization phecode_420  989
# 28   27    0.1975904    Entire population               phecode_420 1147
# 29   28    0.1887492    Less than high school education phecode_420  159
# 30   29    0.1948541    No UBR categorization           phecode_420  162
# ⋮    ⋮     ⋮            ⋮                               ⋮           ⋮
# 7971 7970  0.2033440    At least one UBR categorization phecode_420  978
# 7972 7971  0.2010766    Entire population               phecode_420 1145
# 7973 7972  0.1972358    Less than high school education phecode_420  147
# 7974 7973  0.1711422    No UBR categorization           phecode_420  173
# 7975 7974  0.1903971    Non-white or Hispanic/Latino    phecode_420  588
# 7976 7975  0.2004416    Sexual and gender minorities    phecode_420  165
# 7977 7976  0.2070788    Age >= 65                       phecode_420  367
# 7978 7977  0.2071740    Annual income < $25k            phecode_420  416
# 7979 7978  0.2267988    At least one UBR categorization phecode_420  940
# 7980 7979  0.2178508    Entire population               phecode_420 1089
# 7981 7980  0.1936012    Less than high school education phecode_420  155
# 7982 7981  0.1838536    No UBR categorization           phecode_420  157
# 7983 7982  0.1944398    Non-white or Hispanic/Latino    phecode_420  561
# 7984 7983  0.2083433    Sexual and gender minorities    phecode_420  157
# 7985 7984  0.2253753    Age >= 65                       phecode_420  362
# 7986 7985  0.1855160    Annual income < $25k            phecode_420  390
# 7987 7986  0.2168885    At least one UBR categorization phecode_420  928
# 7988 7987  0.2142158    Entire population               phecode_420 1070
# 7989 7988  0.2109157    Less than high school education phecode_420  156
# 7990 7989  0.2234975    No UBR categorization           phecode_420  147
# 7991 7990  0.1922782    Non-white or Hispanic/Latino    phecode_420  561
# 7992 7991  0.1703801    Sexual and gender minorities    phecode_420  134
# 7993 7992  0.1966236    Age >= 65                       phecode_420  360
# 7994 7993  0.2061629    Annual income < $25k            phecode_420  417
# 7995 7994  0.2086782    At least one UBR categorization phecode_420  934
# 7996 7995  0.2077162    Entire population               phecode_420 1091
# 7997 7996  0.2288027    Less than high school education phecode_420  174
# 7998 7997  0.2032077    No UBR categorization           phecode_420  161
# 7999 7998  0.1975215    Non-white or Hispanic/Latino    phecode_420  536
# 8000 7999  0.2162309    Sexual and gender minorities    phecode_420  158
#      num_included uuid
# 1     62309       100119480074737567420412586714933100548
# 2     61249       100119480074737567420412586714933100548
# 3    178248       100119480074737567420412586714933100548
# 4    231083       100119480074737567420412586714933100548
# 5     22603       100119480074737567420412586714933100548
# 25   Age >= 65
# 26   Annual income < $25k
# 27   At least one UBR categorization
# 28   Entire population
# 29   Less than high school education
# 30   No UBR categorization
# ⋮    ⋮
# 7971 At least one UBR categorization
# 7972 Entire population
# 7973 Less than high school education
# 7974 No UBR categorization
# 7975 Non-white or Hispanic/Latino
# 7976 Sexual and gender minorities
# 7977 Age >= 65
# 7978 Annual income < $25k
# 7979 At least one UBR categorization
# 7980 Entire population
# 7981 Less than high school education
# 7982 No UBR categorization
# 7983 Non-white or Hispanic/Latino
# 7984 Sexual and gender minorities
# 7985 Age >= 65
# 7986 Annual income < $25k
# 7987 At least one UBR categorization
# 7988 Entire population
# 7989 Less than high school education
# 7990 No UBR categorization
# 7991 Non-white or Hispanic/Latino
# 7992 Sexual and gender minorities
# 7993 Age >= 65
# 7994 Annual income < $25k
# 7995 At least one UBR categorization
# 7996 Entire population
# 7997 Less than high school education
# 7998 No UBR categorization
# 7999 Non-white or Hispanic/Latino
# 8000 Sexual and gender minorities

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) +
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0),
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=6, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major.y=element_line()))

plot_width = 8.25; plot_height=2.5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

#temp = benchmark_endpoints %>%
#    filter(score %in% scores_plot) %>%
#    mutate(score = factor(score, levels=scores_plot)) %>%
#    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%

groups_sorted = c('Entire population', 'No UBR categorization', 'At least one UBR categorization', 'Age >= 65', 'Annual income < $25k', 'Less than high school education', 'Non-white or Hispanic/Latino', 'Sexual and gender minorities')

fig_cardiac = results_cardiac %>% 
  mutate(Group=factor(Group, levels=groups_sorted)) %>%
  filter(Group != "Entire population") %>%
  filter(Group != "At least one UBR categorization") %>%
  ggplot(aes(x = Group, y = delta_cindex)) +
    #geom_boxplot(outlier.alpha = 0.25) + 
    stat_pointinterval(size=0.5, alpha=0.7)+
    #geom_signif(
    #  comparisons = list(
    #    c("No UBR categorization", "Age >= 65"), 
    #    c("No UBR categorization", "Annual income < $25k"),
    #    c("No UBR categorization", "Less than high school education"),
    #    c("No UBR categorization", "Non-white or Hispanic/Latino"),
    #    c("No UBR categorization", "Sexual and gender minorities")),
    #  map_signif_level = TRUE,
    #  test=wilcox.test,
    #  step_increase=0.08,
    #  vjust=0.5
    #) + 
  coord_cartesian(ylim=c(0, 0.3), clip = "on")+
  #stat_dotsinterval(side = "right", scale = 0.5, slab_size = NA) +
  scale_fill_brewer(palette="Set1") + 
  labs(x="Group", y="Delta C-Index\nover age and sex") + 
    theme(axis.title.x=element_blank(),
      panel.grid.major=element_blank(),
      strip.text = element_text(angle=270, hjust=1)
    ) +
    theme(legend.position="none") + 
  scale_x_discrete(labels = function(x) str_wrap(x, width = 10))


combined = fig_phenome | fig_cardiac
combined
# Out:
# plot without title

# %%
figure_path = "/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/figures/220823_allofus/230502_revision/"
plot_name = "Figure4c_subgroups"
combined %>% ggsave(filename=glue("{figure_path}/{plot_name}.png"), device="png", width=plot_width, height=plot_height, dpi=plot_res)
combined %>% ggsave(filename=glue("{figure_path}/{plot_name}.pdf"), device="pdf", width=plot_width, height=plot_height, dpi=plot_res)

# %%
c(c("No UBR categorization", "Age >= 65"), c("No UBR categorization", "Annual income < $25k"))
# Out:
# [1] "No UBR categorization" "Age >= 65"             "No UBR categorization"
# [4] "Annual income < $25k"

# %%
install.packages("PMCMRplus")
# Out:
# also installing the dependencies ‘gmp’, ‘Rmpfr’
#
#
# Warning message in install.packages("PMCMRplus"):
# “installation of package ‘gmp’ had non-zero exit status”
# Warning message in install.packages("PMCMRplus"):
# “installation of package ‘Rmpfr’ had non-zero exit status”
# Warning message in install.packages("PMCMRplus"):
# “installation of package ‘PMCMRplus’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
install.packages("ggsignif")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
library(ggstatsplot)
library(ggsignif)
# Out:
# You can cite this package as:
#      Patil, I. (2021). Visualizations with statistical details: The 'ggstatsplot' approach.
#      Journal of Open Source Software, 6(61), 3167, doi:10.21105/joss.03167
#
#
# Attaching package: ‘ggstatsplot’
#
#
# The following object is masked from ‘package:data.table’:
#
#     :=

# %%
  geom_boxplot() + 
  #stat_halfeye(side='left', scale=0.5) + 
  coord_cartesian(ylim=c(0.7, 0.95), clip = "on")+
  #stat_dotsinterval(side = "right", scale = 0.5, slab_size = NA) +
  scale_fill_brewer(palette="Set1") + 
  labs(x="Group", y="C-Index") + 
    theme(axis.title.x=element_blank(),
      panel.grid.major=element_blank(),
      strip.text = element_text(angle=270, hjust=1)
    ) +
    theme(legend.position="none") + 
  scale_x_discrete(labels = function(x) str_wrap(x, width = 10))

# %%
results %>%
    mutate(Group=factor(Group)) %>%
    group_by(Group) %>%
    median_qi(cindex, .width = 0.95)
# Out:
#   Group                           cindex    .lower    .upper    .width .point
# 1 Age >= 65                       0.6701482 0.5421154 0.8245080 0.95   median
# 2 Annual income < $25k            0.7119549 0.5513737 0.8567299 0.95   median
# 3 At least one UBR categorization 0.7066735 0.5581413 0.8569858 0.95   median
# 4 Entire population               0.7036726 0.5607214 0.8595672 0.95   median
# 5 Less than high school education 0.7104032 0.5334177 0.8744769 0.95   median
# 6 No UBR categorization           0.6891180 0.5407752 0.8686168 0.95   median
# 7 Non-white or Hispanic/Latino    0.7133847 0.5500133 0.8687870 0.95   median
# 8 Sexual and gender minorities    0.7054237 0.5516209 0.8704998 0.95   median
#   .interval
# 1 qi
# 2 qi
# 3 qi
# 4 qi
# 5 qi
# 6 qi
# 7 qi
# 8 qi

# %%
results[, list(list(boot(.SD, stat, R = 10))), by = Group]$V1
# Out:
# Error in boot(.SD, stat, R = 10): no data in call to 'boot'
# Traceback:
#
# 1. results[, list(list(boot(.SD, stat, R = 10))), by = Group]
# 2. `[.tbl_df`(results, , list(list(boot(.SD, stat, R = 10))), by = Group)
# 3. boot(.SD, stat, R = 10)
# 4. stop("no data in call to 'boot'")

# %%
  results %>%
    group_by(Group) %>% 
    bootstrap(., 10) %>% 
    do(tidy(median(cindex)))
# Out:
# Error in bootstrap(., 10): could not find function "bootstrap"
# Traceback:
#
# 1. results %>% group_by(Group) %>% bootstrap(., 10) %>% do(tidy(median(cindex)))
# 2. do(., tidy(median(cindex)))

# %%
install.packages(groupwiseMedian)
library(groupwiseMedian)
# Out:
# Error in install.packages(groupwiseMedian): object 'groupwiseMedian' not found
# Traceback:
#
# 1. install.packages(groupwiseMedian)

# %%
devtools::install_github("DavisVaughan/strapgod")
# Out:
# Error in loadNamespace(name): there is no package called ‘devtools’
# Traceback:
#
# 1. devtools::install_github
# 2. getExportedValue(pkg, name)
# 3. asNamespace(ns)
# 4. getNamespace(ns)
# 5. loadNamespace(name)
# 6. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 7. withOneRestart(expr, restarts[[1L]])
# 8. doWithOneRestart(return(expr), restart)

# %%
install.packages('tidymodels')
library(tidymodels)
# Out:
# also installing the dependencies ‘warp’, ‘lhs’, ‘DiceDesign’, ‘furrr’, ‘slider’, ‘GPfit’, ‘conflicted’, ‘dials’, ‘infer’, ‘modeldata’, ‘parsnip’, ‘rsample’, ‘tune’, ‘workflows’, ‘workflowsets’, ‘yardstick’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.1.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.3     ✔ workflows    1.1.0
# ✔ modeldata    1.0.1     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.1     ✔ yardstick    1.1.0
# ✔ recipes      1.0.1
#
# Warning message:
# “package ‘broom’ was built under R version 4.0.5”
# Warning message:
# “package ‘scales’ was built under R version 4.0.5”
# Warning message:
# “package ‘recipes’ was built under R version 4.0.5”
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ data.table::between()   masks dplyr::between()
# ✖ scales::discard()       masks purrr::discard()
# ✖ dplyr::filter()         masks stats::filter()
# ✖ data.table::first()     masks dplyr::first()
# ✖ recipes::fixed()        masks stringr::fixed()
# ✖ jsonlite::flatten()     masks purrr::flatten()
# ✖ dplyr::lag()            masks stats::lag()
# ✖ data.table::last()      masks dplyr::last()
# ✖ yardstick::spec()       masks readr::spec()
# ✖ Hmisc::src()            masks dplyr::src()
# ✖ recipes::step()         masks stats::step()
# ✖ Hmisc::summarize()      masks dplyr::summarize()
# ✖ parsnip::translate()    masks Hmisc::translate()
# ✖ data.table::transpose() masks purrr::transpose()
# • Use tidymodels_prefer() to resolve common conflicts.

# %%
median_as_tibble <- function(split) {
  dat <- analysis(split)
  tibble(
    term = "median",
    estimate = median(dat$cindex),
    # don't know the analytical std.err so no t-intervals
    std.err = NA_real_
  )
}

results %>%
    filter(Group == 'Entire population') %>%
    bootstraps(times = 1000, apparent = TRUE) %>%
    mutate(value = map(splits, median_as_tibble)) %>%
    int_pctl(value)
# Out:
#   term   .lower    .estimate .upper    .alpha .method
# 1 median 0.6992978 0.7039473 0.7097946 0.05   percentile

# %%
median_as_tibble <- function(split) {
  dat <- analysis(split)
  tibble(
    term = "median",
    estimate = median(dat$cindex),
    # don't know the analytical std.err so no t-intervals
    std.err = NA_real_
  )
}

bootstrap_median <- function(group) {
    group %>%
    bootstraps(times = 1000, apparent = TRUE) %>%
    mutate(value = map(splits, median_as_tibble)) %>%
    int_pctl(value)
}

# %%
options(digits = 3) 

results %>% 
     select(Group, cindex) %>% 
     group_by(Group) %>%
     group_modify(~ bootstrap_median(.x), .keep = TRUE)
# Out:
#   Group                           term   .lower .estimate .upper .alpha
# 1 Age >= 65                       median 0.666  0.670     0.673  0.05
# 2 Annual income < $25k            median 0.708  0.713     0.719  0.05
# 3 At least one UBR categorization median 0.701  0.706     0.712  0.05
# 4 Entire population               median 0.699  0.704     0.710  0.05
# 5 Less than high school education median 0.704  0.710     0.715  0.05
# 6 No UBR categorization           median 0.684  0.689     0.695  0.05
# 7 Non-white or Hispanic/Latino    median 0.709  0.713     0.719  0.05
# 8 Sexual and gender minorities    median 0.701  0.706     0.711  0.05
#   .method
# 1 percentile
# 2 percentile
# 3 percentile
# 4 percentile
# 5 percentile
# 6 percentile
# 7 percentile
# 8 percentile

# %%
results %>% boot(statistic = function(x,i) median(x %>% select(cindex)),R = 1000)
# Out:
# Error in median.default(x %>% select(cindex)): need numeric data
# Traceback:
#
# 1. results %>% boot(statistic = function(x, i) median(x %>% select(cindex)),
#  .     R = 1000)
# 2. boot(., statistic = function(x, i) median(x %>% select(cindex)),
#  .     R = 1000)
# 3. statistic(data, original, ...)
# 4. median(x %>% select(cindex))   # at line 1 of file <text>
# 5. median.default(x %>% select(cindex))
# 6. stop("need numeric data")

# %%
results %>% 
     select(Group, cindex) %>% 
     group_by(Group) %>%
     group_map(~ boot(cindex, statistic=median,R = 10))
     
     
     # %>% 
     #group_map(~ smean.cl.boot(., conf.int = .95, B = 1000, na.rm = TRUE))# %>%
     #bind_rows()
# Out:
# Error in NROW(data): object 'cindex' not found
# Traceback:
#
# 1. results %>% select(Group, cindex) %>% group_by(Group) %>% group_map(~boot(cindex,
#  .     statistic = median, R = 10))
# 2. group_map(., ~boot(cindex, statistic = median, R = 10))
# 3. group_map.data.frame(., ~boot(cindex, statistic = median, R = 10))
# 4. map2(chunks, group_keys, .f, ...)
# 5. mapply(.f, .x, .y, MoreArgs = list(...), SIMPLIFY = FALSE)
# 6. (structure(function (..., .x = ..1, .y = ..2, . = ..1)
#  . boot(cindex, statistic = median, R = 10), class = c("rlang_lambda_function",
#  . "function")))(dots[[1L]][[1L]], dots[[2L]][[1L]])
# 7. boot(cindex, statistic = median, R = 10)
# 8. NROW(data)

# %%
    mutate(score = factor(score, levels=scores_plot)) %>%
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    ungroup() %>%
    pivot_wider(names_from=score, values_from=cindex, id_cols=c(uuid, partition, endpoint, phecode_category, phecode_string, num_events)) %>%
    mutate(id = row_number()) %>%
    rename(score1 = scores_plot[1], score2 = scores_plot[2]) %>%
    mutate(delta=score2 - score1) %>%
    group_by(endpoint, phecode_string, phecode_category) %>%
    median_qi(num_events, delta, score1, score2) %>%
    #mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
    mutate(endpoint = fct_reorder(endpoint, delta)) %>%
    mutate(highlight = case_when(endpoint %in% endpoint_selection ~ "YES", TRUE ~ "NO")) %>%# %>% filter(endpoint %in% endpoint_sample)
    mutate(phecode_category = factor(phecode_category, levels=categories_sorted))

temp_num_events

# %%
  stat_dotsinterval(side = "right", scale = 0.5, slab_size = NA) +
  #scale_fill_brewer(palette = "Set3") +
  scale_fill_brewer(palette="Set1") + 
  labs(x="Group", y="C-Index") + 
    theme(axis.title.x=element_blank(),
      panel.grid.major=element_blank(),
      strip.text = element_text(angle=270, hjust=1)
    ) +
    theme(legend.position="none")

# %%
overview = ggplot(temp) +
    geom_ribbon(aes(x=endpoint, ymin=0, ymax=delta), fill="black", alpha=0.2)+
    geom_point(aes(x=endpoint, y=delta, color=highlight, size=highlight, alpha=highlight)) +
    geom_text(data=temp %>% filter(highlight=="YES"), aes(x=endpoint, y=delta+0.1, label="↓"), color="black", size=5, alpha=0.7) +
    #geom_segment(aes(x=endpoint, xend=endpoint, y=0, yend=delta, color=highlight, size=highlight), alpha=0.5)+#+
    labs(x="Endpoints", y="Delta C-Index")+
    scale_color_manual(values=c("NO"="black", "YES"="firebrick"))+
    scale_alpha_manual(values=c("NO"=0.1, "YES"=1))+
    scale_size_manual(values=c("NO"=0.01, "YES"=1))+
    #scale_colour_manual(values = c("pos"="forestgreen", "neg" = "firebrick")) +
    #coord_polar() +
    coord_cartesian(ylim=c(-0.3, 0.3), clip = "off")+
    scale_y_continuous(expand=c(0, 0))+
    scale_x_discrete(expand=expansion(add=20))+
    facet_grid(~phecode_category, scales="free_x", space="free_x")+#, switch=TRUE)+
    #facet_grid2(~phecode_category, scales = "free", independent = "all") +
    theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
        panel.grid.major=element_blank(),
         strip.text = element_text(angle=270, hjust=1)) +
    theme(legend.position="none")

    #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
#geom_violin(size=0.1)
overview

# %%
endpoint_defs = arrow::read_feather(glue("{base_path}/phecode_defs_220306.feather")) %>% arrange(endpoint)
endpoints_md = fread(glue("{base_path}/endpoints.csv"), colClasses=c("phecode"="character"))
endpoints = sort(endpoints_md$endpoint)

glue("{base_path}/phecode_defs_220306.feather")
# Out:
# /sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220823_allofus/phecode_defs_220306.feather

# %%
endpoint_map = endpoint_defs$phecode_string
names(endpoint_map) =  endpoint_defs$endpoint
endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) +
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0),
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major.y=element_line()))

# %%
endpoint_selection = c(

   'phecode_401', #  "Hypertension", # intervention
    'phecode_202', #  "Diabetes mellitus", # intervention
    'phecode_416-21', #  "Atrial fibrillation", # intervention
    'phecode_468', #  "Pneumonia", # intervention
    'phecode_474', #  "Chronic obstructive pulmonary disease [COPD]", # interventio
    'phecode_583', #  "Chronic kidney disease", # intervention

    'phecode_404', #  "Ischemic heart disease",
    'phecode_404-1', #  "Myocardial infarction [Heart attack]", # intervention
    'phecode_431-11', #  "Cerebral infarction [Ischemic stroke]",
    'phecode_424', #  "Heart failure", # intervention
    'phecode_420', #  "Cardiac arrest", # intervention
    'OMOP_4306655', #  "All-Cause Death", # intervention

    'phecode_438-11',   #  "Abdominal aortic aneurysm",
    'phecode_440-3',#  "Pulmonary embolism", # intervention
    'phecode_413-21',#  "Aortic stenosis", # intervention
    'phecode_413-11', #  "Mitral valve insufficiency",
    'phecode_410-2',#  "Endocarditis",
    'phecode_400',#  "Rheumatic fever and chronic rheumatic heart diseases",

    'phecode_164', #  "Anemia", # intervention
    'phecode_718',  #  "Back pain", # intervention
    'phecode_324-11', #  "Parkinson's disease (Primary)",
    'phecode_705-1', #  "Rheumatoid arthritis", # NEW + interventio
    'phecode_665', #  "Psoriasis", # interesting
    'phecode_284'#  "Suicide ideation and attempt or self harm" # intervention
)
endpoint_defs = endpoint_defs %>%
    mutate(name = phecode_string) %>%
    mutate(name =
           case_when(
               phecode_string == "Myocardial infarction [Heart attack]"~"Myocardial infarction",
               phecode_string == "Cerebral infarction [Ischemic stroke]"~"Ischemic stroke",
               phecode_string == "Chronic obstructive pulmonary disease [COPD]"~"COPD",
               phecode_string == "Mitral valve insufficiency"~"Mitral insufficiency",
               phecode_string == "Parkinson's disease (Primary)"~"Parkinson's",
               phecode_string == "Suicide ideation and attempt or self harm"~"Suicide attempt",
               phecode_string == "Ischemic heart disease"~"Ischemic HD",
               phecode_string == "Chronic kidney disease"~"Chronic KD",
               phecode_string == "Rheumatic fever and chronic rheumatic heart diseases"~"Rheumatic HD",
               phecode_string == "Abdominal aortic aneurysm"~"Abdominal AA",
                  TRUE ~ name)
           )

endpoint_map = endpoint_defs$name
names(endpoint_map) =  endpoint_defs$endpoint
#endpoint_order = (endpoint_defs %>% arrange(as.numeric(phecode)))$endpoint
endpoint_order = endpoint_selection

# %%
name = "220831_bootstrap_results"
benchmark_endpoints = arrow::read_feather(glue("{base_path}/{name}.feather"))

# %%
benchmark_endpoints = benchmark_endpoints %>% group_by(endpoint, uuid) %>% filter(all(!is.na(cindex))) %>% ungroup()

# %%
benchmark_endpoints = setDT(benchmark_endpoints)[, endpoint := str_replace(endpoint, "\\.", "-")] %>% as_tibble()

# %%
benchmark_endpoints = benchmark_endpoints %>% left_join(endpoints_md)
# Out:
# Joining, by = "endpoint"

# %%
benchmark_endpoints %>% select(phecode_string) %>% filter(is.na(phecode_string))
# Out:
#      phecode_string

# %%
benchmark_endpoints %>% group_by(endpoint, score)  %>% summarise(cindex=mean(cindex)) %>% group_by(score) %>% summarise(mean(cindex)) %>% arrange(`mean(cindex)`)
# Out:
# `summarise()` has grouped output by 'endpoint'. You can override using the
# `.groups` argument.
#   score                            mean(cindex)
# 1 AgeSex_AoUCPH                    0.6318432
# 2 AgeSex+MedicalHistory_UKBBParams 0.7094673
# 3 AgeSex+MedicalHistory_AoUCPH     0.7332246

# %%
endpoints_sorted = (benchmark_endpoints %>%
    filter(score == "AgeSex+MedicalHistory_UKBBParams") %>%
    group_by(endpoint, score) %>%
    summarise(cindex=mean(cindex, na.rm=TRUE)) %>%
    arrange(cindex) %>% ungroup())$endpoint
# Out:
# `summarise()` has grouped output by 'endpoint'. You can override using the
# `.groups` argument.

# %%
categories_sorted = (endpoint_defs %>% distinct(phecode_category))$phecode_category

# %%
temp_num_events = benchmark_endpoints %>%
    filter(score %in% scores_plot) %>%
    mutate(score = factor(score, levels=scores_plot)) %>%
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    ungroup() %>%
    pivot_wider(names_from=score, values_from=cindex, id_cols=c(uuid, partition, endpoint, phecode_category, phecode_string, num_events)) %>%
    mutate(id = row_number()) %>%
    rename(score1 = scores_plot[1], score2 = scores_plot[2]) %>%
    mutate(delta=score2 - score1) %>%
    group_by(endpoint, phecode_string, phecode_category) %>%
    median_qi(num_events, delta, score1, score2) %>%
    #mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
    mutate(endpoint = fct_reorder(endpoint, delta)) %>%
    mutate(highlight = case_when(endpoint %in% endpoint_selection ~ "YES", TRUE ~ "NO")) %>%# %>% filter(endpoint %in% endpoint_sample)
    mutate(phecode_category = factor(phecode_category, levels=categories_sorted))

temp_num_events
# Out:
#      endpoint
# 1    phecode_441-1
# 2    phecode_168-21
# 3    phecode_209-22
# 4    phecode_084-2
# 5    phecode_168-2
# 6    phecode_110-4
# 7    phecode_209-2
# 8    phecode_174-1
# 9    phecode_979
# 10   phecode_054-2
# 11   phecode_978
# 12   phecode_540-2
# 13   phecode_540-1
# 14   phecode_589
# 15   phecode_355-21
# 16   phecode_069
# 17   phecode_283-8
# 18   phecode_124-7
# 19   phecode_540-3
# 20   phecode_719-3
# 21   phecode_054
# 22   phecode_168-3
# 23   phecode_012
# 24   phecode_098
# 25   phecode_004
# 26   phecode_149-4
# 27   phecode_052-31
# 28   phecode_343-5
# 29   phecode_724
# 30   phecode_809
# ⋮    ⋮
# 1719 phecode_688-6
# 1720 phecode_208-22
# 1721 phecode_444-13
# 1722 phecode_374-42
# 1723 phecode_413-6
# 1724 phecode_583-1
# 1725 phecode_374-512
# 1726 phecode_328-1
# 1727 phecode_168-12
# 1728 phecode_586-5
# 1729 phecode_328-7
# 1730 phecode_337-8
# 1731 phecode_419-2
# 1732 phecode_103-3
# 1733 phecode_419
# 1734 phecode_249-1
# 1735 phecode_328-2
# 1736 phecode_416-3
# 1737 phecode_542-5
# 1738 phecode_608-1
# 1739 phecode_205-3
# 1740 phecode_209-23
# 1741 phecode_414-5
# 1742 phecode_416-213
# 1743 phecode_416-212
# 1744 phecode_416-222
# 1745 phecode_584-1
# 1746 phecode_979-2
# 1747 phecode_328-4
# 1748 phecode_416-214
#      phecode_string
# 1    Arteriovenous fistula
# 2    Primary hypercoagulable state [Primary thrombophilia]
# 3    Hypopituitarism NOS
# 4    Malaria [Plasmodium]
# 5    Hyper-coagulability
# 6    Malignant neoplasm of the pituitary gland and craniopharyngeal duct
# 7    Hypopituitarism
# 8    Hyposplenism*
# 9    Transplated organ
# 10   Hepatitis B
# 11   Tissue transplant or graft
# 12   Acute hepatitis
# 13   Chronic hepatitis
# 14   Pathological lesions of kidney
# 15   Transient alteration of awareness
# 16   Other specified viral infections
# 17   Other problems related to lifestyle
# 18   Chronic myeloproliferative disease
# 19   Viral hepatitits
# 20   Separation of muscle (nontraumatic)
# 21   Hepatovirus
# 22   Hereditary deficiency of other clotting factors
# 23   Proteus
# 24   Carrier or suspected carrier of infectious diseases
# 25   Streptococcus
# 26   Benign neoplasm of the pituitary gland and craniopharyngeal duct
# 27   Varicella [chickenpox]
# 1728 0.8646898    0.8984112    0.95   median qi        NO
# 1729 0.8623186    0.8958798    0.95   median qi        NO
# 1730 0.8747498    0.8887812    0.95   median qi        NO
# 1731 0.8349583    0.9222456    0.95   median qi        NO
# 1732 0.8736159    0.8943396    0.95   median qi        NO
# 1733 0.8653592    0.9050638    0.95   median qi        NO
# 1734 0.8431124    0.9229058    0.95   median qi        NO
# 1735 0.8430257    0.9282419    0.95   median qi        NO
# 1736 0.8657341    0.9124598    0.95   median qi        NO
# 1737 0.8596931    0.9291426    0.95   median qi        NO
# 1738 0.8899574    0.8989999    0.95   median qi        NO
# 1739 0.8628101    0.9313703    0.95   median qi        NO
# 1740 0.7905899    0.9966425    0.95   median qi        NO
# 1741 0.8944947    0.9146719    0.95   median qi        NO
# 1742 0.8969677    0.9138689    0.95   median qi        NO
# 1743 0.9016656    0.9196621    0.95   median qi        NO
# 1744 0.8945619    0.9282919    0.95   median qi        NO
# 1745 0.3013534    0.9897679    0.95   median qi        NO
# 1746 0.8937866    0.9346499    0.95   median qi        NO
# 1747 0.9001100    0.9539716    0.95   median qi        NO
# 1748 0.9273236    0.9474495    0.95   median qi        NO

# %%
temp_num_events %>% filter(delta.upper < 0)
# Out:
#    endpoint
# 1  phecode_168-21
# 2  phecode_084-2
# 3  phecode_355-21
# 4  phecode_069
# 5  phecode_283-8
# 6  phecode_168-3
# 7  phecode_012
# 8  phecode_098
# 9  phecode_004
# 10 phecode_343-5
# 11 phecode_299
# 12 phecode_232-1
# 13 phecode_339-1
# 14 phecode_280-8
# 15 phecode_339
# 16 phecode_280
# 17 phecode_229
# 18 phecode_826-4
# 19 phecode_418
# 20 phecode_280-82
# 21 phecode_281
# 22 phecode_230-1
# 23 phecode_500-4
# 24 phecode_281-2
# 25 phecode_104-3
# 26 phecode_104
# 27 phecode_823
# 28 phecode_112
# 29 phecode_674-23
# 30 phecode_680-2
# ⋮  ⋮
# 42 phecode_239-3
# 43 phecode_165-2
# 44 phecode_165-3
# 45 phecode_664-2
# 46 phecode_323-31
# 47 phecode_088
# 48 phecode_664-21
# 49 phecode_466-3
# 50 phecode_835
# 51 phecode_281-1
# 52 phecode_599-7
# 53 phecode_329-9
# 54 phecode_293-1
# 55 phecode_280-81
# 56 phecode_507-3
# 57 phecode_370-3
# 58 phecode_142-1
# 59 phecode_084-4
# 60 phecode_672
# 61 phecode_614-55
# 62 phecode_142
# 63 phecode_466-1
# 64 phecode_362-6
# 65 phecode_581-3
# 66 phecode_684-2
# 67 phecode_597
# 68 phecode_105
# 69 phecode_726-1
# 70 phecode_822-8
# 71 phecode_822
#    phecode_string
# 1  Primary hypercoagulable state [Primary thrombophilia]
# 2  Malaria [Plasmodium]
# 3  Transient alteration of awareness
# 4  Other specified viral infections
# 5  Other problems related to lifestyle
# 6  Hereditary deficiency of other clotting factors
# 7  Proteus
# 8  Carrier or suspected carrier of infectious diseases
# 9  Streptococcus
# 10 Horner's syndrome*
# 11 Mental disorder, not otherwise specified
# 12 Vitamin A deficiency
# 13 Muscular dystrophy
# 14 Other psychoactive substance related disorders
# 15 Primary disorders of muscles
# 16 Substance related disorders
# 17 Other endocrine disorders
# 18 Other and unspecified nonspecific immunological findings
# 19 Abnormal results of cardiovascular function studies
# 20 Other psychoactive substance dependence
# 21 Substance abuse, dependence, and withdrawl
# 22 Protein-calorie malnutrition
# 23 Disturbances in tooth eruption
# 24 Substance dependence
# 25 Malignant neoplasm of other connective and soft tissue
# 26 Malignant sarcoma-related cancers
# 27 Abnormal serum enzyme levels
# 28 Malignant neoplasm of other and ill-defined sites
# 29 Acanthosis nigricans
# 30 Keratoderma
# ⋮  ⋮
# 42 Mixed hyperlipidemia
# 43 Thalassemia
# 44 Hemoglobin C trait [Sickle-cell trait]
# 45 Pityriasis
# 46 Amyotrophic lateral sclerosis [ALS]
# 47 Sexually transmitted disease
# 48 Pityriasis rosea
# 49 Peritonsillar abscess
# 50 Cytology and pathology findings
# 51 Substance abuse
# 52 Urethral discharge
# 53 Delirium
# 54 Anorexia nervosa
# 55 Other psychoactive substance abuse
# 56 Oral leukoplakia
# 57 Vascular disorders of iris and ciliary body
# 58 Lump or mass in breast
# 59 Trichomoniasis
# 60 Other acute skin changes due to ultraviolet radiation
# 61 Candidiasis of vulva and vagina
# 62 Lump or mass in breast or nonspecific abnormal breast exam
# 63 Acute tonsillitis and adenoiditis
# 64 Dermatochalasis of eyelid
# 65 Obstructive and reflux uropathy
# 66 Hypertrichosis and hirsutism
# 67 Other disorders of urethra and urinary tract
# 68 Malignant neoplasm of the breast
# 69 Osteoporosis
# 70 Abnormal tumor markers
# 71 Other and nonspecific abnormal cytological, histological and immunological findings
#    phecode_category num_events num_events.lower num_events.upper delta
# 1  Blood              861.0      808.475          926.050        -0.26266100
# 2  ID                   4.0        1.000            8.000        -0.44249408
# 3  Neuro                1.0        1.000            3.600        -0.43574864
# 4  ID                  30.0       20.000           40.000        -0.17611023
# 5  Mental            1552.0     1481.950         1636.050        -0.13642172
# 6  Blood                6.0        2.000           11.000        -0.34302668
# 7  ID                   1.0        1.000            4.000        -0.44786887
# 8  ID                 750.0      700.900          807.525        -0.19859484
# 9  ID                3668.5     3553.950         3802.100        -0.19473109
# 10 Neuro                2.0        1.000            5.000        -0.48025541
# 11 Mental           18197.5    17913.450        18401.675        -0.01991253
# 12 Metab              116.5       95.475          138.525        -0.10740953
# 13 Neuro              104.0       82.475          123.525        -0.13077882
# 14 Mental            9325.0     9143.425         9508.025        -0.07060255
# 15 Neuro              126.0      106.000          148.000        -0.10193180
# 16 Mental           10530.5    10339.475        10708.675        -0.06076739
# 17 Endo             14634.0    14436.700        14843.625        -0.01389687
# 18 Signs/Symptoms     219.0      192.475          250.000        -0.07195213
# 19 Cardio           17436.0    17228.950        17668.825        -0.02054916
# 20 Mental            9148.5     8994.425         9326.575        -0.05118967
# 21 Mental            9858.0     9673.325        10030.550        -0.04648847
# 22 Metab            14361.0    14161.225        14598.525        -0.01101969
# 12 -0.18075106 -0.037698060 0.95   median qi        NO
# 13 -0.27942719 -0.050778798 0.95   median qi        NO
# 14 -0.08096298 -0.058186692 0.95   median qi        NO
# 15 -0.15993997 -0.029562901 0.95   median qi        NO
# 16 -0.06944642 -0.049201574 0.95   median qi        NO
# 17 -0.02087287 -0.007466382 0.95   median qi        NO
# 18 -0.13229318 -0.020465367 0.95   median qi        NO
# 19 -0.02561956 -0.016201046 0.95   median qi        NO
# 20 -0.06247777 -0.039818511 0.95   median qi        NO
# 21 -0.05534109 -0.038314808 0.95   median qi        NO
# 22 -0.01726355 -0.004643799 0.95   median qi        NO
# 23 -0.24045907 -0.097090333 0.95   median qi        NO
# 24 -0.03530850 -0.017647395 0.95   median qi        NO
# 25 -0.03296229 -0.011096833 0.95   median qi        NO
# 26 -0.03093037 -0.014779919 0.95   median qi        NO
# 27 -0.04542195 -0.026240038 0.95   median qi        NO
# 28 -0.01623643 -0.008284632 0.95   median qi        NO
# 29 -0.17361862 -0.031805853 0.95   median qi        NO
# 30 -0.11464424 -0.076356788 0.95   median qi        NO
# ⋮  ⋮           ⋮            ⋮      ⋮      ⋮         ⋮
# 42 -0.06597282 -0.032987041 0.95   median qi        NO
# 43 -0.11318143 -0.001771492 0.95   median qi        NO
# 44 -0.13888298 -0.037764794 0.95   median qi        NO
# 45 -0.16531332 -0.009355498 0.95   median qi        NO
# 46 -0.21947987 -0.053272361 0.95   median qi        NO
# 47 -0.04442006 -0.004294096 0.95   median qi        NO
# 48 -0.15834422 -0.008976344 0.95   median qi        NO
# 49 -0.16940423 -0.039923680 0.95   median qi        NO
# 50 -0.04970515 -0.024896929 0.95   median qi        NO
# 51 -0.03807620 -0.012593512 0.95   median qi        NO
# 52 -0.26885794 -0.154680387 0.95   median qi        NO
# 53 -0.11574261 -0.006835202 0.95   median qi        NO
# 54 -0.23640111 -0.043389600 0.95   median qi        NO
# 55 -0.03110348 -0.003273351 0.95   median qi        NO
# 56 -0.09280650 -0.018391372 0.95   median qi        NO
# 57 -0.22358877 -0.080927647 0.95   median qi        NO
# 58 -0.04034957 -0.024072577 0.95   median qi        NO
# 59 -0.14244655 -0.068196370 0.95   median qi        NO
# 60 -0.04129195 -0.002261664 0.95   median qi        NO
# 61 -0.14889737 -0.068595880 0.95   median qi        NO
# 62 -0.04134876 -0.026070447 0.95   median qi        NO
# 63 -0.05884122 -0.012363493 0.95   median qi        NO
# 64 -0.09922170 -0.039416842 0.95   median qi        NO
# 65 -0.03046287 -0.010672992 0.95   median qi        NO
# 66 -0.08674701 -0.012361187 0.95   median qi        NO
# 67 -0.09405498 -0.058720627 0.95   median qi        NO
# 68 -0.02518279 -0.002337119 0.95   median qi        NO
# 69 -0.01787767 -0.004497135 0.95   median qi        NO
# 70 -0.07254456 -0.045608019 0.95   median qi        NO
# 71 -0.07253376 -0.045611863 0.95   median qi        NO

# %%
plot_width = 8.25; plot_height=2.5; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

library(ggtext)
library(ggdist)

scores_plot = c("AgeSex_AoUCPH", "AgeSex+MedicalHistory_UKBBParams")

temp = benchmark_endpoints %>%
    filter(score %in% scores_plot) %>%
    mutate(score = factor(score, levels=scores_plot)) %>%
    mutate(endpoint = factor(endpoint, levels=endpoints_sorted)) %>%
    ungroup() %>%
    pivot_wider(names_from=score, values_from=cindex, id_cols=c(uuid, partition, endpoint, phecode_category, phecode_string, num_events)) %>%
    mutate(id = row_number()) %>%
    rename(score1 = scores_plot[1], score2 = scores_plot[2]) %>%
    mutate(delta=score2 - score1) %>%
    group_by(endpoint, phecode_string, phecode_category) %>%
    median_qi(delta) %>%
    #mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
    mutate(endpoint = fct_reorder(endpoint, delta)) %>%
    mutate(highlight = case_when(endpoint %in% endpoint_selection ~ "YES", TRUE ~ "NO")) %>%# %>% filter(endpoint %in% endpoint_sample)
    mutate(phecode_category = factor(phecode_category, levels=categories_sorted))

# %%
temp
# Out:
#      endpoint
# 1    phecode_441-1
# 2    phecode_168-21
# 3    phecode_209-22
# 4    phecode_084-2
# 5    phecode_168-2
# 6    phecode_110-4
# 7    phecode_209-2
# 8    phecode_174-1
# 9    phecode_979
# 10   phecode_054-2
# 11   phecode_978
# 12   phecode_540-2
# 13   phecode_540-1
# 14   phecode_589
# 15   phecode_355-21
# 16   phecode_069
# 17   phecode_283-8
# 18   phecode_124-7
# 19   phecode_540-3
# 20   phecode_719-3
# 21   phecode_054
# 22   phecode_168-3
# 23   phecode_012
# 24   phecode_098
# 25   phecode_004
# 26   phecode_149-4
# 27   phecode_052-31
# 28   phecode_343-5
# 29   phecode_724
# 30   phecode_809
# ⋮    ⋮
# 1719 phecode_688-6
# 1720 phecode_208-22
# 1721 phecode_444-13
# 1722 phecode_374-42
# 1723 phecode_413-6
# 1724 phecode_583-1
# 1725 phecode_374-512
# 1726 phecode_328-1
# 1727 phecode_168-12
# 1728 phecode_586-5
# 1729 phecode_328-7
# 1730 phecode_337-8
# 1731 phecode_419-2
# 1732 phecode_103-3
# 1733 phecode_419
# 1734 phecode_249-1
# 1735 phecode_328-2
# 1736 phecode_416-3
# 1737 phecode_542-5
# 1738 phecode_608-1
# 1739 phecode_205-3
# 1740 phecode_209-23
# 1741 phecode_414-5
# 1742 phecode_416-213
# 1743 phecode_416-212
# 1744 phecode_416-222
# 1745 phecode_584-1
# 1746 phecode_979-2
# 1747 phecode_328-4
# 1748 phecode_416-214
#      phecode_string
# 1    Arteriovenous fistula
# 2    Primary hypercoagulable state [Primary thrombophilia]
# 3    Hypopituitarism NOS
# 4    Malaria [Plasmodium]
# 5    Hyper-coagulability
# 6    Malignant neoplasm of the pituitary gland and craniopharyngeal duct
# 7    Hypopituitarism
# 8    Hyposplenism*
# 9    Transplated organ
# 10   Hepatitis B
# 11   Tissue transplant or graft
# 12   Acute hepatitis
# 13   Chronic hepatitis
# 14   Pathological lesions of kidney
# 15   Transient alteration of awareness
# 16   Other specified viral infections
# 17   Other problems related to lifestyle
# 18   Chronic myeloproliferative disease
# 19   Viral hepatitits
# 20   Separation of muscle (nontraumatic)
# 21   Hepatovirus
# 22   Hereditary deficiency of other clotting factors
# 23   Proteus
# 24   Carrier or suspected carrier of infectious diseases
# 25   Streptococcus
# 26   Benign neoplasm of the pituitary gland and craniopharyngeal duct
# 27   Varicella [chickenpox]
# 28   Horner's syndrome*
# 29   Other symptoms and disorders of the soft tissue
# 30   Pain
# ⋮    ⋮
# 1719 Rheumatoid nodule*
# 1720 Secondary hyperparathyroidism
# 1721 Esophageal varix
# 1722 Diabetic retinopathy
# 1723 Heart valve replaced
# 1724 End stage renal disease [CDK, stage 5]
# 1725 Exuadative (wet) age-related macular degeneration
# 1726 Alzheimer's disease
# 1727 Hemorrhagic disorder due to intrinsic circulating anticoagulants
# 1728 Renal sclerosis, unspecified
# 1729 Vascular dementia
# 1730 Polyneuropathy in diseases classified elsewhere
# 1731 Presence of cardiac defibrillator
# 1732 Carcinoma in situ of skin
# 1733 Presence of cardiac device
# 1734 Cerebral amyloid angiopathy*
# 1735 Frontotemporal dementia
# 1736 Ventricular fibrillation and flutter
# 1737 Hepatorenal syndrome
# 1738 Abnormal findings in semen
# 1739 Drug-induced hypoglycemia*
# 1740 Iatrogenic hypopituitarism*
# 1741 Ischemic cardiomyopathy*
# 1742 Chronic atrial fibrillation*
# 1743 Persistent atrial fibrillation*
# 1744 Atypical atrial flutter*
# 1745 Renal dialysis
# 1746 Kidney transplant
# 1747 Dementia with Lewy bodies
# 1748 Permanent atrial fibrillation*
#      phecode_category delta        .lower       .upper        .width .point
# 1    Cardio           -0.486594891 -0.551437407  0.3539902858 0.95   median
# 2    Blood            -0.262660996 -0.294607645 -0.1240949425 0.95   median
# 3    Endo             -0.329952095 -0.394441043  0.1727290262 0.95   median
# 4    ID               -0.442494079 -0.815852612 -0.2483819302 0.95   median
# 5    Blood            -0.249456515 -0.284687262  0.1978014208 0.95   median
# 6    Neoplasms        -0.266717171 -0.428702066  0.2210712267 0.95   median
# 7    Endo             -0.250280463 -0.332260678  0.1205680975 0.95   median
# 8    Blood            -0.606466499 -0.914215070  0.2477878854 0.95   median
# 9    Stat             -0.397117471 -0.454792122  0.1961590202 0.95   median
# 10   ID               -0.247252793 -0.315766984  0.1122195665 0.95   median
# 11   Stat             -0.303059331 -0.389098646  0.1105247830 0.95   median
# 12   GI               -0.225940888 -0.272968240  0.1389156567 0.95   median
# 13   GI               -0.300760953 -0.337423783  0.0849380385 0.95   median
# 14   Genitourinary    -0.230617223 -0.401739110  0.2541217571 0.95   median
# 15   Neuro            -0.435748645 -0.462293710 -0.4179966985 0.95   median
# 16   ID               -0.176110234 -0.306051993 -0.0652080909 0.95   median
# 17   Mental           -0.136421720 -0.156865281 -0.1113566855 0.95   median
# 18   Neoplasms        -0.294230747 -0.391726223  0.0104965980 0.95   median
# 19   GI               -0.274172625 -0.307325244  0.0782069477 0.95   median
# 20   Musc/Skel        -0.156689342 -0.508709978  0.0661235137 0.95   median
# 21   ID               -0.272915372 -0.306930054  0.0783951347 0.95   median
# 22   Blood            -0.343026678 -0.666776871 -0.1208185578 0.95   median
# 23   ID               -0.447868870 -0.457738357 -0.4290857238 0.95   median
# 19   qi        NO
# 20   qi        NO
# 21   qi        NO
# 22   qi        NO
# 23   qi        NO
# 24   qi        NO
# 25   qi        NO
# 26   qi        NO
# 27   qi        NO
# 28   qi        NO
# 29   qi        NO
# 30   qi        NO
# ⋮    ⋮         ⋮
# 1719 qi        NO
# 1720 qi        NO
# 1721 qi        NO
# 1722 qi        NO
# 1723 qi        NO
# 1724 qi        NO
# 1725 qi        NO
# 1726 qi        NO
# 1727 qi        NO
# 1728 qi        NO
# 1729 qi        NO
# 1730 qi        NO
# 1731 qi        NO
# 1732 qi        NO
# 1733 qi        NO
# 1734 qi        NO
# 1735 qi        NO
# 1736 qi        NO
# 1737 qi        NO
# 1738 qi        NO
# 1739 qi        NO
# 1740 qi        NO
# 1741 qi        NO
# 1742 qi        NO
# 1743 qi        NO
# 1744 qi        NO
# 1745 qi        NO
# 1746 qi        NO
# 1747 qi        NO
# 1748 qi        NO

# %%
temp %>% filter(.lower > 0)
# Out:
#      endpoint
# 1    phecode_724
# 2    phecode_486
# 3    phecode_089
# 4    phecode_504-3
# 5    phecode_599
# 6    phecode_821
# 7    phecode_977
# 8    phecode_819
# 9    phecode_734-5
# 10   phecode_176
# 11   phecode_089-1
# 12   phecode_559
# 13   phecode_387-2
# 14   phecode_678
# 15   phecode_124-5
# 16   phecode_681
# 17   phecode_460
# 18   phecode_734
# 19   phecode_234
# 20   phecode_402
# 21   phecode_089-2
# 22   phecode_475
# 23   phecode_522
# 24   phecode_236
# 25   phecode_236-1
# 26   phecode_452
# 27   phecode_552-1
# 28   phecode_527
# 29   phecode_473
# 30   phecode_504-1
# ⋮    ⋮
# 1312 phecode_416-221
# 1313 phecode_123-1
# 1314 phecode_374-8
# 1315 phecode_540-4
# 1316 phecode_688-6
# 1317 phecode_208-22
# 1318 phecode_444-13
# 1319 phecode_374-42
# 1320 phecode_413-6
# 1321 phecode_583-1
# 1322 phecode_328-1
# 1323 phecode_168-12
# 1324 phecode_586-5
# 1325 phecode_328-7
# 1326 phecode_337-8
# 1327 phecode_419-2
# 1328 phecode_103-3
# 1329 phecode_419
# 1330 phecode_328-2
# 1331 phecode_416-3
# 1332 phecode_542-5
# 1333 phecode_205-3
# 1334 phecode_209-23
# 1335 phecode_414-5
# 1336 phecode_416-213
# 1337 phecode_416-212
# 1338 phecode_416-222
# 1339 phecode_979-2
# 1340 phecode_328-4
# 1341 phecode_416-214
#      phecode_string
# 1    Other symptoms and disorders of the soft tissue
# 2    Other respiratory disorders
# 3    Infections
# 4    Periodontitis
# 5    Other symptoms/disorders or the urinary system
# 6    Abnormality of red blood cells
# 7    Long term (current) drug therapy
# 8    General symptoms and other findings
# 9    Inflammatory conditions of jaw
# 10   Other diseases of blood and blood-forming organs
# 11   Bacterial infections
# 12   Other disease of digestive system, NOS
# 13   Myopia
# 14   Other skin and connective tissue disorders
# 15   Essential thrombocythemia
# 16   Localized swelling, mass and lump of skin and subcutaneous tissue
# 17   Acute respiratory infection
# 18   Diseases of the jaws
# 19   Other nutritional deficiencies
# 20   Elevated blood pressure reading without diagnosis of hypertension
# 21   Viral infections
# 22   Asthma
# 23   Gastrointestinal inflammation
# 24   Overweight and obesity
# 25   Obesity
# 26   Hemorrhage, NOS
# 27   Cholangitis
# 28   Abdominal pain
# 29   Other diseases of upper respiratory tract
# 30   Gingivitis
# ⋮    ⋮
# 1312 Typical atrial flutter*
# 1313 Multiple myeloma
# 1314 Retinal edema
# 1315 Alcoholic hepatitis
# 1316 Rheumatoid nodule*
# 1317 Secondary hyperparathyroidism
# 1318 Esophageal varix
# 1319 Diabetic retinopathy
# 1320 Heart valve replaced
# 1321 End stage renal disease [CDK, stage 5]
# 1322 Alzheimer's disease
# 1323 Hemorrhagic disorder due to intrinsic circulating anticoagulants
# 1324 Renal sclerosis, unspecified
# 1325 Vascular dementia
# 1326 Polyneuropathy in diseases classified elsewhere
# 1327 Presence of cardiac defibrillator
# 1328 Carcinoma in situ of skin
# 1329 Presence of cardiac device
# 1330 Frontotemporal dementia
# 1331 Ventricular fibrillation and flutter
# 1332 Hepatorenal syndrome
# 1333 Drug-induced hypoglycemia*
# 1334 Iatrogenic hypopituitarism*
# 1335 Ischemic cardiomyopathy*
# 1336 Chronic atrial fibrillation*
# 1337 Persistent atrial fibrillation*
# 1338 Atypical atrial flutter*
# 1339 Kidney transplant
# 1340 Dementia with Lewy bodies
# 1341 Permanent atrial fibrillation*
#      phecode_category delta       .lower       .upper     .width .point
# 1    Musc/Skel        0.007867683 0.0020082880 0.01311853 0.95   median
# 2    Resp             0.048586983 0.0429926555 0.05378074 0.95   median
# 3    ID               0.010629576 0.0041618792 0.01675308 0.95   median
# 4    GI               0.032107953 0.0082912811 0.05583427 0.95   median
# 5    Genitourinary    0.012417266 0.0079220392 0.01768279 0.95   median
# 6    Signs/Symptoms   0.027566106 0.0198067321 0.03330737 0.95   median
# 7    Rx               0.016595122 0.0113742091 0.02094760 0.95   median
# 8    Signs/Symptoms   0.013886132 0.0088453401 0.01827266 0.95   median
# 9    Musc/Skel        0.044532143 0.0272531326 0.06397998 0.95   median
# 10   Blood            0.050888420 0.0457645778 0.05558458 0.95   median
# 11   ID               0.018268296 0.0082796821 0.02845251 0.95   median
# 12   GI               0.065869883 0.0611735452 0.07128367 0.95   median
# 13   Eye              0.052818588 0.0426225485 0.06370373 0.95   median
# 14   Derm             0.071915918 0.0662976152 0.07637663 0.95   median
# 15   Neoplasms        0.037864204 0.0052970417 0.06875236 0.95   median
# 16   Derm             0.036269520 0.0314932957 0.04094898 0.95   median
# 17   Resp             0.023305337 0.0149268816 0.03325304 0.95   median
# 18   Musc/Skel        0.057187515 0.0456766659 0.06791147 0.95   median
# 19   Metab            0.008810213 0.0007424708 0.01722162 0.95   median
# 20   Cardio           0.067934042 0.0578333966 0.07824621 0.95   median
# 21   ID               0.057579735 0.0510971155 0.06344584 0.95   median
# 22   Resp             0.019105466 0.0066665621 0.02961578 0.95   median
# 23   GI               0.045478041 0.0374920270 0.05344918 0.95   median
# 23   qi        NO
# 24   qi        NO
# 25   qi        NO
# 26   qi        NO
# 27   qi        NO
# 28   qi        NO
# 29   qi        NO
# 30   qi        NO
# ⋮    ⋮         ⋮
# 1312 qi        NO
# 1313 qi        NO
# 1314 qi        NO
# 1315 qi        NO
# 1316 qi        NO
# 1317 qi        NO
# 1318 qi        NO
# 1319 qi        NO
# 1320 qi        NO
# 1321 qi        NO
# 1322 qi        NO
# 1323 qi        NO
# 1324 qi        NO
# 1325 qi        NO
# 1326 qi        NO
# 1327 qi        NO
# 1328 qi        NO
# 1329 qi        NO
# 1330 qi        NO
# 1331 qi        NO
# 1332 qi        NO
# 1333 qi        NO
# 1334 qi        NO
# 1335 qi        NO
# 1336 qi        NO
# 1337 qi        NO
# 1338 qi        NO
# 1339 qi        NO
# 1340 qi        NO
# 1341 qi        NO

# %%
options(digits = 3) 

temp_num_events %>%
    filter(endpoint %in% endpoint_selection) %>%
    arrange(delta.lower)
# Out:
#    endpoint       phecode_string
# 1  phecode_401    Hypertension
# 2  phecode_324-11 Parkinson's disease (Primary)
# 3  phecode_438-11 Abdominal aortic aneurysm
# 4  phecode_416-21 Atrial fibrillation
# 5  phecode_404    Ischemic heart disease
# 6  phecode_665    Psoriasis
# 7  phecode_410-2  Endocarditis
# 8  phecode_413-21 Aortic stenosis
# 9  phecode_284    Suicide ideation and attempt or self harm
# 10 phecode_400    Rheumatic fever and chronic rheumatic heart diseases
# 11 phecode_718    Back pain
# 12 phecode_705-1  Rheumatoid arthritis
# 13 phecode_202    Diabetes mellitus
# 14 phecode_431-11 Cerebral infarction [Ischemic stroke]
# 15 phecode_583    Chronic kidney disease
# 16 phecode_164    Anemia
# 17 phecode_413-11 Mitral valve insufficiency
# 18 phecode_474    Chronic obstructive pulmonary disease [COPD]
# 19 phecode_404-1  Myocardial infarction [Heart attack]
# 20 phecode_468    Pneumonia
# 21 phecode_424    Heart failure
# 22 OMOP_4306655   All-Cause Death
# 23 phecode_440-3  Pulmonary embolism
# 24 phecode_420    Cardiac arrest
#    phecode_category num_events num_events.lower num_events.upper delta
# 1  Cardio           13853      13629            14087            0.0164
# 2  Neuro              452        416              492            0.0324
# 3  Cardio             613        569              660            0.0323
# 4  Cardio            3802       3699             3919            0.0438
# 5  Cardio            7699       7534             7880            0.0545
# 6  Derm              1169       1105             1234            0.0700
# 7  Cardio            5238       5106             5385            0.0593
# 8  Cardio             178        155              204            0.0785
# 9  Mental            2266       2180             2347            0.0727
# 10 Cardio            3851       3736             3974            0.0700
# 11 Musc/Skel        16453      16254            16701            0.0769
# 12 Musc/Skel         1201       1138             1270            0.0869
# 13 Endo              7651       7486             7804            0.0801
# 14 Cardio            2330       2231             2420            0.0810
# 15 Genitourinary     5866       5723             6021            0.0860
# 16 Blood            13834      13619            14114            0.0876
# 17 Cardio            2486       2394             2585            0.0930
# 18 Resp              4455       4334             4596            0.0933
# 19 Cardio            3110       3006             3200            0.1052
# 20 Resp              7128       6969             7289            0.1026
# 21 Cardio            4818       4680             4962            0.1077
# 22 Death             2431       2334             2513            0.1137
# 23 Cardio            1970       1885             2063            0.1210
# 24 Cardio             825        775              878            0.1755
#    delta.lower delta.upper score1 score1.lower score1.upper score2 score2.lower
# 1  0.0128      0.0194      0.627  0.623        0.632        0.643  0.639
# 2  0.0211      0.0430      0.817  0.800        0.834        0.849  0.832
# 3  0.0217      0.0442      0.813  0.800        0.828        0.846  0.833
# 4  0.0371      0.0500      0.753  0.746        0.760        0.796  0.790
# 5  0.0496      0.0595      0.708  0.702        0.712        0.762  0.757
# 6  0.0507      0.0914      0.551  0.536        0.564        0.621  0.607
# 7  0.0522      0.0661      0.706  0.699        0.712        0.765  0.758
# 8  0.0562      0.0999      0.787  0.758        0.814        0.866  0.846
# 9  0.0578      0.0871      0.661  0.650        0.671        0.733  0.720
# 10 0.0637      0.0776      0.703  0.696        0.710        0.773  0.766
# 11 0.0709      0.0819      0.541  0.537        0.545        0.618  0.614
# 12 0.0716      0.1068      0.647  0.635        0.660        0.735  0.722
# 13 0.0722      0.0869      0.564  0.558        0.569        0.644  0.637
# 14 0.0733      0.0890      0.687  0.676        0.695        0.767  0.758
# 15 0.0804      0.0919      0.692  0.685        0.698        0.778  0.772
# 16 0.0834      0.0925      0.530  0.526        0.535        0.618  0.613
# 17 0.0842      0.1005      0.717  0.709        0.727        0.810  0.803
# 18 0.0851      0.1009      0.661  0.654        0.668        0.754  0.748
# 19 0.0970      0.1136      0.689  0.683        0.698        0.795  0.788
# 20 0.0975      0.1080      0.590  0.583        0.597        0.693  0.687
# 21 0.1010      0.1135      0.703  0.697        0.710        0.811  0.805
# 22 0.1039      0.1220      0.693  0.685        0.704        0.807  0.799
# 23 0.1092      0.1325      0.590  0.578        0.603        0.711  0.701
# 24 0.1583      0.1945      0.641  0.625        0.659        0.818  0.804
#    score2.upper .width .point .interval highlight
# 1  0.648        0.95   median qi        YES
# 2  0.863        0.95   median qi        YES
# 3  0.860        0.95   median qi        YES
# 4  0.803        0.95   median qi        YES
# 5  0.767        0.95   median qi        YES
# 6  0.635        0.95   median qi        YES
# 7  0.771        0.95   median qi        YES
# 8  0.886        0.95   median qi        YES
# 9  0.746        0.95   median qi        YES
# 10 0.781        0.95   median qi        YES
# 11 0.622        0.95   median qi        YES
# 12 0.749        0.95   median qi        YES
# 13 0.651        0.95   median qi        YES
# 14 0.776        0.95   median qi        YES
# 15 0.784        0.95   median qi        YES
# 16 0.623        0.95   median qi        YES
# 17 0.818        0.95   median qi        YES
# 18 0.760        0.95   median qi        YES
# 19 0.803        0.95   median qi        YES
# 20 0.699        0.95   median qi        YES
# 21 0.817        0.95   median qi        YES
# 22 0.815        0.95   median qi        YES
# 23 0.723        0.95   median qi        YES
# 24 0.831        0.95   median qi        YES

# %%
endpoint_order = (temp %>% arrange(delta))$endpoint

temp = temp %>% mutate(endpoint = factor(endpoint, levels=endpoint_order)) %>% ungroup() %>%
    arrange(endpoint) %>% group_by(phecode_category) %>% mutate(endpoint = row_number()) %>%
    filter(!phecode_category %in% c("Signs/Symptoms", "Preg", "Rx", "Stat"))

# %%
overview = ggplot(temp) +
    geom_ribbon(aes(x=endpoint, ymin=0, ymax=delta), fill="black", alpha=0.2)+
    geom_point(aes(x=endpoint, y=delta, color=highlight, size=highlight, alpha=highlight)) +
    geom_text(data=temp %>% filter(highlight=="YES"), aes(x=endpoint, y=delta+0.1, label="↓"), color="black", size=5, alpha=0.7) +
    #geom_segment(aes(x=endpoint, xend=endpoint, y=0, yend=delta, color=highlight, size=highlight), alpha=0.5)+#+
    labs(x="Endpoints", y="Delta C-Index")+
    scale_color_manual(values=c("NO"="black", "YES"="firebrick"))+
    scale_alpha_manual(values=c("NO"=0.1, "YES"=1))+
    scale_size_manual(values=c("NO"=0.01, "YES"=1))+
    #scale_colour_manual(values = c("pos"="forestgreen", "neg" = "firebrick")) +
    #coord_polar() +
    coord_cartesian(ylim=c(-0.3, 0.3), clip = "off")+
    scale_y_continuous(expand=c(0, 0))+
    scale_x_discrete(expand=expansion(add=20))+
    facet_grid(~phecode_category, scales="free_x", space="free_x")+#, switch=TRUE)+
    #facet_grid2(~phecode_category, scales = "free", independent = "all") +
    theme(axis.title.x=element_blank(),
        axis.text.x=element_blank(),
        axis.ticks.x=element_blank(),
        panel.grid.major=element_blank(),
         strip.text = element_text(angle=270, hjust=1)) +
    theme(legend.position="none")

    #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
#geom_violin(size=0.1)
overview

# %%
#library(gt)
figure_path = "/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/figures/220823_allofus/"
plot_name = "Figure5a_overview"
overview %>% ggsave(filename=glue("{figure_path}/{plot_name}.png"), device="png", width=plot_width, height=plot_height, dpi=plot_res)

# %%
base_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) +
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0),
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major=element_line()))

# %%
plot_width = 8.25; plot_height=2; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

plot_against_score = function(score1, score2, endpoint_order=c()){

  scores_plot = c(score1, score2)#, "AgeSexMedicalHistory"

  score_label = glue("{score1} vs. {score2}")
  #print(score_label)

  temp = benchmark_endpoints %>%
      filter(score %in% scores_plot) %>%
      filter(endpoint %in% endpoint_selection) %>%
      mutate(score = factor(score, levels=scores_plot)) %>%
      mutate(endpoint = factor(endpoint, levels=sort(endpoint_selection))) %>%
      group_by(endpoint, score, phecode_string, phecode_category) %>%
      ungroup() %>%
      pivot_wider(names_from=score, values_from=cindex, id_cols=c(uuid, partition, endpoint, phecode_category, phecode_string)) %>%
      mutate(id = row_number()) %>%
      mutate(delta = !!sym(score2)-!!sym(score1)) %>%
      mutate(pos = case_when(delta>=0 ~ "pos", delta < 0 ~"neg")) %>%
      mutate(endpoint = fct_reorder(endpoint, delta)) %>%
      mutate(highlight = case_when(endpoint %in% endpoint_selection ~ "YES", TRUE ~ "NO")) %>%# %>% filter(endpoint %in% endpoint_sample)
      mutate(phecode_category = factor(phecode_category, levels=categories_sorted)) %>%
      filter(endpoint %in% endpoint_selection) #%>% mutate(endpoint=factor(endpoint, levels=endpoint_order_diff))

  temp_abs = temp %>% group_by(endpoint) %>% summarise(delta=median(delta), m_score2=median(!!sym(score2)), m_score1=median(!!sym(score1))) %>% ungroup()
  #print(levels(temp_abs$endpoint))

  temp_abs_segment = temp_abs %>% rowwise() %>% mutate(min_cindex = min(m_score1, m_score2), max_cindex=max(m_score1, m_score2)) %>% ungroup()# %>% filter(abs(min_cindex-max_cindex)>0.02)

  endpoint_order = (temp %>% group_by(endpoint) %>% summarise(delta=median(delta)) %>% arrange(delta))$endpoint
  print(endpoint_order)

  if (length(endpoint_order)>0){
      temp = temp %>% filter(endpoint %in% endpoint_order) %>% mutate(endpoint=factor(endpoint, levels=endpoint_order))
      temp_abs = temp_abs %>% filter(endpoint %in% endpoint_order) %>% mutate(endpoint=factor(endpoint, levels=endpoint_order))
      temp_abs_segment = temp_abs_segment %>% filter(endpoint %in% endpoint_order) %>% mutate(endpoint=factor(endpoint, levels=endpoint_order))
      }
  #print(temp_abs_segment)

  abs = ggplot(temp_abs) +
      #geom_violin(aes(x=fct_rev(endpoint), y=delta), size=0.5) +
      labs(y="Concordance Index")+

      #geom_segment(data=temp_abs_segment, mapping=aes(x=endpoint, xend=endpoint, y=min_cindex+0.01, yend=max_cindex-0.01), alpha=0.4)+#, arrow = arrow(length = unit(0.01, "npc")), arrow.fill="black")+#+


      geom_point(aes(x=fct_rev(endpoint), y=m_score1), size=1, color="black", alpha=0.7)+
      #geom_point(aes(x=fct_rev(endpoint), y=m_asm), size=1, color="#023768", alpha=0.7)+
      geom_point(aes(x=fct_rev(endpoint), y=m_score2), size=1.5, color="firebrick", alpha=0.7)+
      geom_segment(data=temp_abs %>% filter(abs(delta)>0.02) %>% mutate(endpoint=factor(endpoint, levels=endpoint_order)),
                   aes(x=fct_rev(endpoint), xend=fct_rev(endpoint), y=m_score1+0.01, yend=m_score2-0.01), alpha=0.2, arrow = arrow(length = unit(0.01, "npc")), arrow.fill="black")+#,

      scale_x_discrete(labels=endpoint_map) +

      coord_flip(ylim=c(0.5, 0.9))+
       theme(strip.text = element_text(angle=270), axis.title.y=element_blank()) +
      theme(legend.position="none")

      #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
  #geom_violin(size=0.1)
  rel = ggplot(temp) +
      #geom_violin(aes(x=fct_rev(endpoint), y=delta), size=0.5) +
      labs(y="Difference in Concordance Index")+
      geom_hline(yintercept=0, size=0.25, alpha=0.5, linetype="22") +
      stat_pointinterval(aes(x=fct_rev(endpoint), y=delta), size=0.5, alpha=0.7)+

      theme(axis.title.y=element_blank(),
          axis.text.y=element_blank(),
         axis.ticks.y=element_blank()) +
      coord_flip(ylim=c(-0.01, 0.23))+
       theme(strip.text = element_text(angle=270)) +
      theme(legend.position="none")

      #geom_ribbon(aes(x=id, ymin=AgeSex, ymax=`Age+Sex+MedicalHistory`), fill="red", alpha=0.2)
  #geom_violin(size=0.1)
  return(abs|rel)
}

# %%
ase_size = 8
title_size = 10
facet_size = 9
geom_text_size=3
theme_set(theme_classic(base_size = base_size) +
          theme(strip.background = element_blank(), plot.title=element_text(size=title_size, hjust=0),
                strip.text.x = element_text(size = facet_size),axis.title=element_text(size=10), axis.text=element_text(size=8, color="black"),
                legend.position="bottom", axis.line = element_line(size = 0.2), axis.ticks=element_line(size=0.2), panel.grid.major=element_line()))

endpoint_order=c()
length(endpoint_order)

# %%
plot_width = 8.25; plot_height=3.25; plot_res = 320
options(repr.plot.width = plot_width, repr.plot.height = plot_height, repr.plot.res=plot_res)

fig5b = plot_against_score("AgeSex_AoUCPH", "AgeSex+MedicalHistory_UKBBParams")

plot_name = "Figure5b_performances"
fig5b %>% ggsave(filename=glue("{figure_path}/{plot_name}.png"), device="png", width=plot_width, height=plot_height, dpi=plot_res)
