# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
import os
import math
import pathlib
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.feather as feather
from tqdm.auto import tqdm
from IPython.display import clear_output

import warnings
from lifelines.utils import CensoringType
from lifelines.utils import concordance_index

# %%
import ray
ray.shutdown()

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

pathlib.Path(figure_path).mkdir(parents=True, exist_ok=True)
pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

experiment = 220531
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
import ray
#ray start --head --port=6379 --num-cpus 64 # in terminal
ray.init(address='auto')#, dashboard_port=24762, dashboard_host="0.0.0.0", include_dashboard=True)#, webui_url="0.0.0.0"))
#ray.init(num_cpus=32)#, dashboard_port=24762, dashboard_host="0.0.0.0", include_dashboard=True)#, webui_url="0.0.0.0"))
# Out:
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.9.7', ray_version='1.12.1', ray_commit='4863e33856b54ccf8add5cbe75e41558850a1b75', address_info={'node_ip_address': '10.32.105.4', 'raylet_ip_address': '10.32.105.4', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-06-09_08-50-57_892823_2289229/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-06-09_08-50-57_892823_2289229/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2022-06-09_08-50-57_892823_2289229', 'metrics_export_port': 60256, 'gcs_address': '10.32.105.4:6379', 'address': '10.32.105.4:6379', 'node_id': '8dfd18e69da3dcddb849e2ca9723d8755f21e0ecea16ae5b7df245e6'})

# %%
endpoints_md = pd.read_csv(f"{experiment_path}/endpoints.csv")
endpoints = sorted(endpoints_md.endpoint.to_list())

# %%
out_path = f"{experiment_path}/coxph/predictions"
pathlib.Path(out_path).mkdir(parents=True, exist_ok=True)

# %%
from sklearn.preprocessing import StandardScaler
import pickle
import zstandard

def read_data(fp_in):
    temp = pd.read_feather(f"{fp_in}").set_index("eid")
    return temp   
    
def save_pickle(data, data_path):
    with open(data_path, "wb") as fh:
        cctx = zstandard.ZstdCompressor()
        with cctx.stream_writer(fh) as compressor:
            compressor.write(pickle.dumps(data, protocol=pickle.HIGHEST_PROTOCOL))
    
def read_predictions(endpoint, feature_set, partition):
    
    identifier = f"{endpoint}_{feature_set}_{partition}"
    fp_in = f"{out_path}/{identifier}.feather"
    
    temp = read_data(fp_in)
    return temp

# %%
d = []
for endpoint in tqdm(endpoints):
    for feature_set in ["Age+Sex", "MedicalHistory", "Age+Sex+MedicalHistory", "Age+Sex+MedicalHistory+I(Age*MH)"]:
        for partition in [i for i in range(22)]:
            try: 
                temp = read_predictions(endpoint, feature_set, partition)
                d.append({"endpoint": endpoint, "features":feature_set, "partition":partition, "available": True})
            except:
                d.append({"endpoint": endpoint, "features":feature_set, "partition":partition, "available": False})
# Out:
#   0%|          | 0/1883 [00:00<?, ?it/s]
# (scheduler +19s) Tip: use `ray status` to view detailed cluster status. To disable these messages, set RAY_SCHEDULER_EVENTS=0.
# (scheduler +19s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (raylet) [2022-06-09 08:54:35,711 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2294999) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,721 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295000) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,731 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295007) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,741 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295014) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,776 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295022) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,787 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295029) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,797 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295036) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,806 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295043) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,816 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295050) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,824 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295057) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,830 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295064) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,844 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295071) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,855 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295078) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,863 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295085) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,872 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295092) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,882 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295099) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,891 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295106) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,903 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295113) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,913 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295120) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,923 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295127) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,933 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295134) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,943 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295141) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,954 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295148) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,964 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295155) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,974 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295162) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,982 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295169) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:35,993 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295176) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,004 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295183) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,013 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295190) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,023 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295197) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,031 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295204) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,041 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295211) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,050 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295218) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,059 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295225) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,068 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295232) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,079 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295239) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,087 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295246) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,097 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295253) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,106 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295260) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,117 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295267) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,126 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295274) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,137 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295281) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,146 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295288) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,156 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295295) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,165 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295302) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,174 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295309) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,184 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295316) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,193 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295323) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,203 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295330) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,213 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295337) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,221 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295344) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,230 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295351) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,241 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295358) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,250 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295365) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,261 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295372) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,272 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295379) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,281 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295386) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,291 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295393) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,303 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295400) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,312 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295407) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,322 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295414) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,333 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295421) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,342 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295428) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,351 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295435) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,360 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295442) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,371 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295449) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,380 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295456) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,390 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295463) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,399 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295470) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,410 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295477) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,420 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295484) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,428 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295491) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,436 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295498) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,446 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295505) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,456 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295512) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,464 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295519) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,473 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295526) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,484 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295533) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,492 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295540) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,500 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295547) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,508 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295554) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,519 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295561) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,527 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295568) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,535 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295575) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,544 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295582) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,554 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295589) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,563 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295596) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,573 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295603) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,583 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295610) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,596 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295617) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,604 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295624) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,613 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295631) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,622 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295638) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,631 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295645) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,641 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295652) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:54:36,650 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2295659) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (scheduler +54s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (raylet) [2022-06-09 08:55:05,719 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319653) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,732 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319660) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,744 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319667) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,757 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319676) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,786 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319701) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,797 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319708) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,809 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319715) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,822 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319716) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,834 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319717) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,845 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319718) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,856 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319719) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,868 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319720) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,882 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319723) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,894 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319724) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,908 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319727) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,921 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319734) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,932 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319741) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,947 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319748) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,960 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319755) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,971 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319762) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,983 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319769) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:05,996 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319778) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,008 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319785) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,022 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319792) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,033 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319799) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,045 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319806) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,058 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319813) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,070 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319820) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,081 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319827) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,093 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319834) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,105 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319841) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,118 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319848) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,135 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319857) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,146 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319864) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,160 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319871) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,172 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319878) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,184 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319885) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,196 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319892) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,207 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319899) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,219 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319906) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,234 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319913) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,247 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319920) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,259 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319929) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,271 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319936) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,284 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319943) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,295 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319950) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,307 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319957) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,318 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319964) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,330 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319971) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,342 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319978) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,355 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319985) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,372 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319992) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,385 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2319999) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,398 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320008) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,409 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320015) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,422 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320022) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,434 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320029) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,447 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320039) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,460 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320046) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,473 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320053) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,485 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320060) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,499 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320067) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,511 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320074) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,523 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320085) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,543 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320086) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,557 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320093) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,570 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320100) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,582 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320107) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,595 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320114) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,607 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320121) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,619 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320128) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,631 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320135) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,645 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320142) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,659 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320149) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,671 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320158) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,684 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320165) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,697 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320172) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,709 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320173) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,722 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320180) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,733 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320187) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,746 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320194) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,758 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320201) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,770 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320208) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,789 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320215) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,801 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320222) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,814 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320231) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,826 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320238) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,838 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320245) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,850 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320252) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,864 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320259) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,876 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320266) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,888 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320273) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,900 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320280) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,912 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320287) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,923 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320294) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:06,935 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2320297) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (scheduler +1m29s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (raylet) [2022-06-09 08:55:35,730 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341450) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,746 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341451) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,760 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341458) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,773 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341465) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,796 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341484) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,808 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341493) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,822 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341500) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,837 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341507) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,851 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341514) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,865 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341521) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,880 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341528) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 08:55:35,895 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2341535) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# ...
# (raylet) [2022-06-09 09:23:38,061 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424720) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,083 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424721) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,102 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424722) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,128 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424725) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,148 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424726) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,167 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424727) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,188 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424728) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,209 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424729) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,231 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424732) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,251 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424733) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,271 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424734) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,297 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424735) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,319 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424736) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,341 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424739) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,362 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424740) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,381 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424741) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,403 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424742) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,425 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424743) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,450 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424746) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,469 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424747) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,489 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424748) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,513 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424749) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,535 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424752) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,556 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424753) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,578 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424754) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,600 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424755) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,623 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424756) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,642 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424759) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,664 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424760) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,685 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424761) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,707 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424762) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,728 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424763) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,751 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424768) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,770 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424769) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,790 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424770) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,811 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424771) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,833 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424772) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,855 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424775) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,878 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424776) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,899 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424777) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,924 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424778) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,941 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424781) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,963 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424782) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:38,986 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424783) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,010 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424784) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,032 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424785) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,051 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424790) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,070 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424791) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,090 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424792) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,110 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424793) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,133 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424794) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,154 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424797) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,173 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424798) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,197 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424799) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,215 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424800) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,236 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424801) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,257 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424804) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,279 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424805) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,300 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424806) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,320 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424807) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,338 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424808) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,357 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424811) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,380 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424812) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,403 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424813) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,423 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424814) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,443 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424817) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,462 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424818) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,484 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424819) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-09 09:23:39,505 E 2289301 2289301] (raylet) worker_pool.cc:518: Some workers of the worker process(2424820) have not registered within the timeout. The process is still alive, probably it's hanging during start.

# %%
pd.DataFrame.from_dict(d).groupby(["features"])["available"].sum().to_frame()
