# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
import os
import math
import pathlib
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.feather as feather
from tqdm.auto import tqdm
from IPython.display import clear_output

import warnings
from lifelines.utils import CensoringType
from lifelines.utils import concordance_index

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

pathlib.Path(figure_path).mkdir(parents=True, exist_ok=True)
pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

experiment = 220531
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
endpoints_md = pd.read_csv(f"{experiment_path}/endpoints.csv")
endpoints = sorted(endpoints_md.endpoint.to_list())

# %%
baseline_covariates = pd.read_feather('/sc-projects/sc-proj-ukb-cvd/data/2_datasets_pre/220603_medicalhistory/baseline_covariates.feather').set_index("eid")

# %%
baseline_records = pd.read_feather('/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/baseline_outcomes_220531.feather').set_index("eid")

# %%
data_baseline = baseline_covariates.merge(baseline_records, left_index=True, right_index=True, how="left")

# %%
data_baseline[[c for c in data_baseline.columns if "fh" in c]]
# Out:
#          fh_alzheimer's_disease/dementia_0_0  fh_bowel_cancer_0_0  \
# eid
# 1000018                                False                False
# 1000020                                 True                False
# 1000037                                False                 True
# 1000043                                False                False
# 1000051                                 True                False
# ...                                      ...                  ...
# 6025150                                False                False
# 6025165                                False                False
# 6025173                                False                False
# 6025182                                False                False
# 6025198                                False                False
#
#          fh_breast_cancer_0_0  fh_chronic_bronchitis/emphysema_0_0  \
# eid
# 1000018                 False                                False
# 1000020                 False                                False
# 1000037                 False                                False
# 1000043                 False                                False
# 1000051                 False                                False
# ...                       ...                                  ...
# 6025150                 False                                 True
# 6025165                 False                                 True
# 6025173                 False                                False
# 6025182                 False                                False
# 6025198                 False                                False
#
#          fh_diabetes_0_0  fh_heart_disease_0_0  fh_high_blood_pressure_0_0  \
# eid
# 1000018            False                 False                        True
# 1000020            False                 False                       False
# 1000037            False                 False                        True
# 1000043            False                 False                       False
# 1000051             True                 False                        True
# ...                  ...                   ...                         ...
# 6025150            False                  True                        True
# 6025165            False                  True                        True
# 6025173             True                  True                       False
# 6025182            False                 False                       False
# 6025198            False                 False                       False
#
#          fh_lung_cancer_0_0  fh_parkinson's_disease_0_0  \
# eid
# 1000018                True                       False
# 1000020               False                       False
# 1000037               False                       False
# 1000043                True                       False
# 1000051               False                       False
# ...                     ...                         ...
# 6025150               False                       False
# 6025165               False                       False
# 6025173               False                       False
# 6025182               False                       False
# 6025198               False                       False
#
#          fh_severe_depression_0_0  fh_stroke_0_0
# eid
# 1000018                     False          False
# 1000020                     False          False
# 1000037                     False          False
# 1000043                     False          False
# 1000051                     False           True
# ...                           ...            ...
# 6025150                     False          False
# 6025165                     False          False
# 6025173                     False           True
# 6025182                     False          False
# 6025198                     False          False
#
# [502460 rows x 11 columns]

# %%
endpoints_md[endpoints_md.phecode_string.str.contains("erectile")]
# Out:
#       Unnamed: 0       endpoint  eligable      n      freq  phecode  \
# 1416        1416  phecode_605-1    209847  25611  0.122046    605.1
#
#                  phecode_string phecode_category   sex  ICD10_only  \
# 1416  Male erectile dysfunction    Genitourinary  Male         0.0
#
#       phecode_top  leaf
# 1416        605.0   1.0

# %%
endpoints_md[endpoints_md.phecode==705.1]
# Out:
#       Unnamed: 0       endpoint  eligable     n      freq  phecode  \
# 1622        1622  phecode_705-1    497765  7445  0.014957    705.1
#
#             phecode_string phecode_category   sex  ICD10_only  phecode_top  \
# 1622  Rheumatoid arthritis        Musc/Skel  Both         0.0        705.0
#
#       leaf
# 1622   0.0

# %%
# process for downstream cox models

# %%
covariate_map = {
    'ATC_C02_antihypertensives_0_0': "antihypertensives",
    'ATC_H02_corticosteroids_for_systemic_use_0_0': "corticosteroids",
    'ATC_N05_psycholeptics_0_0': "psycholeptics",
    'age_at_recruitment_f21022_0_0': "age",
    'cholesterol_f30690_0_0': "cholesterol",
    'ethnic_background_f21000_0_0': "ethnic_background",
    'fh_heart_disease_0_0': "fh_heart_disease",
    'hdl_cholesterol_f30760_0_0': "hdl_cholesterol",
    'phecode_202-1_prev': "diabetes1",
    'phecode_202-2_prev': "diabetes2",
    'phecode_202_prev': "diabetes",
    'phecode_286-1_prev': "bipolar_disorder",
    'phecode_286-2_prev': "major_depressive_disorder",
    'phecode_287-1_prev': "schizophrenia",
    'phecode_331-6_prev': "migraine",
    'phecode_416-21_prev': "atrial_fibrillation",
    'phecode_584_prev': "renal_failure",
    'phecode_605-1_prev': "male_erectile_dysfunction",
    'phecode_700-11_prev': "systemic_lupus_erythematosus",
    'phecode_705-1_prev': "rheumatoid_arthritis",
    'sex_f31_0_0': "sex",
    'smoking_status_f20116_0_0': "smoking_status",
    'standing_height_f50_0_0': "height",
    'systolic_blood_pressure_automated_reading_f4080_0_0': "systolic_blood_pressure_0",
    'systolic_blood_pressure_automated_reading_f4080_0_1': "systolic_blood_pressure_1",
    'weight_f21002_0_0': "weight"
}

# %%
data_covariates_pre = data_baseline[covariate_map]
data_covariates_pre.columns = [covariate_map[c] for c in data_covariates_pre.columns]

# %%
# prepare new variables
data_covariates = data_covariates_pre.copy()
data_covariates["age"] = data_covariates["age"].astype(np.int32)
data_covariates["bmi"] = data_covariates["weight"] / (data_covariates["height"]/100)**2
data_covariates["systolic_blood_pressure"] = pd.concat([data_covariates["systolic_blood_pressure_0"], data_covariates["systolic_blood_pressure_1"]], axis=1).agg(np.mean, 1)

ethn_bg_def = {"White": ["White", "British", "Irish", "Any other white background"],
                "Mixed": ["Mixed", "White and Black Caribbean", "White and Black African", "White and Asian", "Any other mixed background"],  
                "Asian": ["Asian or Asian British", "Indian", "Pakistani", "Bangladeshi", "Any other Asian background"], 
                "Black": ["Black or Black British", "Caribbean", "African", "Any other Black background"],
                "Chinese": ["Chinese"],  
                np.nan: ["Other ethnic group", "Do not know", "Prefer not to answer"]}

ethn_bg_dict = {}
for key, values in ethn_bg_def.items(): 
    for value in values:
        ethn_bg_dict[value]=key 
        
data_covariates["ethnic_background"].replace(ethn_bg_dict, inplace=True)
data_covariates["ethnic_background"] = data_covariates["ethnic_background"].astype("category")

# %%
AgeSex = ["age", "sex"]

SCORE2 = [
    "age", 
    "sex",
    "smoking_status", # current smoker
    "systolic_blood_pressure",
    "cholesterol",
    "hdl_cholesterol",

] 

ASCVD = [
    "age", 
    "sex",
    "ethnic_background",
    "smoking_status", # current smoker
    "diabetes", # diabetes
    "antihypertensives", 
    "systolic_blood_pressure",
    "cholesterol",
    "hdl_cholesterol",
] 

QRISK3 = [
    "age", 
    "sex",
    "ethnic_background",
    "smoking_status", # current smoker
    "bmi",
    "diabetes1", # type 1 diabetes
    "diabetes2", # type 1 diabetes
    "fh_heart_disease",
    "renal_failure", # renal failure
    "atrial_fibrillation", # Atrial Fibrillation
    "migraine", # Migraine
    "rheumatoid_arthritis", # Rheumatoid Arthritis
    "systemic_lupus_erythematosus", # SLE
    "schizophrenia", # Schizophrenia
    "bipolar_disorder", # Bipolar disorder
    "major_depressive_disorder", # Major depressive disorder
    "male_erectile_dysfunction", # Male Erectile dysfunction
    "antihypertensives", 
    "corticosteroids",
    "psycholeptics",
    "systolic_blood_pressure",
    "cholesterol",
    "hdl_cholesterol",
]

# assert, that all variables are available
covariates_scores = sorted(list(set(AgeSex + SCORE2 + ASCVD + QRISK3)))
if not set(covariates_scores).issubset(data_covariates.columns.to_list()):
    print("Not all required covariates are prepared!", list(set(covariates_scores).difference(data_covariates.columns.to_list())))
else:
    print("Success, all required covariates are prepared!")
    data_covariates = data_covariates[covariates_scores]
# Out:
# Success, all required covariates are prepared!

# %%
# prepare as float32
data_covariates[data_covariates.select_dtypes(np.float64).columns] = data_covariates.select_dtypes(np.float64).astype(np.float32)

# %%
data_covariates
# Out:
#          age  antihypertensives  atrial_fibrillation  bipolar_disorder  \
# eid
# 1000018   49              False                False             False
# 1000020   59              False                False             False
# 1000037   59              False                False             False
# 1000043   63              False                False             False
# 1000051   51              False                False             False
# ...      ...                ...                  ...               ...
# 6025150   43              False                False             False
# 6025165   45              False                False             False
# 6025173   57              False                False             False
# 6025182   56              False                False             False
# 6025198   67              False                False             False
#
#                bmi  cholesterol  corticosteroids  diabetes  diabetes1  \
# eid
# 1000018  26.555672        5.255            False     False      False
# 1000020  22.746511        7.372            False     False      False
# 1000037  32.421104          NaN            False     False      False
# 1000043  29.567902        5.089            False     False      False
# 1000051  41.022221          NaN            False      True      False
# ...            ...          ...              ...       ...        ...
# 6025150  25.349253        5.775            False     False      False
# 6025165  24.227461        5.631            False     False      False
# 6025173  25.950397        5.583            False     False      False
# 6025182  29.142521        6.224            False     False      False
# 6025198  29.598797        7.049            False     False      False
#
#          diabetes2  ... male_erectile_dysfunction  migraine  psycholeptics  \
# eid                 ...
# 1000018      False  ...                     False     False          False
# 1000020      False  ...                     False     False          False
# 1000037      False  ...                     False     False          False
# 1000043      False  ...                     False     False          False
# 1000051       True  ...                     False     False           True
# ...            ...  ...                       ...       ...            ...
# 6025150      False  ...                     False     False          False
# 6025165      False  ...                     False     False          False
# 6025173      False  ...                     False     False          False
# 6025182      False  ...                     False     False          False
# 6025198      False  ...                     False     False          False
#
#          renal_failure  rheumatoid_arthritis  schizophrenia     sex  \
# eid
# 1000018          False                 False          False  Female
# 1000020          False                 False          False    Male
# 1000037          False                 False          False  Female
# 1000043          False                 False          False    Male
# 1000051          False                 False          False  Female
# ...                ...                   ...            ...     ...
# 6025150          False                 False          False  Female
# 6025165          False                 False          False  Female
# 6025173          False                 False          False    Male
# 6025182          False                 False          False    Male
# 6025198          False                 False          False    Male
#
#          smoking_status  systemic_lupus_erythematosus  systolic_blood_pressure
# eid
# 1000018         Current                         False                    159.5
# 1000020         Current                         False                    133.0
# 1000037        Previous                         False                    118.5
# 1000043        Previous                         False                    141.5
# 1000051           Never                         False                    117.0
# ...                 ...                           ...                      ...
# 6025150           Never                         False                    122.5
# 6025165           Never                         False                    152.5
# 6025173           Never                         False                    131.0
# 6025182        Previous                         False                    127.5
# 6025198         Current                         False                    156.5
#
# [502460 rows x 24 columns]

# %%
data_covariates.reset_index().to_feather(f"{experiment_path}/data_covariates_full.feather")

# %%
data_covariates.dtypes
# Out:
# age                                int32
# antihypertensives                   bool
# atrial_fibrillation                 bool
# bipolar_disorder                    bool
# bmi                              float32
# cholesterol                      float32
# corticosteroids                     bool
# diabetes                            bool
# diabetes1                           bool
# diabetes2                           bool
# ethnic_background               category
# fh_heart_disease                    bool
# hdl_cholesterol                  float32
# major_depressive_disorder           bool
# male_erectile_dysfunction           bool
# migraine                            bool
# psycholeptics                       bool
# renal_failure                       bool
# rheumatoid_arthritis                bool
# schizophrenia                       bool
# sex                             category
# smoking_status                  category
# systemic_lupus_erythematosus        bool
# systolic_blood_pressure          float32
# dtype: object

# %%
data_covariates.isna().sum(axis=0)
# Out:
# age_at_recruitment_f21022_0_0       0
# sex_f31_0_0                         0
# ethnic_background_f21000_0_0     7334
# dtype: int64

# %%
data_covariates.describe(include="all")
# Out:
#         age_at_recruitment_f21022_0_0 sex_f31_0_0 ethnic_background_f21000_0_0
# count                   502460.000000      502460                       495126
# unique                            NaN           2                           19
# top                               NaN      Female                      British
# freq                              NaN      273353                       442551
# mean                        56.528924         NaN                          NaN
# std                          8.095128         NaN                          NaN
# min                         37.000000         NaN                          NaN
# 25%                         50.000000         NaN                          NaN
# 50%                         58.000000         NaN                          NaN
# 75%                         63.000000         NaN                          NaN
# max                         73.000000         NaN                          NaN
