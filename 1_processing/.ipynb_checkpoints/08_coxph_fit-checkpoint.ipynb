# %% [markdown]
# # Fit Cox Models

# %%
import os
import math
import pathlib
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from IPython.display import clear_output
import ray

import warnings
import lifelines
from lifelines.utils import CensoringType
from lifelines.utils import concordance_index

# %% [markdown]
# ## Submit CoxPH jobs

# %%
# %%
import datetime
import itertools
import os
import pathlib
import re
import subprocess

import pandas as pd
from omegaconf import OmegaConf
from tqdm.auto import tqdm

# %% codecell
USER = "steinfej"
BASE = pathlib.Path(f"/home/{USER}/code/")

EXPERIMENT_NAME = "22_medhistory"  # name under which to store the generated .sh scripts and yamls
TEMPLATE_CONFIG = f"{BASE}/config/"  # template yaml to use
TRAIN_SCRIPT = f"{BASE}/22_medical_records/1_processing/08_coxph_fit_partition.py"
ACTIVATE_ENV_CMD = """mamba activate ehrgraphs"""

TAG = 220627
JOBNAME = "fit_coxph"

# %%
os.makedirs(f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_submissions", exist_ok=True)
os.makedirs(f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_configs", exist_ok=True)
os.makedirs(f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_outputs", exist_ok=True)

# %%
def make_job_script(user, job_name, partition):

    job_script_str = (
        f"""#!/bin/bash

#SBATCH --job-name={job_name}  # Specify job name
#SBATCH --nodes=1              # Specify number of nodes
#SBATCH --mem=500G              # Specify number of nodes
#SBATCH --time=4:00:00        # Set a limit on the total run time
#SBATCH --tasks-per-node=1
#SBATCH --exclusive

{ACTIVATE_ENV_CMD}

ray start --head --port=6378 --num-cpus 32
python {TRAIN_SCRIPT} {partition}"""
            )

    return job_script_str

# %%
def submit(path, job_name, job_script, time_stamp=None):
    if not time_stamp:
        time_stamp = datetime.datetime.now().strftime("%Y-%m-%d_%H:%M:%S")

    script_path_long = f"{path}/{job_name}_{time_stamp}.sh"

    with open(script_path_long, "w") as outfile:
        outfile.write(job_script)
    script_path = f"{path}/{job_name}.sh"
    try:
        os.unlink(script_path)
    except FileNotFoundError:  # because we cannot overwrite symlinks directly
        pass
    os.symlink(os.path.realpath(script_path_long), script_path)

    output_path = f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_outputs/{job_name}"

    print(job_script)
    print("\n\nSubmission:\n===========\n")
    sub_cmd = (
        f"sbatch --error={output_path}_%j_stderr.out --output={output_path}_%j_stdout.out <"
        f" {script_path}"
    )
    print(sub_cmd)

    ret = subprocess.run(sub_cmd, shell=True, cwd=os.getcwd(), capture_output=True)
    print(ret.stdout.decode())

# %%
partitions = [i for i in range(22)]

# %%
import time

jobids = []
for partition in partitions:

    job_script = make_job_script(user=USER, job_name=JOBNAME, partition=partition)

    jobid = submit(
        path=f"/home/{USER}/tmp/{EXPERIMENT_NAME}/job_submissions",
        job_name=JOBNAME + f"_{partition}",
        job_script=job_script,
    )

    jobids.append(jobid)
    #time.sleep(2)

print(jobids)

# %% [markdown]
# ## Check progress

# %%
cox_paths = !ls "/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220627/coxph/models/"

path_df = pd.DataFrame(data = [p[:-2] for p in cox_paths]).rename(columns={0:"path"})
path_df[["endpoint_1", "endpoint_2", "score", "partition"]] = path_df.path.str.split("_", expand=True,) 
path_df["endpoint"] = path_df["endpoint_1"] + "_" + path_df["endpoint_2"] 

path_df.value_counts(["partition"]).to_frame()
# Out:
#                0
# partition
# 0          16947
# 1          16947
# 8          16947
# 7          16947
# 6          16947
# 5          16947
# 4          16947
# 3          16947
# 20         16947
# 2          16947
# 19         16947
# 18         16947
# 17         16947
# 16         16947
# 15         16947
# 14         16947
# 13         16947
# 12         16947
# 11         16947
# 10         16947
# 9          16947
# 21         10915

# %% [markdown]
# ## Fig Crashing CoxPH models

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

experiment = 220613
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
endpoints_md = pd.read_csv(f"{experiment_path}/endpoints.csv")
endpoints = sorted(endpoints_md.endpoint.to_list())

# %%
endpoints_md = pd.read_csv(f"{experiment_path}/endpoints.csv")
endpoints = sorted(endpoints_md.endpoint.to_list())

# %%
import yaml
import pickle
import zstandard

def get_score_defs():

    with open(r'/home/steinfej/code/22_medical_records/1_processing/score_definitions.yaml') as file:
        score_defs = yaml.full_load(file)
    
    return score_defs

def get_features(endpoint, score_defs):
    features = {
        'Identity(Records)+MLP': {
            "Age+Sex": score_defs["AgeSex"],
            "SCORE2": score_defs["SCORE2"],
            "ASCVD": score_defs["ASCVD"],
            "QRISK3": score_defs["QRISK3"],
            "MedicalHistory": [endpoint],
            "Age+Sex+MedicalHistory": score_defs["AgeSex"] + [endpoint],
            }
    }
    return features

def load_pickle(fp):
    with open(fp, "rb") as fh:
        dctx = zstandard.ZstdDecompressor()
        with dctx.stream_reader(fh) as decompressor:
            data = pickle.loads(decompressor.read())
    return data

def fit_cox(data_fit, feature_set, covariates, endpoint, penalizer, step_size=1):
    cph = CoxPHFitter(penalizer=penalizer)
    cph.fit(data_fit, f"{endpoint}_time", f"{endpoint}_event", step_size=step_size)
    return cph

score_defs = get_score_defs()

# %%
def clean_covariates(endpoint, covariates):
    if endpoint=="phecode_181": # Autoimmune disease
        covariates = [c for c in covariates if c!="systemic_lupus_erythematosus"]
    if endpoint=="phecode_202": # Diabetes
        covariates = [c for c in covariates if c not in ['diabetes1', 'diabetes2', 'diabetes']]
    if endpoint=="phecode_202-1": # Diabetes 1
        covariates = [c for c in covariates if c!="diabetes1"]
    if endpoint=="phecode_202-2": # Diabetes 1
        covariates = [c for c in covariates if c!="diabetes2"]
    if endpoint=="phecode_286": # Mood [affective] disorders
        covariates = [c for c in covariates if c not in ['bipolar_disorder', 'major_depressive_disorder']]
    if endpoint=="phecode_286-1": # Bipolar disorder
        covariates = [c for c in covariates if c not in ['bipolar_disorder']]
    if endpoint=="phecode_286-2": # Major depressive disorder
        covariates = [c for c in covariates if c not in ['major_depressive_disorder']]
    if endpoint=="phecode_287": # psychotic disorders
        covariates = [c for c in covariates if c not in ['schizophrenia']]
    if endpoint=="phecode_287-1": # schizophrenia
        covariates = [c for c in covariates if c not in ['schizophrenia']]
    if endpoint=="phecode_331": # headache
        covariates = [c for c in covariates if c!="migraine"]
    if endpoint=="phecode_331-6": # headache
        covariates = [c for c in covariates if c!="migraine"]
    if endpoint=="phecode_416": # atrial fibrillation
        covariates = [c for c in covariates if c not in ['atrial_fibrillation']]
    if endpoint=="phecode_416-2": # atrial fibrillation and flutter
        covariates = [c for c in covariates if c not in ['atrial_fibrillation']]
    if endpoint=="phecode_416-21": # atrial fibrillation
        covariates = [c for c in covariates if c not in ['atrial_fibrillation']]
    if endpoint=="phecode_584": # Renal failure
        covariates = [c for c in covariates if c not in ['renal_failure']]
    if endpoint=="phecode_605": # Male sexual dysfuction
        covariates = [c for c in covariates if c not in ['sex_Male', 'male_erectile_dysfunction']]
    if endpoint=="phecode_605-1": # Male sexual dysfuction
        covariates = [c for c in covariates if c not in ['sex_Male', 'male_erectile_dysfunction']]
    if endpoint=="phecode_700": # Diffuse diseases of connective tissue
        covariates = [c for c in covariates if c not in ['systemic_lupus_erythematosus']]
    if endpoint=="phecode_700-1": # Lupus
        covariates = [c for c in covariates if c not in ['systemic_lupus_erythematosus']]
    if endpoint=="phecode_700-11": # Systemic lupus erythematosus [SLE]	
        covariates = [c for c in covariates if c not in ['systemic_lupus_erythematosus']]
    if endpoint=="phecode_705": # Rheumatoid arthritis and other inflammatory
        covariates = [c for c in covariates if c not in ['rheumatoid_arthritis']]
    if endpoint=="phecode_705-1": # Rheumatoid arthritis and other inflammatory
        covariates = [c for c in covariates if c not in ['rheumatoid_arthritis']]
    return covariates

# %%
# problematic endpoints
problem_endpoints = [
    "phecode_181",
    "phecode_202",
    "phecode_202-1",
    "phecode_286",
    "phecode_287-1",
    "phecode_331",
    "phecode_416",
    "phecode_416-2",
    "phecode_416-21",
    "phecode_584", # 
    "phecode_605",
    "phecode_700",
    "phecode_700-1",
    "phecode_700-11",
    "phecode_705",
    "phecode_705-1"
]

endpoints_md.query("endpoint==@problem_endpoints")
# Out:
#       Unnamed: 0        endpoint  eligable      n      freq  phecode  \
# 323          323     phecode_181    486677  14610  0.030020   181.00
# 339          339     phecode_202    477657  37953  0.079457   202.00
# 340          340   phecode_202-1    499103   3722  0.007457   202.10
# 468          468     phecode_286    428189  38738  0.090469   286.00
# 475          475   phecode_287-1    501435    545  0.001087   287.10
# 563          563     phecode_331    431867  45870  0.106213   331.00
# 942          942     phecode_416    484929  52637  0.108546   416.00
# 946          946   phecode_416-2    494218  32911  0.066592   416.20
# 947          947  phecode_416-21    497277  22131  0.044504   416.21
# 1347        1347     phecode_584    500273   4400  0.008795   584.00
# 1415        1415     phecode_605    209820  25690  0.122438   605.00
# 1595        1595     phecode_700    499998   2808  0.005616   700.00
# 1596        1596   phecode_700-1    501538    575  0.001146   700.10
# 1597        1597  phecode_700-11    501875    383  0.000763   700.11
# 1621        1621     phecode_705    493940  14851  0.030066   705.00
# 1622        1622   phecode_705-1    497765   7445  0.014957   705.10
#
#                                          phecode_string phecode_category  \
# 323                                  Autoimmune disease            Blood
# 339                                   Diabetes mellitus             Endo
# 340                                     Type 1 diabetes             Endo
# 468                          Mood [affective] disorders           Mental
# 475                                       Schizophrenia           Mental
# 563                                            Headache            Neuro
# 942         Cardiac arrhythmia and conduction disorders           Cardio
# 946                     Atrial fibrillation and flutter           Cardio
# 947                                 Atrial fibrillation           Cardio
# 1347                                      Renal failure    Genitourinary
# 1415                             Male sexual dysfuction    Genitourinary
# 1595              Diffuse diseases of connective tissue        Musc/Skel
# 1596                                              Lupus        Musc/Skel
# 1597                 Systemic lupus erythematosus [SLE]        Musc/Skel
# 1621  Rheumatoid arthritis and other inflammatory po...        Musc/Skel
# 1622                               Rheumatoid arthritis        Musc/Skel
#
#        sex  ICD10_only  phecode_top  leaf
# 323   Both         0.0        181.0   0.0
# 339   Both         0.0        202.0   0.0
# 340   Both         0.0        202.0   1.0
# 468   Both         0.0        286.0   0.0
# 475   Both         0.0        287.0   1.0
# 563   Both         0.0        331.0   0.0
# 942   Both         0.0        416.0   0.0
# 946   Both         0.0        416.0   0.0
# 947   Both         0.0        416.0   0.0
# 1347  Both         0.0        584.0   0.0
# 1415  Male         0.0        605.0   0.0
# 1595  Both         0.0        700.0   0.0
# 1596  Both         0.0        700.0   0.0
# 1597  Both         0.0        700.0   1.0
# 1621  Both         0.0        705.0   0.0
# 1622  Both         0.0        705.0   0.0

# %%
from lifelines import CoxPHFitter
endpoint = "phecode_202-2"
partition = 11
feature_set = "QRISK3"
display(endpoints_md.query("endpoint==@endpoint"))

test_data = load_pickle(f"/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220613/coxph/errordata_{endpoint}_{feature_set}_{partition}.p")
display(test_data.T)

features = get_features(endpoint, score_defs)
covariates = features["Identity(Records)+MLP"][feature_set]

# # clean covariates for the coxphs to fit
covariates = clean_covariates(endpoint, covariates)
print(covariates)

data_endpoint = test_data[covariates + [f"{endpoint}_event", f"{endpoint}_time"]].astype(np.float32)

cph = fit_cox(data_endpoint,#.drop(columns=["systemic_lupus_erythematosus"]), 
              feature_set, covariates, endpoint, penalizer=0, step_size=0.1)
cph.print_summary()
# Out:
#      Unnamed: 0       endpoint  eligable      n      freq  phecode  \
# 341         341  phecode_202-2    478574  37460  0.078274    202.2
#
#       phecode_string phecode_category   sex  ICD10_only  phecode_top  leaf
# 341  Type 2 diabetes             Endo  Both         0.0        202.0   1.0
# eid                             1000018    1000020    1000037    1000043  \
# age                           -0.931635   0.304384   0.304384   0.798792
# sex_Male                       0.000000   1.000000   0.000000   1.000000
# ethnic_background_Asian        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Chinese      0.000000   0.000000   0.000000   0.000000
# ethnic_background_Black        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Mixed        0.000000   0.000000   0.000000   0.000000
# smoking_status_Previous        0.000000   0.000000   1.000000   1.000000
# smoking_status_Current         1.000000   1.000000   0.000000   0.000000
# bmi                           -0.183534  -0.975784   1.036392   0.442967
# diabetes1                      0.000000   0.000000   0.000000   0.000000
# diabetes2                      0.000000   0.000000   0.000000   0.000000
# fh_heart_disease               0.000000   0.000000   0.000000   0.000000
# renal_failure                  0.000000   0.000000   0.000000   0.000000
# atrial_fibrillation            0.000000   0.000000   0.000000   0.000000
# migraine                       0.000000   0.000000   0.000000   0.000000
# rheumatoid_arthritis           0.000000   0.000000   0.000000   0.000000
# systemic_lupus_erythematosus   0.000000   0.000000   0.000000   0.000000
# schizophrenia                  0.000000   0.000000   0.000000   0.000000
# bipolar_disorder               0.000000   0.000000   0.000000   0.000000
# major_depressive_disorder      0.000000   0.000000   0.000000   0.000000
# male_erectile_dysfunction      0.000000   0.000000   0.000000   0.000000
# antihypertensives              0.000000   0.000000   0.000000   0.000000
# corticosteroids                0.000000   0.000000   0.000000   0.000000
# psycholeptics                  0.000000   0.000000   0.000000   0.000000
# systolic_blood_pressure        1.161921  -0.259634  -1.037466   0.196336
# cholesterol                   -0.387509   1.465404  -0.346372  -0.532801
# hdl_cholesterol                0.011404  -0.626232  -0.200271  -1.480769
# phecode_202-2_event            0.000000   0.000000   0.000000   0.000000
# phecode_202-2_time            11.866089  13.596446  12.868163  12.309629
#
# eid                             1000066    1000079    1000084    1000107  \
# age                            1.293199   0.427986  -1.673247   0.057180
# sex_Male                       1.000000   0.000000   1.000000   0.000000
# ethnic_background_Asian        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Chinese      0.000000   0.000000   0.000000   0.000000
# ethnic_background_Black        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Mixed        0.000000   0.000000   0.000000   0.000000
# smoking_status_Previous        0.000000   0.000000   0.000000   0.000000
# smoking_status_Current         0.000000   0.000000   0.000000   0.000000
# bmi                           -0.717808  -0.503845   0.400390  -1.523006
# diabetes1                      0.000000   0.000000   0.000000   0.000000
# diabetes2                      0.000000   0.000000   0.000000   0.000000
# fh_heart_disease               1.000000   0.000000   0.000000   1.000000
# renal_failure                  0.000000   0.000000   0.000000   0.000000
# atrial_fibrillation            0.000000   0.000000   0.000000   0.000000
# migraine                       0.000000   1.000000   0.000000   0.000000
# rheumatoid_arthritis           0.000000   0.000000   0.000000   0.000000
# systemic_lupus_erythematosus   0.000000   0.000000   0.000000   0.000000
# schizophrenia                  0.000000   0.000000   0.000000   0.000000
# bipolar_disorder               0.000000   0.000000   0.000000   0.000000
# major_depressive_disorder      0.000000   0.000000   1.000000   0.000000
# male_erectile_dysfunction      0.000000   0.000000   0.000000   0.000000
# antihypertensives              0.000000   0.000000   0.000000   0.000000
# corticosteroids                0.000000   0.000000   0.000000   0.000000
# psycholeptics                  0.000000   0.000000   0.000000   0.000000
# systolic_blood_pressure        0.008584   0.437732   0.920525  -1.278863
# cholesterol                   -1.387924   1.384005   0.242674   1.334116
# hdl_cholesterol               -0.587033   0.115934  -1.499062   1.882499
# phecode_202-2_event            0.000000   0.000000   0.000000   0.000000
# phecode_202-2_time            11.775738  13.519785  13.935946  13.098147
#
# eid                             1000110    1000128  ...    5303251    5303279  \
# age                           -1.673247  -0.808033  ...  -0.808033   0.180782
# sex_Male                       0.000000   0.000000  ...   1.000000   0.000000
# ethnic_background_Asian        0.000000   0.000000  ...   0.000000   0.000000
# ethnic_background_Chinese      0.000000   0.000000  ...   0.000000   0.000000
# ethnic_background_Black        0.000000   0.000000  ...   0.000000   0.000000
# ethnic_background_Mixed        0.000000   0.000000  ...   0.000000   0.000000
# smoking_status_Previous        0.000000   1.000000  ...   0.000000   1.000000
# smoking_status_Current         0.000000   0.000000  ...   0.000000   0.000000
# bmi                           -0.419888  -0.985674  ...  -0.725738   0.102242
# diabetes1                      0.000000   0.000000  ...   0.000000   0.000000
# diabetes2                      0.000000   0.000000  ...   0.000000   0.000000
# fh_heart_disease               1.000000   0.000000  ...   0.000000   1.000000
# renal_failure                  0.000000   0.000000  ...   0.000000   0.000000
# atrial_fibrillation            0.000000   0.000000  ...   0.000000   0.000000
# migraine                       0.000000   0.000000  ...   0.000000   0.000000
# rheumatoid_arthritis           0.000000   0.000000  ...   0.000000   0.000000
# systemic_lupus_erythematosus   0.000000   0.000000  ...   0.000000   0.000000
# schizophrenia                  0.000000   0.000000  ...   0.000000   0.000000
# bipolar_disorder               0.000000   0.000000  ...   0.000000   0.000000
# major_depressive_disorder      1.000000   0.000000  ...   0.000000   0.000000
# male_erectile_dysfunction      0.000000   0.000000  ...   0.000000   0.000000
# antihypertensives              0.000000   0.000000  ...   0.000000   0.000000
# corticosteroids                0.000000   0.000000  ...   0.000000   0.000000
# psycholeptics                  0.000000   0.000000  ...   0.000000   0.000000
# systolic_blood_pressure       -1.064288  -1.734833  ...   1.483783  -0.501030
# cholesterol                   -0.136311   0.464113  ...   0.790583   0.436980
# hdl_cholesterol                0.784929   0.912979  ...   1.827621  -0.179364
# phecode_202-2_event            0.000000   0.000000  ...   0.000000   0.000000
# phecode_202-2_time            11.860613  11.616940  ...  13.489668  11.392431
#
# eid                             5303284    5303292    5303300    5303313  \
# age                           -1.426043   1.293199  -1.796849  -1.426043
# sex_Male                       1.000000   1.000000   1.000000   0.000000
# ethnic_background_Asian        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Chinese      0.000000   0.000000   0.000000   0.000000
# ethnic_background_Black        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Mixed        0.000000   0.000000   0.000000   0.000000
# smoking_status_Previous        0.000000   0.000000   0.000000   0.000000
# smoking_status_Current         0.000000   1.000000   0.000000   0.000000
# bmi                           -0.643569  -0.185539  -1.338429  -0.962060
# diabetes1                      0.000000   0.000000   0.000000   0.000000
# diabetes2                      0.000000   0.000000   0.000000   0.000000
# fh_heart_disease               0.000000   0.000000   0.000000   0.000000
# renal_failure                  0.000000   0.000000   0.000000   0.000000
# atrial_fibrillation            0.000000   0.000000   0.000000   0.000000
# migraine                       0.000000   0.000000   0.000000   0.000000
# rheumatoid_arthritis           0.000000   0.000000   0.000000   0.000000
# systemic_lupus_erythematosus   0.000000   0.000000   0.000000   0.000000
# schizophrenia                  0.000000   0.000000   0.000000   0.000000
# bipolar_disorder               0.000000   0.000000   0.000000   0.000000
# major_depressive_disorder      0.000000   0.000000   0.000000   0.000000
# male_erectile_dysfunction      0.000000   0.000000   0.000000   0.000000
# antihypertensives              0.000000   0.000000   0.000000   0.000000
# corticosteroids                0.000000   0.000000   0.000000   0.000000
# psycholeptics                  0.000000   0.000000   0.000000   0.000000
# systolic_blood_pressure       -1.037466  -0.179169  -1.332506  -1.868942
# cholesterol                   -1.218125  -1.134100  -1.057953  -0.168695
# hdl_cholesterol               -0.283895  -0.490342  -0.221176  -0.296961
# phecode_202-2_event            0.000000   0.000000   0.000000   0.000000
# phecode_202-2_time            12.805191  12.668296  13.916781  12.534139
#
# eid                             5303325    5303332    5303348    5303354
# age                            1.169597  -1.920451   0.551588  -0.684431
# sex_Male                       0.000000   1.000000   0.000000   0.000000
# ethnic_background_Asian        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Chinese      0.000000   0.000000   0.000000   0.000000
# ethnic_background_Black        0.000000   0.000000   0.000000   0.000000
# ethnic_background_Mixed        0.000000   0.000000   0.000000   0.000000
# smoking_status_Previous        1.000000   0.000000   0.000000   1.000000
# smoking_status_Current         0.000000   0.000000   0.000000   0.000000
# bmi                            0.081365  -0.068189   0.771572  -0.230506
# diabetes1                      0.000000   0.000000   0.000000   0.000000
# diabetes2                      0.000000   0.000000   0.000000   0.000000
# fh_heart_disease               0.000000   0.000000   1.000000   0.000000
# renal_failure                  0.000000   0.000000   0.000000   0.000000
# atrial_fibrillation            0.000000   0.000000   0.000000   0.000000
# migraine                       0.000000   0.000000   0.000000   0.000000
# rheumatoid_arthritis           0.000000   0.000000   0.000000   0.000000
# systemic_lupus_erythematosus   0.000000   0.000000   0.000000   0.000000
# schizophrenia                  0.000000   0.000000   0.000000   0.000000
# bipolar_disorder               0.000000   0.000000   0.000000   0.000000
# major_depressive_disorder      0.000000   0.000000   0.000000   0.000000
# male_erectile_dysfunction      0.000000   0.000000   0.000000   0.000000
# antihypertensives              0.000000   0.000000   0.000000   0.000000
# corticosteroids                0.000000   0.000000   0.000000   0.000000
# psycholeptics                  0.000000   0.000000   0.000000   0.000000
# systolic_blood_pressure        1.027812  -1.091110  -0.179169  -1.332506
# cholesterol                    1.446148   1.293854  -2.303440  -0.180949
# hdl_cholesterol                1.835461  -0.903238  -1.167177   0.385100
# phecode_202-2_event            0.000000   0.000000   0.000000   0.000000
# phecode_202-2_time            11.269225  13.111836  13.434910  13.213140
#
# [29 rows x 389589 columns]
# ['age', 'sex_Male', 'ethnic_background_Asian', 'ethnic_background_Chinese', 'ethnic_background_Black', 'ethnic_background_Mixed', 'smoking_status_Previous', 'smoking_status_Current', 'bmi', 'diabetes1', 'fh_heart_disease', 'renal_failure', 'atrial_fibrillation', 'migraine', 'rheumatoid_arthritis', 'systemic_lupus_erythematosus', 'schizophrenia', 'bipolar_disorder', 'major_depressive_disorder', 'male_erectile_dysfunction', 'antihypertensives', 'corticosteroids', 'psycholeptics', 'systolic_blood_pressure', 'cholesterol', 'hdl_cholesterol']
# <lifelines.CoxPHFitter: fitted with 389589 total observations, 359161 right-censored observations>
#              duration col = 'phecode_202-2_time'
#                 event col = 'phecode_202-2_event'
#       baseline estimation = breslow
#    number of observations = 389589
# number of events observed = 30428
#    partial log-likelihood = -373563.57
#          time fit was run = 2022-06-14 15:19:50 UTC
#
# ---
#                                coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                            0.30       1.35       0.01             0.29             0.31                 1.33                 1.37
# sex_Male                       0.14       1.15       0.01             0.11             0.16                 1.12                 1.18
# ethnic_background_Asian        1.43       4.19       0.03             1.38             1.48                 3.98                 4.41
# ethnic_background_Chinese      1.07       2.91       0.09             0.89             1.24                 2.44                 3.47
# ethnic_background_Black        1.05       2.85       0.03             0.99             1.11                 2.69                 3.03
# ethnic_background_Mixed        0.55       1.74       0.07             0.42             0.68                 1.53                 1.98
# smoking_status_Previous        0.14       1.15       0.01             0.12             0.17                 1.12                 1.18
# smoking_status_Current         0.47       1.61       0.02             0.44             0.51                 1.55                 1.66
# bmi                            0.51       1.66       0.00             0.50             0.52                 1.65                 1.68
# diabetes1                      2.68      14.54       0.07             2.54             2.82                12.64                16.72
# fh_heart_disease               0.09       1.09       0.01             0.07             0.11                 1.07                 1.12
# renal_failure                  0.13       1.13       0.07            -0.02             0.27                 0.98                 1.31
# atrial_fibrillation            0.30       1.35       0.04             0.22             0.39                 1.24                 1.47
# migraine                       0.09       1.09       0.02             0.04             0.13                 1.04                 1.14
# rheumatoid_arthritis           0.06       1.06       0.05            -0.05             0.16                 0.95                 1.18
# systemic_lupus_erythematosus  -0.07       0.93       0.17            -0.40             0.26                 0.67                 1.30
# schizophrenia                  0.24       1.27       0.09             0.06             0.43                 1.06                 1.53
# bipolar_disorder               0.10       1.10       0.09            -0.07             0.27                 0.93                 1.31
# major_depressive_disorder      0.22       1.24       0.02             0.19             0.25                 1.20                 1.28
# male_erectile_dysfunction      0.09       1.09       0.03             0.04             0.14                 1.04                 1.15
# antihypertensives              0.16       1.17       0.04             0.09             0.23                 1.10                 1.26
# corticosteroids                0.59       1.81       0.14             0.32             0.86                 1.38                 2.37
# psycholeptics                  0.27       1.31       0.04             0.20             0.34                 1.22                 1.41
# systolic_blood_pressure        0.15       1.16       0.01             0.14             0.16                 1.15                 1.18
# cholesterol                   -0.01       0.99       0.01            -0.03            -0.00                 0.97                 1.00
# hdl_cholesterol               -0.42       0.66       0.01            -0.44            -0.40                 0.65                 0.67
#
#                                cmp to      z      p   -log2(p)
# covariate
# age                              0.00  45.92 <0.005        inf
# sex_Male                         0.00  10.23 <0.005      79.18
# ethnic_background_Asian          0.00  54.70 <0.005        inf
# ethnic_background_Chinese        0.00  11.93 <0.005     106.52
# ethnic_background_Black          0.00  33.90 <0.005     834.59
# ethnic_background_Mixed          0.00   8.44 <0.005      54.76
# smoking_status_Previous          0.00  11.12 <0.005      93.00
# smoking_status_Current           0.00  26.99 <0.005     530.69
# bmi                              0.00 109.83 <0.005        inf
# diabetes1                        0.00  37.43 <0.005    1016.42
# fh_heart_disease                 0.00   7.65 <0.005      45.52
# renal_failure                    0.00   1.70   0.09       3.49
# atrial_fibrillation              0.00   7.03 <0.005      38.84
# migraine                         0.00   3.49 <0.005      11.00
# rheumatoid_arthritis             0.00   1.07   0.29       1.81
# systemic_lupus_erythematosus     0.00  -0.42   0.67       0.57
# schizophrenia                    0.00   2.55   0.01       6.53
# bipolar_disorder                 0.00   1.13   0.26       1.96
# major_depressive_disorder        0.00  13.45 <0.005     134.53
# male_erectile_dysfunction        0.00   3.40 <0.005      10.56
# antihypertensives                0.00   4.53 <0.005      17.38
# corticosteroids                  0.00   4.30 <0.005      15.87
# psycholeptics                    0.00   7.20 <0.005      40.63
# systolic_blood_pressure          0.00  25.41 <0.005     470.89
# cholesterol                      0.00  -2.27   0.02       5.44
# hdl_cholesterol                  0.00 -49.44 <0.005        inf
# ---
# Concordance = 0.77
# Partial AIC = 747179.14
# log-likelihood ratio test = 28296.04 on 26 df
# -log2(p) of ll-ratio test = inf

# %%
# Out:
# <lifelines.CoxPHFitter: fitted with 396241 total observations, 384393 right-censored observations>
#              duration col = 'phecode_181_time'
#                 event col = 'phecode_181_event'
#       baseline estimation = breslow
#    number of observations = 396241
# number of events observed = 11848
#    partial log-likelihood = -150483.48
#          time fit was run = 2022-06-14 10:22:14 UTC
#
# ---
#                             coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                         0.20       1.22       0.01             0.18             0.22                 1.19                 1.24
# sex_Male                   -0.48       0.62       0.02            -0.52            -0.44                 0.59                 0.65
# ethnic_background_Asian     0.24       1.27       0.06             0.12             0.36                 1.12                 1.43
# ethnic_background_Chinese  -0.51       0.60       0.23            -0.96            -0.06                 0.38                 0.94
# ethnic_background_Black     0.04       1.04       0.07            -0.11             0.18                 0.90                 1.20
# ethnic_background_Mixed     0.03       1.03       0.12            -0.21             0.26                 0.81                 1.30
# smoking_status_Previous     0.25       1.28       0.02             0.21             0.29                 1.23                 1.34
# smoking_status_Current      0.43       1.54       0.03             0.38             0.49                 1.46                 1.63
# bmi                         0.06       1.06       0.01             0.04             0.08                 1.04                 1.08
# diabetes1                   0.65       1.92       0.09             0.48             0.82                 1.62                 2.28
# diabetes2                  -0.02       0.98       0.04            -0.11             0.06                 0.90                 1.07
# fh_heart_disease            0.03       1.03       0.02            -0.01             0.07                 0.99                 1.07
# renal_failure               0.23       1.26       0.12            -0.00             0.46                 1.00                 1.59
# atrial_fibrillation         0.04       1.04       0.08            -0.13             0.20                 0.88                 1.23
# migraine                    0.24       1.27       0.03             0.17             0.31                 1.19                 1.36
# rheumatoid_arthritis        2.38      10.80       0.32             1.76             3.00                 5.81                20.07
# schizophrenia              -0.03       0.97       0.19            -0.40             0.34                 0.67                 1.40
# bipolar_disorder           -0.34       0.71       0.18            -0.69            -0.00                 0.50                 1.00
# major_depressive_disorder   0.24       1.27       0.02             0.19             0.28                 1.21                 1.33
# male_erectile_dysfunction   0.01       1.01       0.05            -0.09             0.11                 0.92                 1.11
# antihypertensives           0.20       1.22       0.06             0.07             0.32                 1.08                 1.38
# corticosteroids             1.37       3.94       0.16             1.05             1.69                 2.87                 5.43
# psycholeptics               0.29       1.34       0.06             0.17             0.41                 1.19                 1.50
# systolic_blood_pressure    -0.03       0.97       0.01            -0.05            -0.01                 0.96                 0.99
# cholesterol                -0.10       0.91       0.01            -0.12            -0.08                 0.89                 0.93
# hdl_cholesterol            -0.13       0.88       0.01            -0.16            -0.11                 0.86                 0.90
#
#                             cmp to      z      p   -log2(p)
# covariate
# age                           0.00  19.09 <0.005     267.47
# sex_Male                      0.00 -21.78 <0.005     346.84
# ethnic_background_Asian       0.00   3.83 <0.005      12.94
# ethnic_background_Chinese     0.00  -2.22   0.03       5.25
# ethnic_background_Black       0.00   0.50   0.62       0.69
# ethnic_background_Mixed       0.00   0.22   0.82       0.28
# smoking_status_Previous       0.00  12.34 <0.005     113.85
# smoking_status_Current        0.00  15.02 <0.005     167.02
# bmi                           0.00   5.90 <0.005      28.03
# diabetes1                     0.00   7.47 <0.005      43.46
# diabetes2                     0.00  -0.50   0.62       0.69
# fh_heart_disease              0.00   1.65   0.10       3.33
# renal_failure                 0.00   1.94   0.05       4.27
# atrial_fibrillation           0.00   0.47   0.64       0.65
# migraine                      0.00   6.95 <0.005      38.02
# rheumatoid_arthritis          0.00   7.52 <0.005      44.02
# schizophrenia                 0.00  -0.16   0.87       0.20
# bipolar_disorder              0.00  -1.96   0.05       4.34
# major_depressive_disorder     0.00   9.55 <0.005      69.37
# male_erectile_dysfunction     0.00   0.17   0.86       0.21
# antihypertensives             0.00   3.11 <0.005       9.08
# corticosteroids               0.00   8.43 <0.005      54.65
# psycholeptics                 0.00   4.86 <0.005      19.70
# systolic_blood_pressure       0.00  -2.55   0.01       6.52
# cholesterol                   0.00  -9.52 <0.005      69.03
# hdl_cholesterol               0.00 -11.16 <0.005      93.71
# ---
# Concordance = 0.61
# Partial AIC = 301018.97
# log-likelihood ratio test = 1917.69 on 26 df
# -log2(p) of ll-ratio test = inf

# %%
jobids
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
#fit_partition(in_path, model_path, score_defs, 0)

# %%
import submitit

partitions = [i for i in range(22)]

executor = submitit.AutoExecutor(folder="log_test/%j")
# set timeout in min, and partition for running the job
executor.update_parameters(slurm_array_parallelism=6,
                           nodes=1,
                           #slurm_mem="500G",
                           timeout_min=600,
                          #slurm_setup=[
                          #  """export MKL_NUM_THREADS=1""",
                          #  """export NUMEXPR_NUM_THREADS=1""",
                           # """export OMP_NUM_THREADS=1"""]
                          )

job = executor.map_array(fit_partition, partitions)  


# jobs = []
# for partition in tqdm(partitions):
#     job = executor.submit(fit_partition, in_path, model_path, score_defs, partition)
#     jobs.append(job)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_747020/2290864394.py in <module>
#      14                           )
#      15
# ---> 16 job = executor.map_array(fit_partition, partitions)
#      17
#      18
#
# ~/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/submitit/core/core.py in map_array(self, fn, *iterable)
#     628             warnings.warn("Received an empty job array")
#     629             return []
# --> 630         return self._internal_process_submissions(submissions)
#     631
#     632     def submit_array(self, fns: tp.Sequence[tp.Callable[[], R]]) -> tp.List[Job[R]]:
#
# ~/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/submitit/auto/auto.py in _internal_process_submissions(self, delayed_submissions)
#     202         self, delayed_submissions: tp.List[DelayedSubmission]
#     203     ) -> tp.List[Job[tp.Any]]:
# --> 204         return self._executor._internal_process_submissions(delayed_submissions)
#     205
#     206
#
# ~/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/submitit/slurm/slurm.py in _internal_process_submissions(self, delayed_submissions)
#     320             pickle_path = folder / f"{uuid.uuid4().hex}.pkl"
#     321             d.set_timeout(timeout_min, self.max_num_timeout)
# --> 322             d.dump(pickle_path)
#     323             pickle_paths.append(pickle_path)
#     324         n = len(delayed_submissions)
#
# ~/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/submitit/core/utils.py in dump(self, filepath)
#     132
#     133     def dump(self, filepath: Union[str, Path]) -> None:
# --> 134         cloudpickle_dump(self, filepath)
#     135
#     136     def set_timeout(self, timeout_min: int, max_num_timeout: int) -> None:
#
# ~/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/submitit/core/utils.py in cloudpickle_dump(obj, filename)
#     236 def cloudpickle_dump(obj: Any, filename: Union[str, Path]) -> None:
#     237     with open(filename, "wb") as ofile:
# --> 238         cloudpickle.dump(obj, ofile, pickle.HIGHEST_PROTOCOL)
#     239
#     240
#
# ~/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py in dump(obj, file, protocol, buffer_callback)
#      53         compatibility with older versions of Python.
#      54         """
# ---> 55         CloudPickler(
#      56             file, protocol=protocol, buffer_callback=buffer_callback
#      57         ).dump(obj)
#
# ~/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/cloudpickle/cloudpickle_fast.py in dump(self, obj)
#     600     def dump(self, obj):
#     601         try:
# --> 602             return Pickler.dump(self, obj)
#     603         except RuntimeError as e:
#     604             if "recursion" in e.args[0]:
#
# TypeError: cannot pickle '_hashlib.HASH' object

# %%
# %env MKL_NUM_THREADS=1
# %env NUMEXPR_NUM_THREADS=1
# %env OMP_NUM_THREADS=1

import ray
#ray start --head --port=6379 --num-cpus 64 # in terminal
#ray.init(address='auto')#, dashboard_port=24762, dashboard_host="0.0.0.0", include_dashboard=True)#, webui_url="0.0.0.0"))
#ray.init(num_cpus=32)#, dashboard_port=24762, dashboard_host="0.0.0.0", include_dashboard=True)#, webui_url="0.0.0.0"))
# Out:
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.9.7', ray_version='1.12.1', ray_commit='4863e33856b54ccf8add5cbe75e41558850a1b75', address_info={'node_ip_address': '10.32.105.2', 'raylet_ip_address': '10.32.105.2', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-06-13_11-43-47_176488_2125616/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-06-13_11-43-47_176488_2125616/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2022-06-13_11-43-47_176488_2125616', 'metrics_export_port': 63797, 'gcs_address': '10.32.105.2:6379', 'address': '10.32.105.2:6379', 'node_id': 'ebe5c1cc59f8f70c07421a2fbef0a2c0a0f9550a21554a5a287c320f'})

# %%
ray.available_resources()
# Out:
# {'node:10.32.105.2': 1.0,
#  'object_store_memory': 158159606169.0,
#  'memory': 359039081063.0,
#  'CPU': 64.0}

# %%
for partition in tqdm(partitions):
    fit_partition()
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# Ray object not yet initialised
#   0%|          | 0/1883 [00:00<?, ?it/s]
# (raylet) [2022-06-13 11:45:42,810 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143681) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,815 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143687) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,820 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143694) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,825 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143711) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,830 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143736) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,834 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143747) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,839 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143748) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,843 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143749) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,848 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143754) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,852 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143756) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,857 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143757) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,862 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143758) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,866 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143759) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,871 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143760) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,875 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143761) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,880 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143762) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,884 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143763) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,889 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143764) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,893 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143765) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,898 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143766) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,902 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143767) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,907 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143768) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,912 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143769) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,916 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143770) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,921 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143771) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,926 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143772) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,931 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143773) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,936 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143774) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,953 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143775) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,958 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143776) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,963 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143777) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,968 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143778) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,973 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143779) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,978 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143780) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,983 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143781) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,988 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143782) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,993 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143783) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:42,997 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143784) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,002 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143785) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,007 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143786) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,012 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143787) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,017 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143788) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,021 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143789) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,026 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143790) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,030 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143791) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,035 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143792) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,041 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143793) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,047 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143794) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,052 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143795) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,060 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143796) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,065 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143797) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,070 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143798) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,075 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143799) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,080 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143800) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,085 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143801) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,089 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143802) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:45:43,094 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2143803) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:33,978 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144264) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:33,982 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144266) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:33,987 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144269) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:33,992 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144281) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:33,996 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144292) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,001 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144303) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,006 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144326) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,011 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144327) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,015 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144328) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,019 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144329) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,023 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144330) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,028 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144331) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,031 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144332) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,035 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144333) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,040 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144334) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,044 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144335) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,048 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144338) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,053 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144355) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,058 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144362) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,061 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144363) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,065 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144364) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,069 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144365) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,073 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144366) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,077 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144367) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,080 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144368) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,084 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144369) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,088 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144370) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,093 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144371) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,097 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144372) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,101 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144373) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,105 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144374) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,109 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144375) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,114 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144376) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,118 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144377) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,128 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144378) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,133 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144379) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,138 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144380) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,142 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144381) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,147 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144382) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,152 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144383) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,155 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144384) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,159 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144385) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,164 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144386) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,170 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144387) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144388) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144389) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144390) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144391) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144392) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144393) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144394) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144395) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:46:34,298 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144396) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (fit_endpoint pid=2143451) ConvergenceError Identity(Records)+MLP phecode_084-2 ASCVD 0 problem: reduce step size
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1783: RuntimeWarning: overflow encountered in exp
# (fit_endpoint pid=2143451)   scores = weights * exp(dot(X, beta))
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1801: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143451)   risk_phi_x = risk_phi_x + (phi_x_i).sum(0)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1802: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143451)   risk_phi_x_x = risk_phi_x_x + phi_x_x_i
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/numpy/core/_methods.py:47: RuntimeWarning: invalid value encountered in reduce
# (fit_endpoint pid=2143451)   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1846: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   a1 = risk_phi_x_x * denom
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1848: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   summand = numer * denom[:, None]
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1855: RuntimeWarning: divide by zero encountered in log
# (fit_endpoint pid=2143451)   log_lik = log_lik + dot(x_death_sum, beta) + weighted_average * log(denom).sum()
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1831: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   numer = risk_phi_x - multiply.outer(increasing_proportion, tie_phi_x)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1831: RuntimeWarning: invalid value encountered in subtract
# (fit_endpoint pid=2143451)   numer = risk_phi_x - multiply.outer(increasing_proportion, tie_phi_x)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1832: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   denom = 1.0 / (risk_phi - increasing_proportion * tie_phi)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1832: RuntimeWarning: invalid value encountered in subtract
# (fit_endpoint pid=2143451)   denom = 1.0 / (risk_phi - increasing_proportion * tie_phi)
# (fit_endpoint pid=2143451) ConvergenceError Identity(Records)+MLP phecode_084-2 ASCVD 0 trying with reduced step size ... 0.5 failed
# (fit_endpoint pid=2143446) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column ethnic_background_Chinese have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446) >>> events = df['phecode_084-7_event'].astype(bool)
# (fit_endpoint pid=2143446) >>> print(df.loc[events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143446) >>> print(df.loc[~events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446) A very low variance means that the column ethnic_background_Chinese completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143446) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1601: ConvergenceWarning: Newton-Rhaphson convergence completed successfully but norm(delta) is still high, 0.142. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446)   warnings.warn(
# (fit_endpoint pid=2143451) ConvergenceError Identity(Records)+MLP phecode_084-2 ASCVD 0 trying with reduced step size ... 0.1 successfull
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1783: RuntimeWarning: overflow encountered in exp
# (fit_endpoint pid=2143451)   scores = weights * exp(dot(X, beta))
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/numpy/core/_methods.py:47: RuntimeWarning: invalid value encountered in reduce
# (fit_endpoint pid=2143451)   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1801: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143451)   risk_phi_x = risk_phi_x + (phi_x_i).sum(0)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1802: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143451)   risk_phi_x_x = risk_phi_x_x + phi_x_x_i
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1846: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   a1 = risk_phi_x_x * denom
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1848: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   summand = numer * denom[:, None]
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1855: RuntimeWarning: divide by zero encountered in log
# (fit_endpoint pid=2143451)   log_lik = log_lik + dot(x_death_sum, beta) + weighted_average * log(denom).sum()
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1524: LinAlgWarning: Ill-conditioned matrix (rcond=1.42786e-20): result may not be accurate.
# (fit_endpoint pid=2143449)   inv_h_dot_g_T = spsolve(-h, g, assume_a="pos", check_finite=False)
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1783: RuntimeWarning: overflow encountered in exp
# (fit_endpoint pid=2143449)   scores = weights * exp(dot(X, beta))
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1801: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143449)   risk_phi_x = risk_phi_x + (phi_x_i).sum(0)
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1802: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143449)   risk_phi_x_x = risk_phi_x_x + phi_x_x_i
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/numpy/core/_methods.py:47: RuntimeWarning: invalid value encountered in reduce
# (fit_endpoint pid=2143449)   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1846: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143449)   a1 = risk_phi_x_x * denom
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1848: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143449)   summand = numer * denom[:, None]
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1855: RuntimeWarning: divide by zero encountered in log
# (fit_endpoint pid=2143449)   log_lik = log_lik + dot(x_death_sum, beta) + weighted_average * log(denom).sum()
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column renal_failure have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143451)
# (fit_endpoint pid=2143451) >>> events = df['phecode_084-2_event'].astype(bool)
# (fit_endpoint pid=2143451) >>> print(df.loc[events, 'renal_failure'].var())
# (fit_endpoint pid=2143451) >>> print(df.loc[~events, 'renal_failure'].var())
# (fit_endpoint pid=2143451)
# (fit_endpoint pid=2143451) A very low variance means that the column renal_failure completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143451)
# (fit_endpoint pid=2143451)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143451) ConvergenceError Identity(Records)+MLP phecode_084-2 QRISK3 0 problem: reduce step size
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1524: LinAlgWarning: Ill-conditioned matrix (rcond=1.15444e-17): result may not be accurate.
# (fit_endpoint pid=2143452)   inv_h_dot_g_T = spsolve(-h, g, assume_a="pos", check_finite=False)
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1783: RuntimeWarning: overflow encountered in exp
# (fit_endpoint pid=2143452)   scores = weights * exp(dot(X, beta))
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1801: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143452)   risk_phi_x = risk_phi_x + (phi_x_i).sum(0)
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1802: RuntimeWarning: invalid value encountered in add
# (fit_endpoint pid=2143452)   risk_phi_x_x = risk_phi_x_x + phi_x_x_i
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1846: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143452)   a1 = risk_phi_x_x * denom
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1848: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143452)   summand = numer * denom[:, None]
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1855: RuntimeWarning: divide by zero encountered in log
# (fit_endpoint pid=2143452)   log_lik = log_lik + dot(x_death_sum, beta) + weighted_average * log(denom).sum()
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column ethnic_background_Chinese have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143449)
# (fit_endpoint pid=2143449) >>> events = df['phecode_076_event'].astype(bool)
# (fit_endpoint pid=2143449) >>> print(df.loc[events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143449) >>> print(df.loc[~events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143449)
# (fit_endpoint pid=2143449) A very low variance means that the column ethnic_background_Chinese completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143449)
# (fit_endpoint pid=2143449)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/numpy/core/_methods.py:47: RuntimeWarning: invalid value encountered in reduce
# (fit_endpoint pid=2143452)   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# (fit_endpoint pid=2143449) ConvergenceError Identity(Records)+MLP phecode_076 QRISK3 0 problem: reduce step size
# (fit_endpoint pid=2143452) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column ethnic_background_Chinese have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143452)
# (fit_endpoint pid=2143452) >>> events = df['phecode_074_event'].astype(bool)
# (fit_endpoint pid=2143452) >>> print(df.loc[events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143452) >>> print(df.loc[~events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143452)
# (fit_endpoint pid=2143452) A very low variance means that the column ethnic_background_Chinese completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143452)
# (fit_endpoint pid=2143452)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143452) ConvergenceError Identity(Records)+MLP phecode_074 QRISK3 0 problem: reduce step size
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1831: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   numer = risk_phi_x - multiply.outer(increasing_proportion, tie_phi_x)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1831: RuntimeWarning: invalid value encountered in subtract
# (fit_endpoint pid=2143451)   numer = risk_phi_x - multiply.outer(increasing_proportion, tie_phi_x)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1832: RuntimeWarning: invalid value encountered in multiply
# (fit_endpoint pid=2143451)   denom = 1.0 / (risk_phi - increasing_proportion * tie_phi)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1832: RuntimeWarning: invalid value encountered in subtract
# (fit_endpoint pid=2143451)   denom = 1.0 / (risk_phi - increasing_proportion * tie_phi)
# (fit_endpoint pid=2143446) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column ethnic_background_Chinese have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446) >>> events = df['phecode_084-7_event'].astype(bool)
# (fit_endpoint pid=2143446) >>> print(df.loc[events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143446) >>> print(df.loc[~events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446) A very low variance means that the column ethnic_background_Chinese completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143446) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1601: ConvergenceWarning: Newton-Rhaphson convergence completed successfully but norm(delta) is still high, 0.165. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
# (fit_endpoint pid=2143446)
# (fit_endpoint pid=2143446)   warnings.warn(
# (fit_endpoint pid=2143451) ConvergenceError Identity(Records)+MLP phecode_084-2 QRISK3 0 trying with reduced step size ... 0.5 failed
# (fit_endpoint pid=2143449) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1601: ConvergenceWarning: Newton-Rhaphson convergence completed successfully but norm(delta) is still high, 0.124. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
# (fit_endpoint pid=2143449)
# (fit_endpoint pid=2143449)   warnings.warn(
# (fit_endpoint pid=2143452) ConvergenceError Identity(Records)+MLP phecode_074 QRISK3 0 trying with reduced step size ... 0.5 successfull
# (fit_endpoint pid=2143449) ConvergenceError Identity(Records)+MLP phecode_076 QRISK3 0 trying with reduced step size ... 0.5 successfull
# (fit_endpoint pid=2143451) ConvergenceError Identity(Records)+MLP phecode_084-2 QRISK3 0 trying with reduced step size ... 0.1 successfull
# (fit_endpoint pid=2143454) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column diabetes1 have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143454)
# (fit_endpoint pid=2143454) >>> events = df['phecode_084-4_event'].astype(bool)
# (fit_endpoint pid=2143454) >>> print(df.loc[events, 'diabetes1'].var())
# (fit_endpoint pid=2143454) >>> print(df.loc[~events, 'diabetes1'].var())
# (fit_endpoint pid=2143454)
# (fit_endpoint pid=2143454) A very low variance means that the column diabetes1 completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143454)
# (fit_endpoint pid=2143454)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143454) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1601: ConvergenceWarning: Newton-Rhaphson convergence completed successfully but norm(delta) is still high, 0.222. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
# (fit_endpoint pid=2143454)
# (fit_endpoint pid=2143454)   warnings.warn(
# (raylet) [2022-06-13 11:47:04,176 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144419) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,181 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144420) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,187 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144421) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,192 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144422) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,197 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144423) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,203 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144424) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,209 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144425) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,214 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144426) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,220 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144427) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,226 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144428) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,231 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144429) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,236 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144430) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 11:47:04,241 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2144431) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# ...
# (fit_endpoint pid=2143827)
# (fit_endpoint pid=2143827)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column ethnic_background_Chinese have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143451)
# (fit_endpoint pid=2143451) >>> events = df['phecode_391-4_event'].astype(bool)
# (fit_endpoint pid=2143451) >>> print(df.loc[events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143451) >>> print(df.loc[~events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143451)
# (fit_endpoint pid=2143451) A very low variance means that the column ethnic_background_Chinese completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143451)
# (fit_endpoint pid=2143451)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143457) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/utils/__init__.py:1123: ConvergenceWarning: Column ethnic_background_Chinese have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
# (fit_endpoint pid=2143457)
# (fit_endpoint pid=2143457) >>> events = df['phecode_391-22_event'].astype(bool)
# (fit_endpoint pid=2143457) >>> print(df.loc[events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143457) >>> print(df.loc[~events, 'ethnic_background_Chinese'].var())
# (fit_endpoint pid=2143457)
# (fit_endpoint pid=2143457) A very low variance means that the column ethnic_background_Chinese completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
# (fit_endpoint pid=2143457)
# (fit_endpoint pid=2143457)   warnings.warn(dedent(warning_text), ConvergenceWarning)
# (fit_endpoint pid=2143457) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1601: ConvergenceWarning: Newton-Rhaphson convergence completed successfully but norm(delta) is still high, 0.123. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
# (fit_endpoint pid=2143457)
# (fit_endpoint pid=2143457)   warnings.warn(
# (fit_endpoint pid=2143451) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1601: ConvergenceWarning: Newton-Rhaphson convergence completed successfully but norm(delta) is still high, 0.131. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
# (fit_endpoint pid=2143451)
# (fit_endpoint pid=2143451)   warnings.warn(
# (fit_endpoint pid=2143827) /home/steinfej/miniconda3/envs/ehrgraphs/lib/python3.9/site-packages/lifelines/fitters/coxph_fitter.py:1601: ConvergenceWarning: Newton-Rhaphson convergence completed successfully but norm(delta) is still high, 0.272. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
# (fit_endpoint pid=2143827)
# (fit_endpoint pid=2143827)   warnings.warn(
# (fit_endpoint pid=2143827) ConvergenceError Identity(Records)+MLP phecode_390-5 QRISK3 0 trying with reduced step size ... 0.5 successfull
# (raylet) [2022-06-13 12:25:16,490 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160067) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,495 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160068) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,499 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160069) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,504 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160070) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,508 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160071) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,512 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160072) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,517 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160073) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,521 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160074) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,525 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160075) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,530 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160076) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,536 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160077) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,541 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160078) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,546 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160079) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,551 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160080) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,556 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160081) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,561 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160082) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,566 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160083) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,574 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160084) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,579 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160085) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,585 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160087) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,590 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160088) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,595 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160089) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,600 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160090) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,605 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160091) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,610 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160092) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,615 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160093) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,620 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160094) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,626 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160095) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,631 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160096) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,636 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160097) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,641 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160098) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,646 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160099) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,651 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160100) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,657 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160101) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,662 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160102) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,667 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160103) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,672 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160104) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,677 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160105) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,682 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160106) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,687 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160107) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,692 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160108) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,698 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160109) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,703 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160110) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,712 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160111) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,828 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160112) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,828 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160113) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,828 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160114) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,828 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160115) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,828 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160116) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,829 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160117) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,829 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160118) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,829 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160119) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-13 12:25:16,832 E 2125963 2125963] (raylet) worker_pool.cc:518: Some workers of the worker process(2160120) have not registered within the timeout. The process is still alive, probably it's hanging during start.

# %%
## Debugging

# %%
# fit_endpoint(data_partition, eids_dict, endpoint_defs, endpoints[0], partition, models, model_path)
# Out:
# True

# %%
cph_1 = load_pickle("/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220613/coxph/models/OMOP_4306655_QRISK3_0.p")
cph_2 = load_pickle("/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220613/coxph/models/OMOP_4306655_Age+Sex+MedicalHistory_0.p")

# %%
cph_1.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 389520 total observations, 360325 right-censored observations>
#              duration col = 'OMOP_4306655_time'
#                 event col = 'OMOP_4306655_event'
#       baseline estimation = breslow
#    number of observations = 389520
# number of events observed = 29195
#    partial log-likelihood = -358964.51
#          time fit was run = 2022-06-13 08:51:04 UTC
#
# ---
#                                coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age                            0.80       2.22       0.01             0.78             0.81                 2.19                 2.26
# sex_Male                       0.35       1.42       0.01             0.32             0.38                 1.38                 1.46
# ethnic_background_Asian       -0.16       0.85       0.05            -0.26            -0.06                 0.77                 0.94
# ethnic_background_Chinese     -0.13       0.88       0.15            -0.41             0.16                 0.66                 1.17
# ethnic_background_Black       -0.08       0.92       0.06            -0.19             0.03                 0.82                 1.03
# ethnic_background_Mixed       -0.13       0.88       0.10            -0.32             0.06                 0.73                 1.06
# smoking_status_Previous        0.29       1.33       0.01             0.26             0.31                 1.30                 1.37
# smoking_status_Current         1.04       2.84       0.02             1.01             1.08                 2.75                 2.94
# bmi                            0.12       1.13       0.01             0.11             0.14                 1.12                 1.15
# diabetes1                      0.86       2.36       0.04             0.77             0.94                 2.16                 2.57
# diabetes2                      0.12       1.13       0.02             0.08             0.17                 1.08                 1.19
# fh_heart_disease              -0.01       0.99       0.01            -0.03             0.02                 0.97                 1.02
# renal_failure                  0.81       2.25       0.05             0.71             0.91                 2.04                 2.47
# atrial_fibrillation           -0.10       0.91       0.05            -0.19            -0.00                 0.83                 1.00
# migraine                      -0.66       0.52       0.04            -0.73            -0.59                 0.48                 0.56
# rheumatoid_arthritis           0.43       1.54       0.05             0.34             0.52                 1.41                 1.68
# systemic_lupus_erythematosus   0.60       1.83       0.14             0.34             0.87                 1.40                 2.38
# schizophrenia                  0.19       1.21       0.10             0.00             0.38                 1.00                 1.46
# bipolar_disorder               0.35       1.42       0.09             0.18             0.51                 1.20                 1.67
# major_depressive_disorder     -0.37       0.69       0.02            -0.41            -0.33                 0.66                 0.72
# male_erectile_dysfunction     -0.58       0.56       0.03            -0.63            -0.52                 0.53                 0.60
# antihypertensives              0.25       1.29       0.03             0.19             0.32                 1.21                 1.37
# corticosteroids                1.00       2.72       0.10             0.80             1.20                 2.23                 3.34
# psycholeptics                  0.65       1.92       0.03             0.59             0.71                 1.80                 2.04
# systolic_blood_pressure        0.02       1.02       0.01             0.01             0.03                 1.01                 1.03
# cholesterol                   -0.13       0.88       0.01            -0.14            -0.12                 0.87                 0.89
# hdl_cholesterol               -0.03       0.97       0.01            -0.04            -0.01                 0.96                 0.99
#
#                                cmp to      z      p   -log2(p)
# covariate
# age                              0.00 100.61 <0.005        inf
# sex_Male                         0.00  25.52 <0.005     474.73
# ethnic_background_Asian          0.00  -3.16 <0.005       9.31
# ethnic_background_Chinese        0.00  -0.87   0.38       1.39
# ethnic_background_Black          0.00  -1.45   0.15       2.77
# ethnic_background_Mixed          0.00  -1.36   0.17       2.52
# smoking_status_Previous          0.00  21.54 <0.005     339.53
# smoking_status_Current           0.00  63.04 <0.005        inf
# bmi                              0.00  19.67 <0.005     283.78
# diabetes1                        0.00  19.24 <0.005     271.68
# diabetes2                        0.00   5.30 <0.005      23.07
# fh_heart_disease                 0.00  -0.63   0.53       0.91
# renal_failure                    0.00  16.51 <0.005     200.95
# atrial_fibrillation              0.00  -2.04   0.04       4.61
# migraine                         0.00 -17.49 <0.005     225.15
# rheumatoid_arthritis             0.00   9.54 <0.005      69.31
# systemic_lupus_erythematosus     0.00   4.45 <0.005      16.84
# schizophrenia                    0.00   2.00   0.05       4.45
# bipolar_disorder                 0.00   4.09 <0.005      14.51
# major_depressive_disorder        0.00 -18.18 <0.005     242.87
# male_erectile_dysfunction        0.00 -19.11 <0.005     268.08
# antihypertensives                0.00   7.67 <0.005      45.69
# corticosteroids                  0.00   9.71 <0.005      71.59
# psycholeptics                    0.00  19.83 <0.005     288.24
# systolic_blood_pressure          0.00   3.06 <0.005       8.80
# cholesterol                      0.00 -19.94 <0.005     291.53
# hdl_cholesterol                  0.00  -3.89 <0.005      13.26
# ---
# Concordance = 0.74
# Partial AIC = 717983.02
# log-likelihood ratio test = 23951.70 on 27 df
# -log2(p) of ll-ratio test = inf

# %%
cph_2.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 389520 total observations, 360325 right-censored observations>
#              duration col = 'OMOP_4306655_time'
#                 event col = 'OMOP_4306655_event'
#       baseline estimation = breslow
#    number of observations = 389520
# number of events observed = 29195
#    partial log-likelihood = -333358.67
#          time fit was run = 2022-06-13 08:51:18 UTC
#
# ---
#                coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# age            0.41       1.51       0.01             0.40             0.43                 1.49                 1.53
# sex_Male       0.13       1.14       0.01             0.11             0.16                 1.12                 1.17
# OMOP_4306655   1.01       2.74       0.00             1.00             1.02                 2.72                 2.77
#
#                cmp to      z      p   -log2(p)
# covariate
# age              0.00  55.05 <0.005        inf
# sex_Male         0.00  11.14 <0.005      93.31
# OMOP_4306655     0.00 237.90 <0.005        inf
# ---
# Concordance = 0.89
# Partial AIC = 666723.34
# log-likelihood ratio test = 75163.39 on 3 df
# -log2(p) of ll-ratio test = inf

# %%
encode_cols = 
pd.get_dummies(data_partition['Identity(Records)+MLP'], columns=["ethnic_background", "sex", "smoking_status"], prefix=)

# %%
data_partition['Identity(Records)+MLP'].select_dtypes("category")
# Out:
#         partition  split                  model ethnic_background     sex  \
# eid
# 1000018         0  train  Identity(Records)+MLP             White  Female
# 1000020         0  train  Identity(Records)+MLP             White    Male
# 1000037         0  train  Identity(Records)+MLP             White  Female
# 1000043         0  train  Identity(Records)+MLP             White    Male
# 1000051         0  train  Identity(Records)+MLP             White  Female
# ...           ...    ...                    ...               ...     ...
# 5337676         0  train  Identity(Records)+MLP             White    Male
# 5337681         0  train  Identity(Records)+MLP             White    Male
# 5337697         0  train  Identity(Records)+MLP             White    Male
# 5337703         0  train  Identity(Records)+MLP             White    Male
# 5337711         0  train  Identity(Records)+MLP             White    Male
#
#         smoking_status
# eid
# 1000018        Current
# 1000020        Current
# 1000037       Previous
# 1000043       Previous
# 1000051          Never
# ...                ...
# 5337676          Never
# 5337681       Previous
# 5337697       Previous
# 5337703       Previous
# 5337711        Current
#
# [389526 rows x 6 columns]
# (raylet) [2022-06-12 21:30:41,739 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954666) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,743 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954667) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,747 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954668) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,752 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954669) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,756 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954674) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,761 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954675) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,765 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954676) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,770 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954677) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,774 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954678) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,779 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954679) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,783 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954680) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,787 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954681) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,792 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954682) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,796 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954683) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,800 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954684) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,804 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954685) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,808 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954686) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,813 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954687) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,817 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954688) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,821 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954689) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,826 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954690) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,830 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954691) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,834 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954692) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,838 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954693) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,842 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954694) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,850 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954695) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,854 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954696) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,858 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954698) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,862 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954700) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,867 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954701) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,871 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954702) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,876 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954703) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,881 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954704) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,885 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954705) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,890 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954706) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,894 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954707) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,899 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954708) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,903 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954709) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,908 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954710) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,912 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954711) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,916 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954712) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,921 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954713) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,926 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954714) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:41,931 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954715) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,041 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954716) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954717) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954718) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954719) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954720) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954721) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954722) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954723) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:30:42,042 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2954724) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,937 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955027) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,941 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955028) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,946 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955029) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,950 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955030) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,954 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955031) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,959 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955032) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,963 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955033) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,967 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955034) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,971 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955035) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,976 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955036) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,980 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955037) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,984 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955038) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,988 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955039) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,993 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955040) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:11,997 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955041) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,002 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955042) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,006 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955045) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,010 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955046) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,015 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955047) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,019 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955048) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,023 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955049) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,027 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955050) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,031 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955051) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,036 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955052) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,040 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955053) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,049 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955054) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,055 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955055) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,061 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955056) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,065 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955057) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,070 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955058) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,075 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955059) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,079 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955060) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,084 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955061) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,089 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955062) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,094 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955063) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,098 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955064) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,103 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955065) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,109 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955068) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,115 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955069) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,120 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955070) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,124 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955071) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,130 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955072) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,135 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955073) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,140 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955074) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,146 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955075) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,152 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955076) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,158 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955077) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,164 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955078) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,169 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955079) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,174 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955080) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,180 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955081) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,185 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955082) have not registered within the timeout. The process is still alive, probably it's hanging during start.
# (raylet) [2022-06-12 21:31:12,191 E 2586297 2586297] (raylet) worker_pool.cc:518: Some workers of the worker process(2955083) have not registered within the timeout. The process is still alive, probably it's hanging during start.

# %%
load_pickle("/sc-projects/sc-proj-ukb-cvd/results/projects/22_medical_records/data/220413/coxph/errordata_phecode_002-1_Age+Sex+MedicalHistory+I(Age*MH)_0.p")
# Out:
#          age_at_recruitment_f21022_0_0  sex_f31_0_0  phecode_002-1  \
# eid
# 1000018                      -0.931072          0.0       0.086565
# 1000020                       0.304493          1.0      -1.797872
# 1000037                       0.304493          0.0       0.259373
# 1000043                       0.798719          1.0       2.246452
# 1000051                      -0.683959          0.0       0.685702
# ...                                ...          ...            ...
# 5337676                       0.922275          1.0       0.725549
# 5337681                       1.292945          1.0       0.346841
# 5337697                      -1.919524          1.0       0.265374
# 5337703                      -1.795968          1.0       0.061749
# 5337711                       1.540058          1.0      -1.797872
#
#          phecode_002-1_event  phecode_002-1_time
# eid
# 1000018                  0.0           11.866089
# 1000020                  0.0           13.596446
# 1000037                  0.0           12.868163
# 1000043                  0.0           12.309629
# 1000051                  0.0           15.291210
# ...                      ...                 ...
# 5337676                  0.0           11.518374
# 5337681                  0.0           12.312367
# 5337697                  0.0           11.822283
# 5337703                  0.0           12.627227
# 5337711                  0.0            8.898198
#
# [388894 rows x 5 columns]

# %%
data_partition['Identity(Records)+MLP']['phecode_977']
# Out:
# eid
# 1303905    0.507814
# 1303918    0.033095
# 1303920   -0.946619
# 1303937    0.042184
# 1303943   -0.270619
#              ...
# 5316968   -0.614777
# 5316970    0.009382
# 5316985   -0.361461
# 5316994   -0.194883
# 5317002   -0.581893
# Name: phecode_977, Length: 401263, dtype: float64
