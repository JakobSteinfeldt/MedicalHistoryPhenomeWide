# %% [markdown]
# # Benchmarks

# %% [markdown]
# ## Initialize

# %%
import os
import math
import pathlib
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from IPython.display import clear_output

import warnings
from lifelines.utils import CensoringType
from lifelines.utils import concordance_index

# %%
node = !hostname
if "sc" in node[0]:
    base_path = "/sc-projects/sc-proj-ukb-cvd"
else: 
    base_path = "/data/analysis/ag-reils/ag-reils-shared/cardioRS"
print(base_path)

project_label = "22_medical_records"
project_path = f"{base_path}/results/projects/{project_label}"
figure_path = f"{project_path}/figures"
output_path = f"{project_path}/data"

experiment = 230425
experiment_path = f"{output_path}/{experiment}"
pathlib.Path(experiment_path).mkdir(parents=True, exist_ok=True)
# Out:
# /sc-projects/sc-proj-ukb-cvd

# %%
endpoints_md = pd.read_csv(f"{experiment_path}/endpoints.csv")
endpoints = sorted(endpoints_md.endpoint.to_list())

# %%
partitions = [p for p in range(0, 22)]
splits = ["train", "valid", "test"]

# %%
endpoint_defs = pd.read_feather(f"{output_path}/phecode_defs_220306.feather").query("endpoint==@endpoints").sort_values("endpoint").set_index("endpoint")

# %%
eligable_eids = pd.read_feather(f"{output_path}/eligable_eids_220627.feather")
eids_dict = eligable_eids.set_index("endpoint")["eid_list"].to_dict()

# %%
# %env MKL_NUM_THREADS=1
# %env NUMEXPR_NUM_THREADS=2
# %env OMP_NUM_THREADS=1
# Out:
# env: MKL_NUM_THREADS=1
# env: NUMEXPR_NUM_THREADS=2
# env: OMP_NUM_THREADS=1

# %%
ray.shutdown()

# %%
import ray

#ray.init(address="auto")#, dashboard_port=24762, dashboard_host="0.0.0.0", include_dashboard=True)#, webui_url="0.0.0.0"))
ray.init(num_cpus=24)
# Out:
# 2023-05-04 08:55:02,531	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.10.9', ray_version='2.2.0', ray_commit='b6af0887ee5f2e460202133791ad941a41f15beb', address_info={'node_ip_address': '10.32.105.111', 'raylet_ip_address': '10.32.105.111', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-05-04_08-54-57_017535_2353716/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-05-04_08-54-57_017535_2353716/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2023-05-04_08-54-57_017535_2353716', 'metrics_export_port': 59169, 'gcs_address': '10.32.105.111:39340', 'address': '10.32.105.111:39340', 'dashboard_agent_listen_port': 52365, 'node_id': '64a291d735b1b4a9fbb4724729db1bfaa4761ba61fd8204d69f96e1e'})

# %% [markdown]
# # Train COX

# %%
in_path = pathlib.Path(f"{experiment_path}/coxph/input")
model_path = f"{experiment_path}/coxph/models"

out_path = f"{experiment_path}/coxph/predictions"
pathlib.Path(out_path).mkdir(parents=True, exist_ok=True)

# %%
import pickle
import zstandard

def load_pickle(fp):
    with open(fp, "rb") as fh:
        dctx = zstandard.ZstdDecompressor()
        with dctx.stream_reader(fh) as decompressor:
            data = pickle.loads(decompressor.read())
    return data

# %%
cox_paths = !ls $model_path
cox_paths = [p for p in cox_paths if "_MedicalHistory" in p or "+MedicalHistory" in p or "I(" in p]
cox = pd.Series(cox_paths).str.split("_", expand=True)\
    .assign(path = cox_paths)\
    .assign(endpoint = lambda x: x[0]+"_"+x[1])\
    .assign(score = lambda x: x[2])\
    .assign(partition = lambda x: x[3].str.replace(".p", "", regex=True).astype(int))\
    [["endpoint", "score", "partition", "path"]].sort_values(["endpoint", "score", "partition"])\
    .query("endpoint ==@ endpoints")\
    .reset_index(drop=True)
cox
# Out:
#              endpoint                  score  partition  \
# 0        OMOP_4306655   ASCVD+MedicalHistory          0
# 1        OMOP_4306655   ASCVD+MedicalHistory          1
# 2        OMOP_4306655   ASCVD+MedicalHistory          2
# 3        OMOP_4306655   ASCVD+MedicalHistory          3
# 4        OMOP_4306655   ASCVD+MedicalHistory          4
# ...               ...                    ...        ...
# 372829  phecode_979-7  SCORE2+MedicalHistory         17
# 372830  phecode_979-7  SCORE2+MedicalHistory         18
# 372831  phecode_979-7  SCORE2+MedicalHistory         19
# 372832  phecode_979-7  SCORE2+MedicalHistory         20
# 372833  phecode_979-7  SCORE2+MedicalHistory         21
#
#                                             path
# 0          OMOP_4306655_ASCVD+MedicalHistory_0.p
# 1          OMOP_4306655_ASCVD+MedicalHistory_1.p
# 2          OMOP_4306655_ASCVD+MedicalHistory_2.p
# 3          OMOP_4306655_ASCVD+MedicalHistory_3.p
# 4          OMOP_4306655_ASCVD+MedicalHistory_4.p
# ...                                          ...
# 372829  phecode_979-7_SCORE2+MedicalHistory_17.p
# 372830  phecode_979-7_SCORE2+MedicalHistory_18.p
# 372831  phecode_979-7_SCORE2+MedicalHistory_19.p
# 372832  phecode_979-7_SCORE2+MedicalHistory_20.p
# 372833  phecode_979-7_SCORE2+MedicalHistory_21.p
#
# [372834 rows x 4 columns]

# %% [raw]
# cox = cox.query("endpoint == 'phecode_101-8'")#&score=='Age+Sex+MedicalHistory+I(Age*MH)'")

# %%
#endpoints = sorted(cox.endpoint.unique().tolist())
scores = sorted(cox.score.unique().tolist())
partitions = sorted(cox.partition.unique().tolist())

# %%
import ray

@ray.remote
def get_cox_info(p):
    cph = load_pickle(f"{model_path}/{p}")
    p_split = p.split("_")
    endpoint = f"{p_split[0]}_{p_split[1]}"
    score = p_split[2]
    partition = p_split[3][:-2]
    hrs = cph.hazard_ratios_.to_dict()
    
    if score=="Age+Sex+MedicalHistory+I(Age*MH)":
        hr_mh = hrs[endpoint.replace("-", "")]
        
        key_int_age = [k for k in hrs if "age_at_recruitment_f21022_0_0" in k and endpoint.replace("-", "") in k][0]
        hr_mh_age = hrs[key_int_age]
        
        try:
            key_int_sex = [k for k in hrs if "sex_f31_0_0" in k and endpoint.replace("-", "") in k][0]
            hr_mh_sex = hrs[key_int_sex]
        except:
            hr_mh_sex = np.nan
    else:
        hr_mh = hrs[endpoint] 
        hr_mh_age = np.nan
        hr_mh_sex = np.nan
        
    return {"endpoint": endpoint, "score": score, "partition": partition, "hrs": hrs, 
            "hrs_mh": hr_mh, 
            "hrs_mh_age": hr_mh_age, 
            "hrs_mh_sex": hr_mh_sex
           }

# %%
rows = []

for p in tqdm(cox.path.tolist()):
    rows.append(get_cox_info.remote(p))
# Out:
#   0%|          | 0/372834 [00:00<?, ?it/s]

# %%
rows = [ray.get(r) for r in tqdm(rows)]
# Out:
#   0%|          | 0/372834 [00:00<?, ?it/s]

# %%
rows[10]

# %%
hrs_endpoints = pd.DataFrame({}).append(rows, ignore_index=True)

# %%
hrs_endpoints

# %%
name = f"hrs_endpoints"
hrs_endpoints.to_feather(f"{experiment_path}/{name}.feather")
